# %% [markdown]
# # Importaciones

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Importamos la libreria para realizar la conexión con la base de datos
from sqlalchemy import create_engine

#Libreria para el manejo de datos
import pandas as pd
from datetime import datetime
import dateutil.relativedelta
import random

#Libreria para la descripción de las variables
import matplotlib.pyplot as plt

#Libreria para realizar los conjuntos de modelamiento, validación y pruebas
import numpy as np 
from sklearn.model_selection import train_test_split

#Libreria para utilizar la técnica de árboles extremadamente aleatorios
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

#LIbreria para guardar el entrenamiento de los extra trees
from joblib import dump, load

#Para realizar las redes neuronales
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, InputLayer, LSTM, Bidirectional
from keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.regularizers import l2
from keras.models import load_model

#Libreria para realizar comparaciónes
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Carga de datos
#
# Descargamos el archivo de datos desde la página http://www.sui.gov.co/web/datos-abiertos/energia/energia-formato-5-informacion-de-transformadores donde se encuentran el archivos de datos particular de enero de 2019 en el siguiente enlace http://www.sui.gov.co/datosAbiertos/Energia_442_M_4_2019.csv.zip.
#
# Es de importancia aclarar que se realizo la descarga de los datos de manera manual, debido a que la página web tiene protección para descargas automáticas.

# %% [markdown]
# ## Funciones

# %%
def df_aleatorios(df, cantidad):

  lenght = len(df) -1
  aleatorios = [ random.randint(0,lenght) for _ in range(cantidad)]
  df = df[aleatorios]

  return df

# %%
# Funcion de lectura de los datos
def df_read():
    
        #Lectura del archivo a dataframe
        dataframe = pd.read_csv('/content/drive/My Drive/Colab Notebooks/TFM/IA/formato5_520.zip',
                                header=0)
        
        #Convertimos las fecha a tipo fecha
        dataframe['fecha'] = pd.to_datetime(dataframe['fecha'])
        
        dataframe['mes'] = dataframe['fecha'].dt.month
        
        #Convertimos los valores S y N en booleanos
        dic = {'S': True, 'N': False}
        
        dataframe['propiedad'] = dataframe['propiedad'].map(dic)
        
        print('Archivo cargado ',dataframe.shape)
        
        return dataframe

# %%
# Función traer códigos de todos los transformadores
def df_tranformadores(df):
    
    unique_transformators = df['id_transformador'].unique()
    
    print('Transformadores unicos ',len(unique_transformators))
    
    return unique_transformators

# %%
# Función traer datos de entrada
def df_entrada(df, transformador, fecha):
    
    df_in = df[(df['fecha'] > (fecha - dateutil.relativedelta.relativedelta(months=37) ) ) & 
               (df['fecha'] < fecha) & 
               (df['id_transformador'] == transformador)]
    
    df_in = df_in.sort_values(by=['fecha'], ascending=False)
    
    del df_in['fecha']
    del df_in['id_transformador']
    
    return df_in

# %%
# Función traer datos de entrada
def df_entrada_lstm(df, transformador, fecha):
    
    df_in = df[(df['fecha'] == (fecha - dateutil.relativedelta.relativedelta(months=1) ) ) & 
               (df['id_transformador'] == transformador)]
    
    df_in = df_in.sort_values(by=['fecha'], ascending=False)
    
    del df_in['fecha']
    del df_in['id_transformador']
    
    return df_in

# %%
# Función traer datos de salida
def df_predicción(df, transformador, fecha):
    
    df_out = df[(df['fecha'] == fecha) & 
                (df['id_transformador'] == transformador)]
    
    df_out = df_out[['min_catastrofes','min_expansion','min_infraestructura',
                     'min_inpne','min_ipne','min_limitacion','min_racionamiento', 
                     'min_seguridad', 'min_strstn', 'min_subestaciones', 'min_terrorismo', 
                     'min_usuario', 'min_zonasespeciales']]

    return df_out

# %%
# Función para entrenamiento de una fecha particular
# Con todos los transformadores
def df_conjunto(fecha):
    
    print('Leyendo el archivo de datos')
    
    df = df_read()
    
    print('Extrayendo información transformadores')
    
    transformador = df_tranformadores(df)
    
    #Limitación para las pruebas
    #transformador = df_aleatorios(transformador, 10000)
    
    #Conjuntos
    X = []
    y = []

    #Lista de fechas
    # Rango de 6 años
    date_list = [fecha - dateutil.relativedelta.relativedelta(months=x) for x in range(48)]

    date_list = np.array(date_list)
    
    # Recorremos todos los transformadores
    # Tomamos conjuntos de entrada y predicción
    for index,t in enumerate(transformador): 
        
        y1 = []
        X1 = []
        
        if (index * 100 / len(transformador)) % 10 == 0:
            print('Revisando el registro ',index, ' correspondiente al ',
                  index*100 / len(transformador),'% de ',len(transformador), ' registros')

        #transformator_dates = df_aleatorios(date_list, 18) #Para pruebas
        transformator_dates = date_list

        #Realizamos la extracción de conjunto para determianda fecha
        for date in transformator_dates:
        
            y1 = df_predicción(df, t, date)

            if not y1.empty:

                X1 = df_entrada(df, t, date)

                if (not X1.empty) and X1.shape[0] == 36 :

                    X.append(X1.values)
                    y.append(y1.values[0])
                
    print('Cargado un total de: ',len(X),' datos')
        
    return np.array(X), np.array(y)

# %%
# Función para entrenamiento de una fecha particular
# Con todos los transformadores
def df_conjunto_lstm(fecha):
    
    print('Leyendo el archivo de datos')
    
    df = df_read()
    
    print('Extrayendo información transformadores')
    
    transformador = df_tranformadores(df)
    
    #Limitación para las pruebas
    #transformador = df_aleatorios(transformador, 100)
    
    #Conjuntos
    X = []
    y = []

    #Lista de fechas
    # Rango de fechas años
    date_list = [fecha - dateutil.relativedelta.relativedelta(months=x) for x in range(108)]

    #date_list = np.array(date_list)
    
    # Recorremos todos los transformadores
    # Tomamos conjuntos de entrada y predicción
    for index,t in enumerate(transformador): 
        
        y1 = []
        X1 = []
        
        if (index * 100 / len(transformador)) % 10 == 0:
            print('Revisando el registro ',index, ' correspondiente al ',
                  index*100 / len(transformador),'% de ',len(transformador), ' registros')

        #transformator_dates = df_aleatorios(date_list, 18) #Para pruebas
        transformator_dates = date_list

        #Realizamos la extracción de conjunto para determianda fecha
        for date in transformator_dates:
        
            y1 = df_predicción(df, t, date)

            if not y1.empty:

                X1 = df_entrada_lstm(df, t, date)

                if (not X1.empty) and X1.shape[0] == 36 :

                    X.append(X1.values)
                    y.append(y1.values[0])
                
    print('Cargado un total de: ',len(X),' datos')
        
    return np.array(X), np.array(y)

# %% [markdown]
# ## Aplicación

# %%
#X, y = df_conjunto(datetime(2019,2,1))
# Out:
# Leyendo el archivo de datos
# Archivo cargado  (1324082, 39)
# Extrayendo información transformadores
# Transformadores unicos  25000
# Revisando el registro  0  correspondiente al  0.0 % de  25000  registros
# Revisando el registro  2500  correspondiente al  10.0 % de  25000  registros
# Revisando el registro  5000  correspondiente al  20.0 % de  25000  registros
# Revisando el registro  7500  correspondiente al  30.0 % de  25000  registros
# Revisando el registro  10000  correspondiente al  40.0 % de  25000  registros
# Revisando el registro  12500  correspondiente al  50.0 % de  25000  registros
# Revisando el registro  15000  correspondiente al  60.0 % de  25000  registros
# Revisando el registro  17500  correspondiente al  70.0 % de  25000  registros
# Revisando el registro  20000  correspondiente al  80.0 % de  25000  registros
# Revisando el registro  22500  correspondiente al  90.0 % de  25000  registros
# Cargado un total de:  397528  datos

# %%
#dump(X, '/content/drive/My Drive/Colab Notebooks/TFM/IA/X_full.joblib.z')
#dump(y, '/content/drive/My Drive/Colab Notebooks/TFM/IA/y_full.joblib.z')
# Out:
# ['/content/drive/My Drive/Colab Notebooks/TFM/IA/y_full.joblib.z']

# %%
X = load('/content/drive/My Drive/Colab Notebooks/TFM/IA/X_full.joblib.z')
y = load('/content/drive/My Drive/Colab Notebooks/TFM/IA/y_full.joblib.z')

# %% [markdown]
# # Determinación de conjunto de modelamiento, validación y pruebas

# %%
# Cojunto de pruebas
train_x, test_x, train_y, test_y = train_test_split(X, y, 
                                                    test_size=0.2, random_state=2)

# %%
# Cojunto de pruebas
train_x, validation_x, train_y, validation_y = train_test_split(train_x, train_y, 
                                                    test_size=0.2, random_state=4)

# %%
print('Tamaño cojunto de entrenamiento final : ', len(train_x), len(train_y))
print('Tamaño cojunto de validación final : ', len(validation_x), len(validation_y))
print('Tamaño cojunto de pruebas final : ', len(test_x), len(test_y))
# Out:
# Tamaño cojunto de entrenamiento final :  254417 254417
# Tamaño cojunto de validación final :  63605 63605
# Tamaño cojunto de pruebas final :  79506 79506

# %% [markdown]
# # Redes Neuronales Profundas

# %%
epochs = 1000
batch = 512

# %% [markdown]
# ## Funciones

# %%
# Función Input
def input_layer(model, size_x, size_y = None, size_z = None):
    
    if size_y == None:
        
        model.add( InputLayer( input_shape=(size_x, ) ) )
        
    elif size_z == None:
    
        model.add( InputLayer( input_shape=(size_x,size_y) ) )
        
    else:
        
        model.add( InputLayer( input_shape=(size_x,size_y, size_z) ) )
    
    model.add( BatchNormalization() )
    
    return model

# %%
#Función Densa
def densa(model, neuronas= 256, activacion = 'relu', 
          regularizador = l2(0.001), dropout = 0.2):

    #Creación de una capa de 32 neuronas densas
    model.add(Dense(neuronas, activation=activacion, 
                    kernel_regularizer=regularizador,
                    bias_regularizer=regularizador))
  
    model.add(BatchNormalization())

    model.add(Dropout(dropout))

    return model

# %%
#Función de resultado
def result_layer(model, y, activacion = 'linear'):
    
    model.add(Dense(y, activation=activacion))
    
    return model

# %%
def coeff_determination(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
def run_desing(model, name, batch, epochs, 
               train_x, train_y, 
               test_x, test_y, 
               optimizer = 'adam', loss = 'mean_squared_error'):
    
    metrics = ['mean_absolute_error','mean_squared_error',coeff_determination]
    model.name = name
    
    #Revisamos el modelo
    model.summary()
    
    #Compilación del modelo
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    #Con el objetivo de parar el entrenamiento si los valores no mejoran
    early_stop = EarlyStopping(monitor='val_loss', patience=epochs*0.05, verbose=1, 
                             min_delta=0.01, mode='auto')  

    #Con el objetivo de cambiar el learnfactor
    reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.1, patience=epochs*0.02, 
                                  mode='auto', verbose=1, min_delta=1e-4, 
                                  min_lr=0) 
    
    #Guardamos el mejor modelo
    checkpoint = ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/TFM/IA/'+name+'.model', 
                                 monitor='val_loss', verbose=1, 
                                 save_best_only=True, mode='min')

    history = model.fit(train_x, train_y,
                        batch_size=batch,
                        epochs=epochs,
                        verbose=1,
                        validation_data=(test_x, test_y),
                        callbacks=[early_stop, reduce_lr,
                                  checkpoint])
    
    model.save('/content/drive/My Drive/Colab Notebooks/TFM/IA/'+name+'.h5')

    dump([model,history,coeff_determination], '/content/drive/My Drive/Colab Notebooks/TFM/IA/'+name+'.joblib.z')
  
    return model, history

# %%
def load_desing(name):

  #Cargamos desde disco
  model_complete = load('/content/drive/My Drive/Colab Notebooks/TFM/IA/'+name+'.joblib.lz4')

  #Cargamos el modelo, historia y variable especial
  model = model_complete[0]
  history = model_complete[1]
  coeff_determination = model_complete[2]

  return model, history

# %%
def load_model_weights(model, name):

  model.load_weights('/content/drive/My Drive/Colab Notebooks/TFM/IA/'+name+'.model')

  return model

# %% [markdown]
# ## Modelo

# %%
def modelo_dnn():
    
    #Creación del modelo secuencial
    model = Sequential()
    
    function_act = 'relu'
    
    #Capa inicial
    model = input_layer(model, len(train_x[0]), len(train_x[0][0]))
    
    model.add(Flatten())
    
    model = densa(model, 1024, activacion = function_act)
    
    model = densa(model, 1024, activacion = function_act)
    
    model = densa(model, 512, activacion = function_act)
    
    model = densa(model, 512, activacion = function_act)
    
    model = densa(model, 256, activacion = function_act)
    
    model = result_layer(model, len(train_y[0]))
    
    return model

# %% [markdown]
# ## Ejecución

# %%
model_dnn, history_dnn = run_desing(modelo_dnn(), 'modelo_dnn_full', batch, epochs, 
                                    train_x, train_y, 
                                    validation_x, validation_y,
                                     'adam','huber_loss')
# Out:
# Model: "modelo_dnn_full"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 36, 37)            148
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1332)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1364992
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 13)                3341
# =================================================================
# Total params: 3,350,177
# Trainable params: 3,343,447
# Non-trainable params: 6,730
# _________________________________________________________________
# Train on 254417 samples, validate on 63605 samples
# Epoch 1/1000
# 254417/254417 [==============================] - 22s 85us/step - loss: 44.1190 - mean_absolute_error: 43.4009 - mean_squared_error: 131875.3750 - coeff_determination: 0.0438 - val_loss: 48.7735 - val_mean_absolute_error: 48.0887 - val_mean_squared_error: 147513.5938 - val_coeff_determination: -0.0145
#
# Epoch 00001: val_loss improved from inf to 48.77350, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 2/1000
# 254417/254417 [==============================] - 19s 74us/step - loss: 33.0256 - mean_absolute_error: 31.8434 - mean_squared_error: 105785.1641 - coeff_determination: 0.2604 - val_loss: 30.4253 - val_mean_absolute_error: 28.8423 - val_mean_squared_error: 105202.0938 - val_coeff_determination: 0.3210
#
# Epoch 00002: val_loss improved from 48.77350 to 30.42526, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 3/1000
# 254417/254417 [==============================] - 19s 74us/step - loss: 27.8426 - mean_absolute_error: 26.0089 - mean_squared_error: 90098.8516 - coeff_determination: 0.3912 - val_loss: 26.0454 - val_mean_absolute_error: 24.0151 - val_mean_squared_error: 93223.2188 - val_coeff_determination: 0.4140
#
# Epoch 00003: val_loss improved from 30.42526 to 26.04544, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 4/1000
# 254417/254417 [==============================] - 19s 73us/step - loss: 25.4860 - mean_absolute_error: 23.3173 - mean_squared_error: 82329.0078 - coeff_determination: 0.4503 - val_loss: 22.6818 - val_mean_absolute_error: 20.3975 - val_mean_squared_error: 87073.4531 - val_coeff_determination: 0.4598
#
# Epoch 00004: val_loss improved from 26.04544 to 22.68180, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 5/1000
# 254417/254417 [==============================] - 19s 74us/step - loss: 24.2185 - mean_absolute_error: 21.7987 - mean_squared_error: 77754.3125 - coeff_determination: 0.4866 - val_loss: 22.2647 - val_mean_absolute_error: 19.7249 - val_mean_squared_error: 83211.7734 - val_coeff_determination: 0.4876
#
# Epoch 00005: val_loss improved from 22.68180 to 22.26470, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 6/1000
# 254417/254417 [==============================] - 19s 74us/step - loss: 23.2961 - mean_absolute_error: 20.7010 - mean_squared_error: 74546.7578 - coeff_determination: 0.5098 - val_loss: 21.4252 - val_mean_absolute_error: 18.7589 - val_mean_squared_error: 81300.3438 - val_coeff_determination: 0.5032
#
# Epoch 00006: val_loss improved from 22.26470 to 21.42520, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 7/1000
# 254417/254417 [==============================] - 19s 73us/step - loss: 22.6385 - mean_absolute_error: 19.9405 - mean_squared_error: 72668.4531 - coeff_determination: 0.5269 - val_loss: 21.5200 - val_mean_absolute_error: 18.7787 - val_mean_squared_error: 80544.0547 - val_coeff_determination: 0.5095
#
# Epoch 00007: val_loss did not improve from 21.42520
# Epoch 8/1000
# 254417/254417 [==============================] - 18s 72us/step - loss: 22.3180 - mean_absolute_error: 19.5156 - mean_squared_error: 71116.5625 - coeff_determination: 0.5390 - val_loss: 20.9041 - val_mean_absolute_error: 18.0502 - val_mean_squared_error: 78730.0312 - val_coeff_determination: 0.5200
#
# Epoch 00008: val_loss improved from 21.42520 to 20.90406, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 9/1000
# 254417/254417 [==============================] - 19s 73us/step - loss: 21.9396 - mean_absolute_error: 19.0492 - mean_squared_error: 70161.4531 - coeff_determination: 0.5475 - val_loss: 19.9298 - val_mean_absolute_error: 17.0439 - val_mean_squared_error: 76638.3828 - val_coeff_determination: 0.5361
#
# Epoch 00009: val_loss improved from 20.90406 to 19.92976, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 10/1000
# 254417/254417 [==============================] - 18s 72us/step - loss: 21.5569 - mean_absolute_error: 18.6338 - mean_squared_error: 68746.8984 - coeff_determination: 0.5586 - val_loss: 19.6232 - val_mean_absolute_error: 16.6578 - val_mean_squared_error: 74933.3203 - val_coeff_determination: 0.5484
#
# Epoch 00010: val_loss improved from 19.92976 to 19.62315, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 11/1000
# 254417/254417 [==============================] - 18s 72us/step - loss: 21.3396 - mean_absolute_error: 18.3731 - mean_squared_error: 68342.0000 - coeff_determination: 0.5619 - val_loss: 20.4275 - val_mean_absolute_error: 17.4314 - val_mean_squared_error: 75757.5078 - val_coeff_determination: 0.5424
#
# Epoch 00011: val_loss did not improve from 19.62315
# Epoch 12/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 21.2273 - mean_absolute_error: 18.2253 - mean_squared_error: 67242.5391 - coeff_determination: 0.5676 - val_loss: 18.8793 - val_mean_absolute_error: 15.8128 - val_mean_squared_error: 73566.4453 - val_coeff_determination: 0.5552
#
# Epoch 00012: val_loss improved from 19.62315 to 18.87930, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 13/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.9912 - mean_absolute_error: 17.9358 - mean_squared_error: 67009.0078 - coeff_determination: 0.5745 - val_loss: 18.6028 - val_mean_absolute_error: 15.5252 - val_mean_squared_error: 72570.7188 - val_coeff_determination: 0.5646
#
# Epoch 00013: val_loss improved from 18.87930 to 18.60280, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 14/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.8057 - mean_absolute_error: 17.7169 - mean_squared_error: 66220.5156 - coeff_determination: 0.5757 - val_loss: 18.7042 - val_mean_absolute_error: 15.5931 - val_mean_squared_error: 72709.6172 - val_coeff_determination: 0.5634
#
# Epoch 00014: val_loss did not improve from 18.60280
# Epoch 15/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.5804 - mean_absolute_error: 17.4750 - mean_squared_error: 65858.1328 - coeff_determination: 0.5776 - val_loss: 18.8417 - val_mean_absolute_error: 15.7065 - val_mean_squared_error: 72417.7891 - val_coeff_determination: 0.5657
#
# Epoch 00015: val_loss did not improve from 18.60280
# Epoch 16/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.5754 - mean_absolute_error: 17.4612 - mean_squared_error: 65839.0078 - coeff_determination: 0.5813 - val_loss: 18.5416 - val_mean_absolute_error: 15.4014 - val_mean_squared_error: 72436.1328 - val_coeff_determination: 0.5655
#
# Epoch 00016: val_loss improved from 18.60280 to 18.54157, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 17/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.5096 - mean_absolute_error: 17.3684 - mean_squared_error: 65819.0156 - coeff_determination: 0.5778 - val_loss: 18.3475 - val_mean_absolute_error: 15.1706 - val_mean_squared_error: 72652.6797 - val_coeff_determination: 0.5631
#
# Epoch 00017: val_loss improved from 18.54157 to 18.34747, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 18/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.4569 - mean_absolute_error: 17.2917 - mean_squared_error: 65345.8086 - coeff_determination: 0.5774 - val_loss: 18.5193 - val_mean_absolute_error: 15.3075 - val_mean_squared_error: 71310.9609 - val_coeff_determination: 0.5723
#
# Epoch 00018: val_loss did not improve from 18.34747
# Epoch 19/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 20.1620 - mean_absolute_error: 16.9774 - mean_squared_error: 64449.4453 - coeff_determination: 0.5944 - val_loss: 18.2053 - val_mean_absolute_error: 14.9880 - val_mean_squared_error: 70433.8828 - val_coeff_determination: 0.5784
#
# Epoch 00019: val_loss improved from 18.34747 to 18.20530, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 20/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.1780 - mean_absolute_error: 16.9811 - mean_squared_error: 64370.8672 - coeff_determination: 0.5938 - val_loss: 18.5531 - val_mean_absolute_error: 15.3619 - val_mean_squared_error: 71860.5469 - val_coeff_determination: 0.5695
#
# Epoch 00020: val_loss did not improve from 18.20530
# Epoch 21/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 20.1158 - mean_absolute_error: 16.9231 - mean_squared_error: 64209.8320 - coeff_determination: 0.5879 - val_loss: 18.2521 - val_mean_absolute_error: 15.0283 - val_mean_squared_error: 72175.0156 - val_coeff_determination: 0.5668
#
# Epoch 00021: val_loss did not improve from 18.20530
# Epoch 22/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 20.0117 - mean_absolute_error: 16.7708 - mean_squared_error: 63448.6445 - coeff_determination: 0.5987 - val_loss: 18.6070 - val_mean_absolute_error: 15.3230 - val_mean_squared_error: 70663.6953 - val_coeff_determination: 0.5771
#
# Epoch 00022: val_loss did not improve from 18.20530
# Epoch 23/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 20.1035 - mean_absolute_error: 16.8271 - mean_squared_error: 63920.8555 - coeff_determination: 0.5911 - val_loss: 18.4659 - val_mean_absolute_error: 15.1718 - val_mean_squared_error: 73010.5625 - val_coeff_determination: 0.5613
#
# Epoch 00023: val_loss did not improve from 18.20530
# Epoch 24/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 19.9325 - mean_absolute_error: 16.6706 - mean_squared_error: 63389.0312 - coeff_determination: 0.5956 - val_loss: 18.2469 - val_mean_absolute_error: 14.9446 - val_mean_squared_error: 70863.3906 - val_coeff_determination: 0.5755
#
# Epoch 00024: val_loss did not improve from 18.20530
# Epoch 25/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.9499 - mean_absolute_error: 16.6868 - mean_squared_error: 63602.6523 - coeff_determination: 0.5966 - val_loss: 17.9468 - val_mean_absolute_error: 14.6439 - val_mean_squared_error: 72196.1484 - val_coeff_determination: 0.5687
#
# Epoch 00025: val_loss improved from 18.20530 to 17.94677, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 26/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 19.8756 - mean_absolute_error: 16.6155 - mean_squared_error: 63511.6797 - coeff_determination: 0.5971 - val_loss: 17.4841 - val_mean_absolute_error: 14.2174 - val_mean_squared_error: 69368.8516 - val_coeff_determination: 0.5870
#
# Epoch 00026: val_loss improved from 17.94677 to 17.48413, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 27/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.6733 - mean_absolute_error: 16.4127 - mean_squared_error: 62730.6016 - coeff_determination: 0.5981 - val_loss: 18.0462 - val_mean_absolute_error: 14.7434 - val_mean_squared_error: 72419.9609 - val_coeff_determination: 0.5659
#
# Epoch 00027: val_loss did not improve from 17.48413
# Epoch 28/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.7422 - mean_absolute_error: 16.4618 - mean_squared_error: 63267.1758 - coeff_determination: 0.5994 - val_loss: 18.0898 - val_mean_absolute_error: 14.7733 - val_mean_squared_error: 70398.7031 - val_coeff_determination: 0.5751
#
# Epoch 00028: val_loss did not improve from 17.48413
# Epoch 29/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 19.7585 - mean_absolute_error: 16.4526 - mean_squared_error: 63124.5547 - coeff_determination: 0.6007 - val_loss: 17.8198 - val_mean_absolute_error: 14.4869 - val_mean_squared_error: 68856.2812 - val_coeff_determination: 0.5892
#
# Epoch 00029: val_loss did not improve from 17.48413
# Epoch 30/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.6843 - mean_absolute_error: 16.3899 - mean_squared_error: 63387.1133 - coeff_determination: 0.6034 - val_loss: 17.3828 - val_mean_absolute_error: 14.0588 - val_mean_squared_error: 69229.6250 - val_coeff_determination: 0.5868
#
# Epoch 00030: val_loss improved from 17.48413 to 17.38282, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 31/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.7128 - mean_absolute_error: 16.3954 - mean_squared_error: 63108.5742 - coeff_determination: 0.6007 - val_loss: 17.2551 - val_mean_absolute_error: 13.9096 - val_mean_squared_error: 69156.3125 - val_coeff_determination: 0.5878
#
# Epoch 00031: val_loss improved from 17.38282 to 17.25507, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 32/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.5421 - mean_absolute_error: 16.2346 - mean_squared_error: 62611.4492 - coeff_determination: 0.6041 - val_loss: 17.6837 - val_mean_absolute_error: 14.3433 - val_mean_squared_error: 70334.9141 - val_coeff_determination: 0.5783
#
# Epoch 00032: val_loss did not improve from 17.25507
# Epoch 33/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 19.5763 - mean_absolute_error: 16.2455 - mean_squared_error: 62885.2656 - coeff_determination: 0.6031 - val_loss: 18.1390 - val_mean_absolute_error: 14.7548 - val_mean_squared_error: 70061.8359 - val_coeff_determination: 0.5815
#
# Epoch 00033: val_loss did not improve from 17.25507
# Epoch 34/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.6929 - mean_absolute_error: 16.3264 - mean_squared_error: 63068.6836 - coeff_determination: 0.6063 - val_loss: 17.3263 - val_mean_absolute_error: 13.9492 - val_mean_squared_error: 70225.6953 - val_coeff_determination: 0.5818
#
# Epoch 00034: val_loss did not improve from 17.25507
# Epoch 35/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.3999 - mean_absolute_error: 16.0709 - mean_squared_error: 62172.8633 - coeff_determination: 0.6086 - val_loss: 17.4964 - val_mean_absolute_error: 14.1423 - val_mean_squared_error: 67839.1875 - val_coeff_determination: 0.5963
#
# Epoch 00035: val_loss did not improve from 17.25507
# Epoch 36/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.4969 - mean_absolute_error: 16.1582 - mean_squared_error: 62217.0938 - coeff_determination: 0.6047 - val_loss: 17.6354 - val_mean_absolute_error: 14.2391 - val_mean_squared_error: 69580.6562 - val_coeff_determination: 0.5854
#
# Epoch 00036: val_loss did not improve from 17.25507
# Epoch 37/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.2766 - mean_absolute_error: 15.9435 - mean_squared_error: 61524.1680 - coeff_determination: 0.6099 - val_loss: 16.7764 - val_mean_absolute_error: 13.4350 - val_mean_squared_error: 67837.9375 - val_coeff_determination: 0.5965
#
# Epoch 00037: val_loss improved from 17.25507 to 16.77636, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 38/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 19.3615 - mean_absolute_error: 16.0454 - mean_squared_error: 61547.4492 - coeff_determination: 0.6116 - val_loss: 17.2114 - val_mean_absolute_error: 13.8438 - val_mean_squared_error: 68747.5156 - val_coeff_determination: 0.5876
#
# Epoch 00038: val_loss did not improve from 16.77636
# Epoch 39/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.2979 - mean_absolute_error: 15.9378 - mean_squared_error: 61317.0586 - coeff_determination: 0.6116 - val_loss: 17.7496 - val_mean_absolute_error: 14.3465 - val_mean_squared_error: 68912.8984 - val_coeff_determination: 0.5869
#
# Epoch 00039: val_loss did not improve from 16.77636
# Epoch 40/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.4152 - mean_absolute_error: 16.0247 - mean_squared_error: 61728.1797 - coeff_determination: 0.6079 - val_loss: 17.2040 - val_mean_absolute_error: 13.8191 - val_mean_squared_error: 68449.6641 - val_coeff_determination: 0.5925
#
# Epoch 00040: val_loss did not improve from 16.77636
# Epoch 41/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.3276 - mean_absolute_error: 15.9616 - mean_squared_error: 61795.6758 - coeff_determination: 0.6065 - val_loss: 17.4184 - val_mean_absolute_error: 14.0054 - val_mean_squared_error: 68649.8281 - val_coeff_determination: 0.5922
#
# Epoch 00041: val_loss did not improve from 16.77636
# Epoch 42/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.2303 - mean_absolute_error: 15.8507 - mean_squared_error: 60921.4023 - coeff_determination: 0.6136 - val_loss: 17.4566 - val_mean_absolute_error: 14.0405 - val_mean_squared_error: 67826.1484 - val_coeff_determination: 0.5956
#
# Epoch 00042: val_loss did not improve from 16.77636
# Epoch 43/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.2657 - mean_absolute_error: 15.8931 - mean_squared_error: 60873.1719 - coeff_determination: 0.6123 - val_loss: 17.1410 - val_mean_absolute_error: 13.7592 - val_mean_squared_error: 67359.1797 - val_coeff_determination: 0.5995
#
# Epoch 00043: val_loss did not improve from 16.77636
# Epoch 44/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 19.1951 - mean_absolute_error: 15.8277 - mean_squared_error: 61027.3477 - coeff_determination: 0.6146 - val_loss: 17.0028 - val_mean_absolute_error: 13.6154 - val_mean_squared_error: 68385.9453 - val_coeff_determination: 0.5945
#
# Epoch 00044: val_loss did not improve from 16.77636
# Epoch 45/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 19.2498 - mean_absolute_error: 15.8874 - mean_squared_error: 61103.4570 - coeff_determination: 0.6134 - val_loss: 17.4462 - val_mean_absolute_error: 14.0459 - val_mean_squared_error: 69845.5703 - val_coeff_determination: 0.5856
#
# Epoch 00045: val_loss did not improve from 16.77636
# Epoch 46/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.0802 - mean_absolute_error: 15.7165 - mean_squared_error: 60409.0859 - coeff_determination: 0.6188 - val_loss: 17.1563 - val_mean_absolute_error: 13.7622 - val_mean_squared_error: 68218.3047 - val_coeff_determination: 0.5938
#
# Epoch 00046: val_loss did not improve from 16.77636
# Epoch 47/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.2077 - mean_absolute_error: 15.8209 - mean_squared_error: 60353.0195 - coeff_determination: 0.6152 - val_loss: 17.1064 - val_mean_absolute_error: 13.6925 - val_mean_squared_error: 68116.2734 - val_coeff_determination: 0.5925
#
# Epoch 00047: val_loss did not improve from 16.77636
# Epoch 48/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.2643 - mean_absolute_error: 15.8702 - mean_squared_error: 60837.1406 - coeff_determination: 0.6138 - val_loss: 16.8663 - val_mean_absolute_error: 13.4576 - val_mean_squared_error: 66793.4766 - val_coeff_determination: 0.6023
#
# Epoch 00048: val_loss did not improve from 16.77636
# Epoch 49/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.2033 - mean_absolute_error: 15.7976 - mean_squared_error: 60623.4805 - coeff_determination: 0.6196 - val_loss: 16.9123 - val_mean_absolute_error: 13.4891 - val_mean_squared_error: 66850.5000 - val_coeff_determination: 0.6044
#
# Epoch 00049: val_loss did not improve from 16.77636
# Epoch 50/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.2460 - mean_absolute_error: 15.8213 - mean_squared_error: 60713.8984 - coeff_determination: 0.6138 - val_loss: 17.2545 - val_mean_absolute_error: 13.7798 - val_mean_squared_error: 69223.3203 - val_coeff_determination: 0.5849
#
# Epoch 00050: val_loss did not improve from 16.77636
# Epoch 51/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 19.0698 - mean_absolute_error: 15.6374 - mean_squared_error: 59865.9219 - coeff_determination: 0.6180 - val_loss: 16.5508 - val_mean_absolute_error: 13.1173 - val_mean_squared_error: 65890.9922 - val_coeff_determination: 0.6085
#
# Epoch 00051: val_loss improved from 16.77636 to 16.55081, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 52/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.0373 - mean_absolute_error: 15.6353 - mean_squared_error: 59916.0898 - coeff_determination: 0.6218 - val_loss: 16.7046 - val_mean_absolute_error: 13.2801 - val_mean_squared_error: 67381.8047 - val_coeff_determination: 0.6008
#
# Epoch 00052: val_loss did not improve from 16.55081
# Epoch 53/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 19.0408 - mean_absolute_error: 15.6282 - mean_squared_error: 60253.1797 - coeff_determination: 0.6199 - val_loss: 16.7543 - val_mean_absolute_error: 13.3529 - val_mean_squared_error: 67361.3906 - val_coeff_determination: 0.6002
#
# Epoch 00053: val_loss did not improve from 16.55081
# Epoch 54/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.9925 - mean_absolute_error: 15.5969 - mean_squared_error: 59903.8359 - coeff_determination: 0.6230 - val_loss: 17.1251 - val_mean_absolute_error: 13.7109 - val_mean_squared_error: 65934.8438 - val_coeff_determination: 0.6092
#
# Epoch 00054: val_loss did not improve from 16.55081
# Epoch 55/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.0704 - mean_absolute_error: 15.6597 - mean_squared_error: 60171.1875 - coeff_determination: 0.6206 - val_loss: 16.6888 - val_mean_absolute_error: 13.2423 - val_mean_squared_error: 67083.6172 - val_coeff_determination: 0.6019
#
# Epoch 00055: val_loss did not improve from 16.55081
# Epoch 56/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.9119 - mean_absolute_error: 15.5352 - mean_squared_error: 59769.2656 - coeff_determination: 0.6242 - val_loss: 16.8612 - val_mean_absolute_error: 13.4793 - val_mean_squared_error: 67396.6875 - val_coeff_determination: 0.5994
#
# Epoch 00056: val_loss did not improve from 16.55081
# Epoch 57/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.8188 - mean_absolute_error: 15.4612 - mean_squared_error: 59482.7227 - coeff_determination: 0.6286 - val_loss: 16.7499 - val_mean_absolute_error: 13.3601 - val_mean_squared_error: 67716.8594 - val_coeff_determination: 0.5965
#
# Epoch 00057: val_loss did not improve from 16.55081
# Epoch 58/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.8469 - mean_absolute_error: 15.4702 - mean_squared_error: 59775.2812 - coeff_determination: 0.6258 - val_loss: 16.6488 - val_mean_absolute_error: 13.2503 - val_mean_squared_error: 66768.8125 - val_coeff_determination: 0.6046
#
# Epoch 00058: val_loss did not improve from 16.55081
# Epoch 59/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 19.1847 - mean_absolute_error: 15.7905 - mean_squared_error: 62548.4297 - coeff_determination: 0.5993 - val_loss: 17.2663 - val_mean_absolute_error: 13.8246 - val_mean_squared_error: 67787.4219 - val_coeff_determination: 0.5969
#
# Epoch 00059: val_loss did not improve from 16.55081
# Epoch 60/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.9294 - mean_absolute_error: 15.5433 - mean_squared_error: 59646.9180 - coeff_determination: 0.6254 - val_loss: 16.8443 - val_mean_absolute_error: 13.4640 - val_mean_squared_error: 67888.1641 - val_coeff_determination: 0.5967
#
# Epoch 00060: val_loss did not improve from 16.55081
# Epoch 61/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.9524 - mean_absolute_error: 15.5495 - mean_squared_error: 59693.4180 - coeff_determination: 0.6172 - val_loss: 16.7066 - val_mean_absolute_error: 13.2655 - val_mean_squared_error: 67039.1094 - val_coeff_determination: 0.6019
#
# Epoch 00061: val_loss did not improve from 16.55081
# Epoch 62/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.8337 - mean_absolute_error: 15.4421 - mean_squared_error: 59095.2383 - coeff_determination: 0.6275 - val_loss: 16.5923 - val_mean_absolute_error: 13.1786 - val_mean_squared_error: 66452.9297 - val_coeff_determination: 0.6047
#
# Epoch 00062: val_loss did not improve from 16.55081
# Epoch 63/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.8892 - mean_absolute_error: 15.4836 - mean_squared_error: 59764.6133 - coeff_determination: 0.6230 - val_loss: 16.6482 - val_mean_absolute_error: 13.2060 - val_mean_squared_error: 67060.1953 - val_coeff_determination: 0.6044
#
# Epoch 00063: val_loss did not improve from 16.55081
# Epoch 64/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.9338 - mean_absolute_error: 15.5071 - mean_squared_error: 60224.3477 - coeff_determination: 0.6236 - val_loss: 16.7124 - val_mean_absolute_error: 13.2743 - val_mean_squared_error: 66075.4766 - val_coeff_determination: 0.6087
#
# Epoch 00064: val_loss did not improve from 16.55081
# Epoch 65/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.8630 - mean_absolute_error: 15.4705 - mean_squared_error: 59734.1836 - coeff_determination: 0.6239 - val_loss: 16.7068 - val_mean_absolute_error: 13.2722 - val_mean_squared_error: 66857.1172 - val_coeff_determination: 0.6028
#
# Epoch 00065: val_loss did not improve from 16.55081
# Epoch 66/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.9711 - mean_absolute_error: 15.5675 - mean_squared_error: 60253.9062 - coeff_determination: 0.6187 - val_loss: 17.4560 - val_mean_absolute_error: 14.0288 - val_mean_squared_error: 66417.9141 - val_coeff_determination: 0.6068
#
# Epoch 00066: val_loss did not improve from 16.55081
# Epoch 67/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.8794 - mean_absolute_error: 15.4677 - mean_squared_error: 59014.3672 - coeff_determination: 0.6303 - val_loss: 16.6520 - val_mean_absolute_error: 13.2197 - val_mean_squared_error: 67340.8828 - val_coeff_determination: 0.5985
#
# Epoch 00067: val_loss did not improve from 16.55081
# Epoch 68/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.8279 - mean_absolute_error: 15.4346 - mean_squared_error: 59229.1641 - coeff_determination: 0.6288 - val_loss: 16.7432 - val_mean_absolute_error: 13.3146 - val_mean_squared_error: 67964.2422 - val_coeff_determination: 0.5970
#
# Epoch 00068: val_loss did not improve from 16.55081
# Epoch 69/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.8172 - mean_absolute_error: 15.4135 - mean_squared_error: 59379.3594 - coeff_determination: 0.6269 - val_loss: 16.4749 - val_mean_absolute_error: 13.0597 - val_mean_squared_error: 67470.3672 - val_coeff_determination: 0.6008
#
# Epoch 00069: val_loss improved from 16.55081 to 16.47486, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 70/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7478 - mean_absolute_error: 15.3675 - mean_squared_error: 59657.5039 - coeff_determination: 0.6246 - val_loss: 17.2796 - val_mean_absolute_error: 13.8811 - val_mean_squared_error: 67560.1094 - val_coeff_determination: 0.5984
#
# Epoch 00070: val_loss did not improve from 16.47486
# Epoch 71/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.8304 - mean_absolute_error: 15.4500 - mean_squared_error: 59145.1055 - coeff_determination: 0.6253 - val_loss: 16.7482 - val_mean_absolute_error: 13.3253 - val_mean_squared_error: 66864.5938 - val_coeff_determination: 0.6012
#
# Epoch 00071: val_loss did not improve from 16.47486
# Epoch 72/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7625 - mean_absolute_error: 15.3738 - mean_squared_error: 59490.1523 - coeff_determination: 0.6241 - val_loss: 16.6693 - val_mean_absolute_error: 13.2694 - val_mean_squared_error: 66521.6641 - val_coeff_determination: 0.6039
#
# Epoch 00072: val_loss did not improve from 16.47486
# Epoch 73/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.6768 - mean_absolute_error: 15.3252 - mean_squared_error: 59242.3828 - coeff_determination: 0.6272 - val_loss: 16.4979 - val_mean_absolute_error: 13.0967 - val_mean_squared_error: 65341.7266 - val_coeff_determination: 0.6133
#
# Epoch 00073: val_loss did not improve from 16.47486
# Epoch 74/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.8738 - mean_absolute_error: 15.4753 - mean_squared_error: 59444.2227 - coeff_determination: 0.6259 - val_loss: 17.1398 - val_mean_absolute_error: 13.7036 - val_mean_squared_error: 67945.1875 - val_coeff_determination: 0.5938
#
# Epoch 00074: val_loss did not improve from 16.47486
# Epoch 75/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.7347 - mean_absolute_error: 15.3221 - mean_squared_error: 58513.9062 - coeff_determination: 0.6291 - val_loss: 16.7162 - val_mean_absolute_error: 13.2850 - val_mean_squared_error: 65786.9219 - val_coeff_determination: 0.6082
#
# Epoch 00075: val_loss did not improve from 16.47486
# Epoch 76/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.7835 - mean_absolute_error: 15.3790 - mean_squared_error: 58836.7500 - coeff_determination: 0.6259 - val_loss: 17.1008 - val_mean_absolute_error: 13.6444 - val_mean_squared_error: 65826.2969 - val_coeff_determination: 0.6091
#
# Epoch 00076: val_loss did not improve from 16.47486
# Epoch 77/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.8019 - mean_absolute_error: 15.3647 - mean_squared_error: 58788.6719 - coeff_determination: 0.6278 - val_loss: 17.3725 - val_mean_absolute_error: 13.9064 - val_mean_squared_error: 67751.7734 - val_coeff_determination: 0.5973
#
# Epoch 00077: val_loss did not improve from 16.47486
# Epoch 78/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.8263 - mean_absolute_error: 15.3760 - mean_squared_error: 58770.1680 - coeff_determination: 0.6286 - val_loss: 16.5099 - val_mean_absolute_error: 13.0396 - val_mean_squared_error: 64969.5898 - val_coeff_determination: 0.6157
#
# Epoch 00078: val_loss did not improve from 16.47486
# Epoch 79/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 18.7876 - mean_absolute_error: 15.3393 - mean_squared_error: 58366.1484 - coeff_determination: 0.6324 - val_loss: 16.5250 - val_mean_absolute_error: 13.0586 - val_mean_squared_error: 65765.0234 - val_coeff_determination: 0.6100
#
# Epoch 00079: val_loss did not improve from 16.47486
# Epoch 80/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.7292 - mean_absolute_error: 15.3090 - mean_squared_error: 58785.1406 - coeff_determination: 0.6282 - val_loss: 17.0171 - val_mean_absolute_error: 13.5817 - val_mean_squared_error: 66282.7812 - val_coeff_determination: 0.6062
#
# Epoch 00080: val_loss did not improve from 16.47486
# Epoch 81/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7953 - mean_absolute_error: 15.3913 - mean_squared_error: 59189.8125 - coeff_determination: 0.6242 - val_loss: 16.6969 - val_mean_absolute_error: 13.2734 - val_mean_squared_error: 66457.2812 - val_coeff_determination: 0.6034
#
# Epoch 00081: val_loss did not improve from 16.47486
# Epoch 82/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7488 - mean_absolute_error: 15.3164 - mean_squared_error: 59100.6758 - coeff_determination: 0.6258 - val_loss: 16.7318 - val_mean_absolute_error: 13.2917 - val_mean_squared_error: 66825.5000 - val_coeff_determination: 0.6034
#
# Epoch 00082: val_loss did not improve from 16.47486
# Epoch 83/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.8126 - mean_absolute_error: 15.4077 - mean_squared_error: 59533.5781 - coeff_determination: 0.6241 - val_loss: 16.7423 - val_mean_absolute_error: 13.3202 - val_mean_squared_error: 65651.8047 - val_coeff_determination: 0.6116
#
# Epoch 00083: val_loss did not improve from 16.47486
# Epoch 84/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.5641 - mean_absolute_error: 15.1687 - mean_squared_error: 58505.7852 - coeff_determination: 0.6295 - val_loss: 16.6637 - val_mean_absolute_error: 13.2335 - val_mean_squared_error: 66768.6719 - val_coeff_determination: 0.6037
#
# Epoch 00084: val_loss did not improve from 16.47486
# Epoch 85/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.5468 - mean_absolute_error: 15.1660 - mean_squared_error: 58219.0234 - coeff_determination: 0.6347 - val_loss: 17.1056 - val_mean_absolute_error: 13.6976 - val_mean_squared_error: 67491.9688 - val_coeff_determination: 0.5996
#
# Epoch 00085: val_loss did not improve from 16.47486
# Epoch 86/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7166 - mean_absolute_error: 15.2926 - mean_squared_error: 58568.9727 - coeff_determination: 0.6249 - val_loss: 16.6285 - val_mean_absolute_error: 13.1486 - val_mean_squared_error: 64246.7188 - val_coeff_determination: 0.6196
#
# Epoch 00086: val_loss did not improve from 16.47486
# Epoch 87/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.6487 - mean_absolute_error: 15.2290 - mean_squared_error: 58418.8789 - coeff_determination: 0.6297 - val_loss: 16.4383 - val_mean_absolute_error: 12.9947 - val_mean_squared_error: 65612.5391 - val_coeff_determination: 0.6111
#
# Epoch 00087: val_loss improved from 16.47486 to 16.43832, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 88/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.6521 - mean_absolute_error: 15.2379 - mean_squared_error: 58490.4023 - coeff_determination: 0.6326 - val_loss: 17.0654 - val_mean_absolute_error: 13.5977 - val_mean_squared_error: 69124.9844 - val_coeff_determination: 0.5848
#
# Epoch 00088: val_loss did not improve from 16.43832
# Epoch 89/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.9447 - mean_absolute_error: 15.4667 - mean_squared_error: 59207.1094 - coeff_determination: 0.6253 - val_loss: 16.8438 - val_mean_absolute_error: 13.3050 - val_mean_squared_error: 65043.1406 - val_coeff_determination: 0.6129
#
# Epoch 00089: val_loss did not improve from 16.43832
# Epoch 90/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.7724 - mean_absolute_error: 15.3057 - mean_squared_error: 58163.5977 - coeff_determination: 0.6276 - val_loss: 16.1835 - val_mean_absolute_error: 12.7310 - val_mean_squared_error: 64576.1016 - val_coeff_determination: 0.6181
#
# Epoch 00090: val_loss improved from 16.43832 to 16.18348, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 91/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.7522 - mean_absolute_error: 15.3111 - mean_squared_error: 58463.7812 - coeff_determination: 0.6266 - val_loss: 16.7264 - val_mean_absolute_error: 13.2634 - val_mean_squared_error: 65495.5508 - val_coeff_determination: 0.6099
#
# Epoch 00091: val_loss did not improve from 16.18348
# Epoch 92/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.7305 - mean_absolute_error: 15.2860 - mean_squared_error: 58604.1992 - coeff_determination: 0.6341 - val_loss: 16.5133 - val_mean_absolute_error: 13.0339 - val_mean_squared_error: 65803.7578 - val_coeff_determination: 0.6091
#
# Epoch 00092: val_loss did not improve from 16.18348
# Epoch 93/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.6149 - mean_absolute_error: 15.1655 - mean_squared_error: 58351.5234 - coeff_determination: 0.6338 - val_loss: 16.3812 - val_mean_absolute_error: 12.9028 - val_mean_squared_error: 69225.8906 - val_coeff_determination: 0.5888
#
# Epoch 00093: val_loss did not improve from 16.18348
# Epoch 94/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.6681 - mean_absolute_error: 15.2590 - mean_squared_error: 59981.6094 - coeff_determination: 0.6243 - val_loss: 17.7062 - val_mean_absolute_error: 14.2798 - val_mean_squared_error: 66589.0156 - val_coeff_determination: 0.6075
#
# Epoch 00094: val_loss did not improve from 16.18348
# Epoch 95/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.5350 - mean_absolute_error: 15.1296 - mean_squared_error: 58975.1680 - coeff_determination: 0.6372 - val_loss: 16.1818 - val_mean_absolute_error: 12.7546 - val_mean_squared_error: 65175.2109 - val_coeff_determination: 0.6151
#
# Epoch 00095: val_loss improved from 16.18348 to 16.18182, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 96/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.5361 - mean_absolute_error: 15.1286 - mean_squared_error: 58303.3242 - coeff_determination: 0.6340 - val_loss: 16.5678 - val_mean_absolute_error: 13.1501 - val_mean_squared_error: 66289.1016 - val_coeff_determination: 0.6051
#
# Epoch 00096: val_loss did not improve from 16.18182
# Epoch 97/1000
# 254417/254417 [==============================] - 18s 71us/step - loss: 18.5323 - mean_absolute_error: 15.1189 - mean_squared_error: 58307.1562 - coeff_determination: 0.6370 - val_loss: 16.9322 - val_mean_absolute_error: 13.4722 - val_mean_squared_error: 66243.5469 - val_coeff_determination: 0.6066
#
# Epoch 00097: val_loss did not improve from 16.18182
# Epoch 98/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7242 - mean_absolute_error: 15.3057 - mean_squared_error: 58698.8789 - coeff_determination: 0.6333 - val_loss: 16.4440 - val_mean_absolute_error: 12.9884 - val_mean_squared_error: 65853.4922 - val_coeff_determination: 0.6077
#
# Epoch 00098: val_loss did not improve from 16.18182
# Epoch 99/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.5073 - mean_absolute_error: 15.0920 - mean_squared_error: 57969.6367 - coeff_determination: 0.6331 - val_loss: 16.1598 - val_mean_absolute_error: 12.7040 - val_mean_squared_error: 64816.5430 - val_coeff_determination: 0.6195
#
# Epoch 00099: val_loss improved from 16.18182 to 16.15977, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 100/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.6602 - mean_absolute_error: 15.2327 - mean_squared_error: 58185.4023 - coeff_determination: 0.6353 - val_loss: 16.8467 - val_mean_absolute_error: 13.3861 - val_mean_squared_error: 66066.8984 - val_coeff_determination: 0.6081
#
# Epoch 00100: val_loss did not improve from 16.15977
# Epoch 101/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.4912 - mean_absolute_error: 15.0531 - mean_squared_error: 57232.7227 - coeff_determination: 0.6350 - val_loss: 16.4580 - val_mean_absolute_error: 13.0260 - val_mean_squared_error: 66253.9609 - val_coeff_determination: 0.6052
#
# Epoch 00101: val_loss did not improve from 16.15977
# Epoch 102/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.7661 - mean_absolute_error: 15.3185 - mean_squared_error: 58262.0234 - coeff_determination: 0.6343 - val_loss: 16.7433 - val_mean_absolute_error: 13.2982 - val_mean_squared_error: 65002.7773 - val_coeff_determination: 0.6162
#
# Epoch 00102: val_loss did not improve from 16.15977
# Epoch 103/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.4855 - mean_absolute_error: 15.0745 - mean_squared_error: 57777.3906 - coeff_determination: 0.6374 - val_loss: 16.6002 - val_mean_absolute_error: 13.1900 - val_mean_squared_error: 64646.8320 - val_coeff_determination: 0.6197
#
# Epoch 00103: val_loss did not improve from 16.15977
# Epoch 104/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.4600 - mean_absolute_error: 15.0623 - mean_squared_error: 57602.4102 - coeff_determination: 0.6373 - val_loss: 16.7700 - val_mean_absolute_error: 13.3504 - val_mean_squared_error: 66001.2188 - val_coeff_determination: 0.6083
#
# Epoch 00104: val_loss did not improve from 16.15977
# Epoch 105/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.5763 - mean_absolute_error: 15.1579 - mean_squared_error: 57856.2695 - coeff_determination: 0.6318 - val_loss: 16.4063 - val_mean_absolute_error: 12.9416 - val_mean_squared_error: 64293.2852 - val_coeff_determination: 0.6204
#
# Epoch 00105: val_loss did not improve from 16.15977
# Epoch 106/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.5743 - mean_absolute_error: 15.1610 - mean_squared_error: 57482.6523 - coeff_determination: 0.6379 - val_loss: 16.9065 - val_mean_absolute_error: 13.4807 - val_mean_squared_error: 65539.6328 - val_coeff_determination: 0.6123
#
# Epoch 00106: val_loss did not improve from 16.15977
# Epoch 107/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.5676 - mean_absolute_error: 15.1799 - mean_squared_error: 57751.1328 - coeff_determination: 0.6328 - val_loss: 17.1298 - val_mean_absolute_error: 13.7301 - val_mean_squared_error: 65527.1445 - val_coeff_determination: 0.6131
#
# Epoch 00107: val_loss did not improve from 16.15977
# Epoch 108/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.3874 - mean_absolute_error: 15.0210 - mean_squared_error: 57434.6719 - coeff_determination: 0.6341 - val_loss: 16.1940 - val_mean_absolute_error: 12.7843 - val_mean_squared_error: 63454.3945 - val_coeff_determination: 0.6255
#
# Epoch 00108: val_loss did not improve from 16.15977
# Epoch 109/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.4214 - mean_absolute_error: 15.0523 - mean_squared_error: 57898.0391 - coeff_determination: 0.6363 - val_loss: 16.4003 - val_mean_absolute_error: 13.0318 - val_mean_squared_error: 66682.7344 - val_coeff_determination: 0.6034
#
# Epoch 00109: val_loss did not improve from 16.15977
# Epoch 110/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.3629 - mean_absolute_error: 15.0044 - mean_squared_error: 58076.3125 - coeff_determination: 0.6354 - val_loss: 16.2870 - val_mean_absolute_error: 12.9097 - val_mean_squared_error: 65080.8359 - val_coeff_determination: 0.6138
#
# Epoch 00110: val_loss did not improve from 16.15977
# Epoch 111/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.3516 - mean_absolute_error: 14.9726 - mean_squared_error: 57007.6680 - coeff_determination: 0.6431 - val_loss: 16.0750 - val_mean_absolute_error: 12.7071 - val_mean_squared_error: 63865.1016 - val_coeff_determination: 0.6197
#
# Epoch 00111: val_loss improved from 16.15977 to 16.07498, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_dnn_full.model
# Epoch 112/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.3194 - mean_absolute_error: 14.9547 - mean_squared_error: 56915.8086 - coeff_determination: 0.6383 - val_loss: 16.2196 - val_mean_absolute_error: 12.8278 - val_mean_squared_error: 63045.0742 - val_coeff_determination: 0.6274
#
# Epoch 00112: val_loss did not improve from 16.07498
# Epoch 113/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.4617 - mean_absolute_error: 15.0679 - mean_squared_error: 57258.1484 - coeff_determination: 0.6393 - val_loss: 16.2900 - val_mean_absolute_error: 12.8699 - val_mean_squared_error: 63829.5938 - val_coeff_determination: 0.6253
#
# Epoch 00113: val_loss did not improve from 16.07498
# Epoch 114/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 18.5805 - mean_absolute_error: 15.1759 - mean_squared_error: 57524.3945 - coeff_determination: 0.6388 - val_loss: 16.2437 - val_mean_absolute_error: 12.8123 - val_mean_squared_error: 65765.3516 - val_coeff_determination: 0.6080
#
# Epoch 00114: val_loss did not improve from 16.07498
# Epoch 115/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 18.4328 - mean_absolute_error: 15.0607 - mean_squared_error: 57435.8672 - coeff_determination: 0.6361 - val_loss: 16.5175 - val_mean_absolute_error: 13.1306 - val_mean_squared_error: 64477.5781 - val_coeff_determination: 0.6191
#
# Epoch 00115: val_loss did not improve from 16.07498
# Epoch 116/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 18.4700 - mean_absolute_error: 15.0684 - mean_squared_error: 57329.4609 - coeff_determination: 0.6365 - val_loss: 16.8388 - val_mean_absolute_error: 13.3912 - val_mean_squared_error: 64412.5586 - val_coeff_determination: 0.6181
#
# Epoch 00116: val_loss did not improve from 16.07498
# Epoch 117/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 18.5168 - mean_absolute_error: 15.1044 - mean_squared_error: 57411.6602 - coeff_determination: 0.6398 - val_loss: 16.5135 - val_mean_absolute_error: 13.0520 - val_mean_squared_error: 64533.1484 - val_coeff_determination: 0.6155
#
# Epoch 00117: val_loss did not improve from 16.07498
# ...
#
# Epoch 00543: val_loss did not improve from 9.84904
# Epoch 544/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8500 - mean_absolute_error: 10.9373 - mean_squared_error: 43198.4102 - coeff_determination: 0.7310 - val_loss: 10.0236 - val_mean_absolute_error: 9.0745 - val_mean_squared_error: 50408.3633 - val_coeff_determination: 0.7008
#
# Epoch 00544: val_loss did not improve from 9.84904
# Epoch 545/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.6370 - mean_absolute_error: 10.7238 - mean_squared_error: 42782.7383 - coeff_determination: 0.7286 - val_loss: 9.9280 - val_mean_absolute_error: 8.9669 - val_mean_squared_error: 50124.7891 - val_coeff_determination: 0.7033
#
# Epoch 00545: val_loss did not improve from 9.84904
# Epoch 546/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8007 - mean_absolute_error: 10.8885 - mean_squared_error: 43036.5664 - coeff_determination: 0.7305 - val_loss: 10.0777 - val_mean_absolute_error: 9.1263 - val_mean_squared_error: 50319.9688 - val_coeff_determination: 0.7021
#
# Epoch 00546: val_loss did not improve from 9.84904
# Epoch 547/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7403 - mean_absolute_error: 10.8279 - mean_squared_error: 42573.2695 - coeff_determination: 0.7327 - val_loss: 10.1438 - val_mean_absolute_error: 9.1897 - val_mean_squared_error: 50313.5039 - val_coeff_determination: 0.7022
#
# Epoch 00547: val_loss did not improve from 9.84904
# Epoch 548/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7915 - mean_absolute_error: 10.8792 - mean_squared_error: 42562.3516 - coeff_determination: 0.7330 - val_loss: 9.9453 - val_mean_absolute_error: 8.9989 - val_mean_squared_error: 50296.1250 - val_coeff_determination: 0.7019
#
# Epoch 00548: val_loss did not improve from 9.84904
# Epoch 549/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7100 - mean_absolute_error: 10.7974 - mean_squared_error: 42749.9102 - coeff_determination: 0.7327 - val_loss: 10.0789 - val_mean_absolute_error: 9.1357 - val_mean_squared_error: 50337.2500 - val_coeff_determination: 0.7020
#
# Epoch 00549: val_loss did not improve from 9.84904
# Epoch 550/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8017 - mean_absolute_error: 10.8897 - mean_squared_error: 42717.6523 - coeff_determination: 0.7312 - val_loss: 9.9237 - val_mean_absolute_error: 8.9812 - val_mean_squared_error: 50196.5117 - val_coeff_determination: 0.7027
#
# Epoch 00550: val_loss did not improve from 9.84904
# Epoch 551/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8202 - mean_absolute_error: 10.9079 - mean_squared_error: 42816.0508 - coeff_determination: 0.7301 - val_loss: 9.9329 - val_mean_absolute_error: 8.9848 - val_mean_squared_error: 50989.3281 - val_coeff_determination: 0.6967
#
# Epoch 00551: val_loss did not improve from 9.84904
# Epoch 552/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7215 - mean_absolute_error: 10.8090 - mean_squared_error: 42754.8867 - coeff_determination: 0.7301 - val_loss: 10.0156 - val_mean_absolute_error: 9.0602 - val_mean_squared_error: 50266.1992 - val_coeff_determination: 0.7021
#
# Epoch 00552: val_loss did not improve from 9.84904
# Epoch 553/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7559 - mean_absolute_error: 10.8438 - mean_squared_error: 42846.3867 - coeff_determination: 0.7308 - val_loss: 10.0273 - val_mean_absolute_error: 9.0785 - val_mean_squared_error: 50388.9922 - val_coeff_determination: 0.7012
#
# Epoch 00553: val_loss did not improve from 9.84904
# Epoch 554/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.8270 - mean_absolute_error: 10.9150 - mean_squared_error: 43279.9844 - coeff_determination: 0.7278 - val_loss: 10.0604 - val_mean_absolute_error: 9.1199 - val_mean_squared_error: 50542.8320 - val_coeff_determination: 0.7003
#
# Epoch 00554: val_loss did not improve from 9.84904
# Epoch 555/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.8047 - mean_absolute_error: 10.8931 - mean_squared_error: 42925.9688 - coeff_determination: 0.7320 - val_loss: 9.8652 - val_mean_absolute_error: 8.9044 - val_mean_squared_error: 50468.8906 - val_coeff_determination: 0.7007
#
# Epoch 00555: val_loss did not improve from 9.84904
# Epoch 556/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7121 - mean_absolute_error: 10.7999 - mean_squared_error: 42795.4258 - coeff_determination: 0.7313 - val_loss: 10.0633 - val_mean_absolute_error: 9.1133 - val_mean_squared_error: 50467.2461 - val_coeff_determination: 0.7008
#
# Epoch 00556: val_loss did not improve from 9.84904
# Epoch 557/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8095 - mean_absolute_error: 10.8976 - mean_squared_error: 42949.4609 - coeff_determination: 0.7251 - val_loss: 10.0238 - val_mean_absolute_error: 9.0749 - val_mean_squared_error: 50557.3945 - val_coeff_determination: 0.7003
#
# Epoch 00557: val_loss did not improve from 9.84904
# Epoch 558/1000
# 254417/254417 [==============================] - 18s 69us/step - loss: 11.8074 - mean_absolute_error: 10.8953 - mean_squared_error: 42843.8164 - coeff_determination: 0.7313 - val_loss: 9.9882 - val_mean_absolute_error: 9.0424 - val_mean_squared_error: 50468.4688 - val_coeff_determination: 0.7006
#
# Epoch 00558: val_loss did not improve from 9.84904
# Epoch 559/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7073 - mean_absolute_error: 10.7953 - mean_squared_error: 42735.4453 - coeff_determination: 0.7337 - val_loss: 10.1355 - val_mean_absolute_error: 9.1997 - val_mean_squared_error: 50241.9141 - val_coeff_determination: 0.7023
#
# Epoch 00559: val_loss did not improve from 9.84904
# Epoch 560/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7557 - mean_absolute_error: 10.8439 - mean_squared_error: 42959.0156 - coeff_determination: 0.7297 - val_loss: 9.9980 - val_mean_absolute_error: 9.0437 - val_mean_squared_error: 50440.9922 - val_coeff_determination: 0.7008
#
# Epoch 00560: val_loss did not improve from 9.84904
# Epoch 561/1000
# 254417/254417 [==============================] - 17s 69us/step - loss: 11.6140 - mean_absolute_error: 10.7018 - mean_squared_error: 42722.8984 - coeff_determination: 0.7301 - val_loss: 9.9174 - val_mean_absolute_error: 8.9666 - val_mean_squared_error: 50143.8281 - val_coeff_determination: 0.7032
#
# Epoch 00561: val_loss did not improve from 9.84904
# Epoch 562/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7605 - mean_absolute_error: 10.8490 - mean_squared_error: 43316.0312 - coeff_determination: 0.7258 - val_loss: 9.9740 - val_mean_absolute_error: 9.0208 - val_mean_squared_error: 50539.4766 - val_coeff_determination: 0.7004
#
# Epoch 00562: val_loss did not improve from 9.84904
# Epoch 563/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7168 - mean_absolute_error: 10.8053 - mean_squared_error: 42452.4414 - coeff_determination: 0.7300 - val_loss: 10.0327 - val_mean_absolute_error: 9.0814 - val_mean_squared_error: 50828.8672 - val_coeff_determination: 0.6981
#
# Epoch 00563: val_loss did not improve from 9.84904
# Epoch 564/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7004 - mean_absolute_error: 10.7891 - mean_squared_error: 42777.2812 - coeff_determination: 0.7278 - val_loss: 10.0710 - val_mean_absolute_error: 9.1279 - val_mean_squared_error: 51560.5156 - val_coeff_determination: 0.6930
#
# Epoch 00564: val_loss did not improve from 9.84904
# Epoch 565/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7170 - mean_absolute_error: 10.8055 - mean_squared_error: 42788.7109 - coeff_determination: 0.7320 - val_loss: 10.0079 - val_mean_absolute_error: 9.0537 - val_mean_squared_error: 50301.9805 - val_coeff_determination: 0.7022
#
# Epoch 00565: val_loss did not improve from 9.84904
# Epoch 566/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7691 - mean_absolute_error: 10.8584 - mean_squared_error: 42952.1094 - coeff_determination: 0.7255 - val_loss: 10.0386 - val_mean_absolute_error: 9.0817 - val_mean_squared_error: 50469.1133 - val_coeff_determination: 0.7010
#
# Epoch 00566: val_loss did not improve from 9.84904
# Epoch 567/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7947 - mean_absolute_error: 10.8840 - mean_squared_error: 42816.1445 - coeff_determination: 0.7348 - val_loss: 10.0391 - val_mean_absolute_error: 9.0840 - val_mean_squared_error: 50411.8516 - val_coeff_determination: 0.7012
#
# Epoch 00567: val_loss did not improve from 9.84904
# Epoch 568/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.6297 - mean_absolute_error: 10.7184 - mean_squared_error: 42868.2969 - coeff_determination: 0.7292 - val_loss: 10.0326 - val_mean_absolute_error: 9.0882 - val_mean_squared_error: 50655.9453 - val_coeff_determination: 0.6994
#
# Epoch 00568: val_loss did not improve from 9.84904
# Epoch 569/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8158 - mean_absolute_error: 10.9050 - mean_squared_error: 43334.0234 - coeff_determination: 0.7273 - val_loss: 9.9968 - val_mean_absolute_error: 9.0471 - val_mean_squared_error: 50533.4180 - val_coeff_determination: 0.7002
#
# Epoch 00569: val_loss did not improve from 9.84904
# Epoch 570/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8337 - mean_absolute_error: 10.9227 - mean_squared_error: 43236.9922 - coeff_determination: 0.7302 - val_loss: 10.0039 - val_mean_absolute_error: 9.0545 - val_mean_squared_error: 50626.5742 - val_coeff_determination: 0.6995
#
# Epoch 00570: val_loss did not improve from 9.84904
# Epoch 571/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8118 - mean_absolute_error: 10.9011 - mean_squared_error: 43231.2500 - coeff_determination: 0.7264 - val_loss: 10.0455 - val_mean_absolute_error: 9.0915 - val_mean_squared_error: 50662.6406 - val_coeff_determination: 0.6993
#
# Epoch 00571: val_loss did not improve from 9.84904
# Epoch 572/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7640 - mean_absolute_error: 10.8528 - mean_squared_error: 42789.6133 - coeff_determination: 0.7311 - val_loss: 10.0610 - val_mean_absolute_error: 9.1077 - val_mean_squared_error: 50402.7422 - val_coeff_determination: 0.7011
#
# Epoch 00572: val_loss did not improve from 9.84904
# Epoch 573/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7621 - mean_absolute_error: 10.8511 - mean_squared_error: 42846.0273 - coeff_determination: 0.7317 - val_loss: 9.9315 - val_mean_absolute_error: 8.9759 - val_mean_squared_error: 50324.1328 - val_coeff_determination: 0.7017
#
# Epoch 00573: val_loss did not improve from 9.84904
# Epoch 574/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7595 - mean_absolute_error: 10.8492 - mean_squared_error: 42679.7070 - coeff_determination: 0.7294 - val_loss: 10.0360 - val_mean_absolute_error: 9.0951 - val_mean_squared_error: 50086.1211 - val_coeff_determination: 0.7037
#
# Epoch 00574: val_loss did not improve from 9.84904
# Epoch 575/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7563 - mean_absolute_error: 10.8453 - mean_squared_error: 43046.8398 - coeff_determination: 0.7308 - val_loss: 10.0032 - val_mean_absolute_error: 9.0499 - val_mean_squared_error: 50179.0938 - val_coeff_determination: 0.7030
#
# Epoch 00575: val_loss did not improve from 9.84904
# Epoch 576/1000
# 254417/254417 [==============================] - 18s 70us/step - loss: 11.7977 - mean_absolute_error: 10.8876 - mean_squared_error: 42638.8672 - coeff_determination: 0.7293 - val_loss: 10.0535 - val_mean_absolute_error: 9.1093 - val_mean_squared_error: 50188.6797 - val_coeff_determination: 0.7026
#
# Epoch 00576: val_loss did not improve from 9.84904
# Epoch 577/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7649 - mean_absolute_error: 10.8553 - mean_squared_error: 42709.4961 - coeff_determination: 0.7298 - val_loss: 9.9275 - val_mean_absolute_error: 8.9812 - val_mean_squared_error: 50527.3398 - val_coeff_determination: 0.7000
#
# Epoch 00577: val_loss did not improve from 9.84904
# Epoch 578/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8018 - mean_absolute_error: 10.8912 - mean_squared_error: 42879.2695 - coeff_determination: 0.7312 - val_loss: 10.0450 - val_mean_absolute_error: 9.1079 - val_mean_squared_error: 50289.5938 - val_coeff_determination: 0.7019
#
# Epoch 00578: val_loss did not improve from 9.84904
# Epoch 579/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7328 - mean_absolute_error: 10.8227 - mean_squared_error: 42664.7344 - coeff_determination: 0.7310 - val_loss: 9.9720 - val_mean_absolute_error: 9.0283 - val_mean_squared_error: 50592.4336 - val_coeff_determination: 0.6994
#
# Epoch 00579: val_loss did not improve from 9.84904
# Epoch 580/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.6457 - mean_absolute_error: 10.7352 - mean_squared_error: 42953.0195 - coeff_determination: 0.7312 - val_loss: 9.9554 - val_mean_absolute_error: 9.0036 - val_mean_squared_error: 50751.6328 - val_coeff_determination: 0.6984
#
# Epoch 00580: val_loss did not improve from 9.84904
# Epoch 581/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.6573 - mean_absolute_error: 10.7468 - mean_squared_error: 42598.6484 - coeff_determination: 0.7354 - val_loss: 10.1021 - val_mean_absolute_error: 9.1579 - val_mean_squared_error: 50247.4922 - val_coeff_determination: 0.7022
#
# Epoch 00581: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
#
# Epoch 00581: val_loss did not improve from 9.84904
# Epoch 582/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.6629 - mean_absolute_error: 10.7523 - mean_squared_error: 42947.8945 - coeff_determination: 0.7307 - val_loss: 9.8824 - val_mean_absolute_error: 8.9248 - val_mean_squared_error: 50382.9414 - val_coeff_determination: 0.7011
#
# Epoch 00582: val_loss did not improve from 9.84904
# Epoch 583/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7606 - mean_absolute_error: 10.8502 - mean_squared_error: 42853.2266 - coeff_determination: 0.7258 - val_loss: 9.9769 - val_mean_absolute_error: 9.0250 - val_mean_squared_error: 50353.1172 - val_coeff_determination: 0.7015
#
# Epoch 00583: val_loss did not improve from 9.84904
# Epoch 584/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.8464 - mean_absolute_error: 10.9360 - mean_squared_error: 42958.9531 - coeff_determination: 0.7284 - val_loss: 10.0400 - val_mean_absolute_error: 9.0857 - val_mean_squared_error: 50935.4336 - val_coeff_determination: 0.6973
#
# Epoch 00584: val_loss did not improve from 9.84904
# Epoch 585/1000
# 254417/254417 [==============================] - 17s 68us/step - loss: 11.7318 - mean_absolute_error: 10.8217 - mean_squared_error: 42619.4531 - coeff_determination: 0.7290 - val_loss: 10.0259 - val_mean_absolute_error: 9.0706 - val_mean_squared_error: 50287.6328 - val_coeff_determination: 0.7022
#
# Epoch 00585: val_loss did not improve from 9.84904
# Epoch 586/1000
# 254417/254417 [==============================] - 17s 67us/step - loss: 11.7813 - mean_absolute_error: 10.8711 - mean_squared_error: 42923.0977 - coeff_determination: 0.7319 - val_loss: 9.9114 - val_mean_absolute_error: 8.9561 - val_mean_squared_error: 50432.1875 - val_coeff_determination: 0.7010
#
# Epoch 00586: val_loss did not improve from 9.84904
# Epoch 00586: early stopping

# %%
predict_y_dnn = model_dnn.predict(test_x)

# %% [markdown]
# # Red Neuronal Convolucional

# %% [markdown]
# ## Funciones

# %%
#Función convolucional
def convolutional(model, filtros = 256, kernel_x = 3,kernel_y = 3, 
                  stride = 1, activacion = 'relu', regularizador = l2(0.001), 
                  dropout = 0.2):

    #Capa convolucional
    model.add(Conv2D(filtros, kernel_size=(kernel_x, kernel_y),
                   activation=activacion,padding='same',
                   kernel_regularizer=regularizador,
                   bias_regularizer=regularizador))
    
    model.add(Dropout(dropout))

    return model

# %%
#Función de pooling
def pooling(model, pooling_x = 3, pooling_y = 3, stride = 1,
           dropout = 0.2):

    #Capa de polling
    model.add(MaxPooling2D((pooling_x, pooling_y)))

    model.add(Dropout(dropout))
    
    model.add(BatchNormalization())

    return model

# %%
def data_cnn(data):

  return data.reshape(len(data),len(data[0]),len(data[0][0]),1)

# %% [markdown]
# ## Modelo

# %%
def modelo_cnn():
    #Creación del modelo secuencial
    model = Sequential()
    
    function_act = 'relu'

    #Primera Capa convolucional
    
    model = input_layer(model, len(train_x[0]),len(train_x[0][0]),1)
    
    model = convolutional(model, 64, activacion = function_act)
    model = convolutional(model, 64, activacion = function_act)

    model = pooling(model, 2, 2, dropout = 0)

    model = convolutional(model, 128, activacion = function_act)
    model = convolutional(model, 128, activacion = function_act)

    model = pooling(model, 2, 2, dropout = 0)

    model = convolutional(model, 256, activacion = function_act)
    model = convolutional(model, 256, activacion = function_act)

    model = pooling(model, 2, 2, dropout = 0)

    model = convolutional(model, 512, activacion = function_act)
    model = convolutional(model, 512, activacion = function_act)

    model = pooling(model, 2, 2, dropout = 0)

    model = convolutional(model, 512, activacion = function_act)
    model = convolutional(model, 512, activacion = function_act)

    model = pooling(model, 2, 2, dropout = 0)

    model.add(Flatten())

    model = densa(model, 1024, activacion = function_act)
    model = densa(model, 1024, activacion = function_act)
    model = densa(model, 512, activacion = function_act)

    #Capa de salida
    model = result_layer(model, len(train_y[0]))

    return model

# %% [markdown]
# ## Ejecución

# %%
#Transformación para CNN
train_x_cnn = data_cnn(train_x)
validation_x_cnn = data_cnn(validation_x)
test_x_cnn = data_cnn(test_x)

# %%
model_cnn, history_cnn = run_desing(modelo_cnn(), 'modelo_cnn_full', 
                                    batch, epochs, 
                                    train_x_cnn, train_y, 
                                    validation_x_cnn, validation_y,
                                     'adam','huber_loss')
# Out:
# Model: "modelo_cnn_full"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_7 (Batch (None, 36, 37, 1)         4
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 36, 37, 64)        640
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 36, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 36, 37, 64)        36928
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 36, 37, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 18, 18, 64)        0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 18, 18, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 128)       73856
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 18, 18, 128)       147584
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 18, 18, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 9, 9, 128)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 9, 9, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 256)         295168
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 9, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 512)         2359808
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 512)         2359808
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 2, 2, 512)         2359808
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 1, 1, 512)         0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1, 1, 512)         2048
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 13)                6669
# =================================================================
# Total params: 11,526,353
# Trainable params: 11,518,287
# Non-trainable params: 8,066
# _________________________________________________________________
# Train on 254417 samples, validate on 63605 samples
# Epoch 1/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 45.8979 - mean_absolute_error: 44.8307 - mean_squared_error: 132059.5938 - coeff_determination: 0.0406 - val_loss: 51.3266 - val_mean_absolute_error: 50.6820 - val_mean_squared_error: 131543.2656 - val_coeff_determination: 0.1038
#
# Epoch 00001: val_loss improved from inf to 51.32664, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 2/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 41.5909 - mean_absolute_error: 40.5136 - mean_squared_error: 116937.0781 - coeff_determination: 0.1652 - val_loss: 44.5343 - val_mean_absolute_error: 43.1065 - val_mean_squared_error: 127537.2812 - val_coeff_determination: 0.1431
#
# Epoch 00002: val_loss improved from 51.32664 to 44.53434, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 3/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 39.3833 - mean_absolute_error: 37.6251 - mean_squared_error: 109473.0859 - coeff_determination: 0.2269 - val_loss: 43.6095 - val_mean_absolute_error: 41.5336 - val_mean_squared_error: 127722.7031 - val_coeff_determination: 0.1409
#
# Epoch 00003: val_loss improved from 44.53434 to 43.60954, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 4/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 37.7133 - mean_absolute_error: 35.3812 - mean_squared_error: 104304.3594 - coeff_determination: 0.2668 - val_loss: 39.8301 - val_mean_absolute_error: 37.2298 - val_mean_squared_error: 118048.7891 - val_coeff_determination: 0.2153
#
# Epoch 00004: val_loss improved from 43.60954 to 39.83013, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 5/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 36.4478 - mean_absolute_error: 33.6238 - mean_squared_error: 100866.1797 - coeff_determination: 0.2961 - val_loss: 41.1996 - val_mean_absolute_error: 38.2011 - val_mean_squared_error: 115222.9297 - val_coeff_determination: 0.2389
#
# Epoch 00005: val_loss did not improve from 39.83013
# Epoch 6/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 35.6098 - mean_absolute_error: 32.4318 - mean_squared_error: 98347.7188 - coeff_determination: 0.3165 - val_loss: 41.5579 - val_mean_absolute_error: 38.1766 - val_mean_squared_error: 120630.1406 - val_coeff_determination: 0.1954
#
# Epoch 00006: val_loss did not improve from 39.83013
# Epoch 7/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 34.9145 - mean_absolute_error: 31.4145 - mean_squared_error: 96360.3047 - coeff_determination: 0.3302 - val_loss: 40.3847 - val_mean_absolute_error: 36.6739 - val_mean_squared_error: 118423.2266 - val_coeff_determination: 0.2140
#
# Epoch 00007: val_loss did not improve from 39.83013
# Epoch 8/1000
# 254417/254417 [==============================] - 98s 385us/step - loss: 34.3668 - mean_absolute_error: 30.5300 - mean_squared_error: 94699.3594 - coeff_determination: 0.3477 - val_loss: 41.2051 - val_mean_absolute_error: 37.2579 - val_mean_squared_error: 117771.2266 - val_coeff_determination: 0.2175
#
# Epoch 00008: val_loss did not improve from 39.83013
# Epoch 9/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 33.9929 - mean_absolute_error: 29.8828 - mean_squared_error: 93170.1016 - coeff_determination: 0.3569 - val_loss: 40.3008 - val_mean_absolute_error: 36.0093 - val_mean_squared_error: 109841.2109 - val_coeff_determination: 0.2798
#
# Epoch 00009: val_loss did not improve from 39.83013
# Epoch 10/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 33.6888 - mean_absolute_error: 29.3140 - mean_squared_error: 91757.1641 - coeff_determination: 0.3683 - val_loss: 36.5670 - val_mean_absolute_error: 32.0913 - val_mean_squared_error: 104699.8047 - val_coeff_determination: 0.3176
#
# Epoch 00010: val_loss improved from 39.83013 to 36.56697, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 11/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 33.3413 - mean_absolute_error: 28.7923 - mean_squared_error: 90338.5312 - coeff_determination: 0.3820 - val_loss: 38.1852 - val_mean_absolute_error: 33.5465 - val_mean_squared_error: 108905.8984 - val_coeff_determination: 0.2869
#
# Epoch 00011: val_loss did not improve from 36.56697
# Epoch 12/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 33.1333 - mean_absolute_error: 28.4083 - mean_squared_error: 89604.8828 - coeff_determination: 0.3885 - val_loss: 40.3087 - val_mean_absolute_error: 35.5167 - val_mean_squared_error: 113042.1328 - val_coeff_determination: 0.2521
#
# Epoch 00012: val_loss did not improve from 36.56697
# Epoch 13/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 32.9959 - mean_absolute_error: 28.1359 - mean_squared_error: 89025.7969 - coeff_determination: 0.3929 - val_loss: 33.9136 - val_mean_absolute_error: 28.9906 - val_mean_squared_error: 97708.2578 - val_coeff_determination: 0.3712
#
# Epoch 00013: val_loss improved from 36.56697 to 33.91358, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 14/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.7849 - mean_absolute_error: 27.8483 - mean_squared_error: 88479.0703 - coeff_determination: 0.3972 - val_loss: 39.8844 - val_mean_absolute_error: 34.9104 - val_mean_squared_error: 112408.4922 - val_coeff_determination: 0.2577
#
# Epoch 00014: val_loss did not improve from 33.91358
# Epoch 15/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.6625 - mean_absolute_error: 27.6779 - mean_squared_error: 88004.1328 - coeff_determination: 0.4004 - val_loss: 41.1515 - val_mean_absolute_error: 36.0699 - val_mean_squared_error: 114363.9219 - val_coeff_determination: 0.2440
#
# Epoch 00015: val_loss did not improve from 33.91358
# Epoch 16/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.5820 - mean_absolute_error: 27.4754 - mean_squared_error: 87347.3359 - coeff_determination: 0.4042 - val_loss: 41.1426 - val_mean_absolute_error: 35.9837 - val_mean_squared_error: 111740.3750 - val_coeff_determination: 0.2638
#
# Epoch 00016: val_loss did not improve from 33.91358
# Epoch 17/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 32.4776 - mean_absolute_error: 27.2910 - mean_squared_error: 87133.0703 - coeff_determination: 0.4073 - val_loss: 40.9885 - val_mean_absolute_error: 35.8210 - val_mean_squared_error: 113779.4375 - val_coeff_determination: 0.2485
#
# Epoch 00017: val_loss did not improve from 33.91358
# Epoch 18/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.3034 - mean_absolute_error: 27.0821 - mean_squared_error: 86806.1641 - coeff_determination: 0.4078 - val_loss: 38.2104 - val_mean_absolute_error: 32.9044 - val_mean_squared_error: 105182.9062 - val_coeff_determination: 0.3159
#
# Epoch 00018: val_loss did not improve from 33.91358
# Epoch 19/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.4158 - mean_absolute_error: 27.0760 - mean_squared_error: 86964.2812 - coeff_determination: 0.4060 - val_loss: 38.0442 - val_mean_absolute_error: 32.7071 - val_mean_squared_error: 108008.5859 - val_coeff_determination: 0.2937
#
# Epoch 00019: val_loss did not improve from 33.91358
# Epoch 20/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 32.2596 - mean_absolute_error: 26.9107 - mean_squared_error: 86700.2266 - coeff_determination: 0.4044 - val_loss: 33.6322 - val_mean_absolute_error: 28.2137 - val_mean_squared_error: 98037.2891 - val_coeff_determination: 0.3708
#
# Epoch 00020: val_loss improved from 33.91358 to 33.63224, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 21/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.3059 - mean_absolute_error: 26.8444 - mean_squared_error: 86150.0781 - coeff_determination: 0.4129 - val_loss: 37.3037 - val_mean_absolute_error: 31.8492 - val_mean_squared_error: 99657.7891 - val_coeff_determination: 0.3566
#
# Epoch 00021: val_loss did not improve from 33.63224
# Epoch 22/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 32.2225 - mean_absolute_error: 26.6881 - mean_squared_error: 85805.2109 - coeff_determination: 0.4173 - val_loss: 35.3987 - val_mean_absolute_error: 29.7946 - val_mean_squared_error: 97986.7969 - val_coeff_determination: 0.3680
#
# Epoch 00022: val_loss did not improve from 33.63224
# Epoch 23/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.2346 - mean_absolute_error: 26.6454 - mean_squared_error: 86053.0469 - coeff_determination: 0.4130 - val_loss: 39.1730 - val_mean_absolute_error: 33.5988 - val_mean_squared_error: 104452.6328 - val_coeff_determination: 0.3196
#
# Epoch 00023: val_loss did not improve from 33.63224
# Epoch 24/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.0332 - mean_absolute_error: 26.4346 - mean_squared_error: 85765.0156 - coeff_determination: 0.4116 - val_loss: 39.4401 - val_mean_absolute_error: 33.8402 - val_mean_squared_error: 103172.6797 - val_coeff_determination: 0.3301
#
# Epoch 00024: val_loss did not improve from 33.63224
# Epoch 25/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.0854 - mean_absolute_error: 26.4847 - mean_squared_error: 85876.8750 - coeff_determination: 0.4179 - val_loss: 45.2296 - val_mean_absolute_error: 39.5709 - val_mean_squared_error: 118992.5781 - val_coeff_determination: 0.2073
#
# Epoch 00025: val_loss did not improve from 33.63224
# Epoch 26/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 32.0499 - mean_absolute_error: 26.3700 - mean_squared_error: 85695.8125 - coeff_determination: 0.4198 - val_loss: 33.0120 - val_mean_absolute_error: 27.3617 - val_mean_squared_error: 95233.3203 - val_coeff_determination: 0.3923
#
# Epoch 00026: val_loss improved from 33.63224 to 33.01198, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_cnn_full.model
# Epoch 27/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.0795 - mean_absolute_error: 26.3994 - mean_squared_error: 85657.0781 - coeff_determination: 0.4206 - val_loss: 40.0343 - val_mean_absolute_error: 34.3118 - val_mean_squared_error: 101086.4688 - val_coeff_determination: 0.3436
#
# Epoch 00027: val_loss did not improve from 33.01198
# Epoch 28/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.0369 - mean_absolute_error: 26.2898 - mean_squared_error: 85458.2578 - coeff_determination: 0.4192 - val_loss: 37.5923 - val_mean_absolute_error: 31.8249 - val_mean_squared_error: 96983.8594 - val_coeff_determination: 0.3754
#
# Epoch 00028: val_loss did not improve from 33.01198
# Epoch 29/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.0740 - mean_absolute_error: 26.2805 - mean_squared_error: 85231.4062 - coeff_determination: 0.4175 - val_loss: 39.1362 - val_mean_absolute_error: 33.2683 - val_mean_squared_error: 101452.2656 - val_coeff_determination: 0.3409
#
# Epoch 00029: val_loss did not improve from 33.01198
# Epoch 30/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.0414 - mean_absolute_error: 26.2247 - mean_squared_error: 85018.4844 - coeff_determination: 0.4251 - val_loss: 34.3449 - val_mean_absolute_error: 28.5253 - val_mean_squared_error: 95687.9922 - val_coeff_determination: 0.3872
#
# Epoch 00030: val_loss did not improve from 33.01198
# Epoch 31/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.0021 - mean_absolute_error: 26.1833 - mean_squared_error: 85191.9375 - coeff_determination: 0.4193 - val_loss: 39.7255 - val_mean_absolute_error: 33.8410 - val_mean_squared_error: 101655.6094 - val_coeff_determination: 0.3400
#
# Epoch 00031: val_loss did not improve from 33.01198
# Epoch 32/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 32.1333 - mean_absolute_error: 26.2313 - mean_squared_error: 84986.8438 - coeff_determination: 0.4208 - val_loss: 39.9732 - val_mean_absolute_error: 34.0039 - val_mean_squared_error: 103286.9531 - val_coeff_determination: 0.3291
#
# Epoch 00032: val_loss did not improve from 33.01198
# Epoch 33/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.0689 - mean_absolute_error: 26.1080 - mean_squared_error: 85032.6484 - coeff_determination: 0.4200 - val_loss: 42.7136 - val_mean_absolute_error: 36.7474 - val_mean_squared_error: 101443.8984 - val_coeff_determination: 0.3415
#
# Epoch 00033: val_loss did not improve from 33.01198
# Epoch 34/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.9697 - mean_absolute_error: 26.0130 - mean_squared_error: 84886.7422 - coeff_determination: 0.4214 - val_loss: 43.1797 - val_mean_absolute_error: 37.2503 - val_mean_squared_error: 100994.5781 - val_coeff_determination: 0.3443
#
# Epoch 00034: val_loss did not improve from 33.01198
# Epoch 35/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.9325 - mean_absolute_error: 25.9940 - mean_squared_error: 85018.8281 - coeff_determination: 0.4224 - val_loss: 43.0865 - val_mean_absolute_error: 37.1667 - val_mean_squared_error: 106358.2500 - val_coeff_determination: 0.3030
#
# Epoch 00035: val_loss did not improve from 33.01198
# Epoch 36/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.9138 - mean_absolute_error: 26.0097 - mean_squared_error: 84916.5312 - coeff_determination: 0.4229 - val_loss: 39.0256 - val_mean_absolute_error: 33.1271 - val_mean_squared_error: 98883.2500 - val_coeff_determination: 0.3637
#
# Epoch 00036: val_loss did not improve from 33.01198
# Epoch 37/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.8696 - mean_absolute_error: 25.9357 - mean_squared_error: 84599.8359 - coeff_determination: 0.4253 - val_loss: 43.0137 - val_mean_absolute_error: 37.0266 - val_mean_squared_error: 103039.6406 - val_coeff_determination: 0.3291
#
# Epoch 00037: val_loss did not improve from 33.01198
# Epoch 38/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.9596 - mean_absolute_error: 25.9655 - mean_squared_error: 84654.9688 - coeff_determination: 0.4293 - val_loss: 36.5609 - val_mean_absolute_error: 30.5400 - val_mean_squared_error: 96225.9531 - val_coeff_determination: 0.3818
#
# Epoch 00038: val_loss did not improve from 33.01198
# Epoch 39/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.9466 - mean_absolute_error: 25.8763 - mean_squared_error: 84620.9844 - coeff_determination: 0.4244 - val_loss: 41.4339 - val_mean_absolute_error: 35.3484 - val_mean_squared_error: 109492.1641 - val_coeff_determination: 0.2800
#
# Epoch 00039: val_loss did not improve from 33.01198
# Epoch 40/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.0361 - mean_absolute_error: 25.9162 - mean_squared_error: 84746.6172 - coeff_determination: 0.4253 - val_loss: 36.9265 - val_mean_absolute_error: 30.7317 - val_mean_squared_error: 96740.0703 - val_coeff_determination: 0.3775
#
# Epoch 00040: val_loss did not improve from 33.01198
# Epoch 41/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 32.1833 - mean_absolute_error: 25.9827 - mean_squared_error: 84809.7734 - coeff_determination: 0.4231 - val_loss: 39.0933 - val_mean_absolute_error: 32.9008 - val_mean_squared_error: 100237.6406 - val_coeff_determination: 0.3516
#
# Epoch 00041: val_loss did not improve from 33.01198
# Epoch 42/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 32.0620 - mean_absolute_error: 25.8658 - mean_squared_error: 84502.0625 - coeff_determination: 0.4258 - val_loss: 41.7099 - val_mean_absolute_error: 35.4550 - val_mean_squared_error: 102940.9844 - val_coeff_determination: 0.3291
#
# Epoch 00042: val_loss did not improve from 33.01198
# Epoch 43/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.1042 - mean_absolute_error: 25.8528 - mean_squared_error: 84610.6562 - coeff_determination: 0.4271 - val_loss: 38.2257 - val_mean_absolute_error: 32.0130 - val_mean_squared_error: 101778.8438 - val_coeff_determination: 0.3406
#
# Epoch 00043: val_loss did not improve from 33.01198
# Epoch 44/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.8883 - mean_absolute_error: 25.6880 - mean_squared_error: 84153.4297 - coeff_determination: 0.4263 - val_loss: 39.7958 - val_mean_absolute_error: 33.5326 - val_mean_squared_error: 100589.3594 - val_coeff_determination: 0.3476
#
# Epoch 00044: val_loss did not improve from 33.01198
# Epoch 45/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 32.2013 - mean_absolute_error: 25.8571 - mean_squared_error: 84080.3672 - coeff_determination: 0.4288 - val_loss: 46.3293 - val_mean_absolute_error: 39.9726 - val_mean_squared_error: 106108.8672 - val_coeff_determination: 0.3046
#
# Epoch 00045: val_loss did not improve from 33.01198
# Epoch 46/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.1122 - mean_absolute_error: 25.7678 - mean_squared_error: 84127.8516 - coeff_determination: 0.4279 - val_loss: 38.2532 - val_mean_absolute_error: 31.9008 - val_mean_squared_error: 101147.2109 - val_coeff_determination: 0.3441
#
# Epoch 00046: val_loss did not improve from 33.01198
# Epoch 47/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 31.9622 - mean_absolute_error: 25.6605 - mean_squared_error: 84166.7422 - coeff_determination: 0.4296 - val_loss: 38.9635 - val_mean_absolute_error: 32.5967 - val_mean_squared_error: 104018.4453 - val_coeff_determination: 0.3229
#
# Epoch 00047: val_loss did not improve from 33.01198
# Epoch 48/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 31.9999 - mean_absolute_error: 25.6696 - mean_squared_error: 84140.7969 - coeff_determination: 0.4299 - val_loss: 41.5565 - val_mean_absolute_error: 35.3077 - val_mean_squared_error: 103532.3672 - val_coeff_determination: 0.3269
#
# Epoch 00048: val_loss did not improve from 33.01198
# Epoch 49/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.9296 - mean_absolute_error: 25.6285 - mean_squared_error: 84175.3672 - coeff_determination: 0.4294 - val_loss: 38.0105 - val_mean_absolute_error: 31.6572 - val_mean_squared_error: 98067.6719 - val_coeff_determination: 0.3678
#
# Epoch 00049: val_loss did not improve from 33.01198
# Epoch 50/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.8988 - mean_absolute_error: 25.5896 - mean_squared_error: 83814.4688 - coeff_determination: 0.4322 - val_loss: 36.3780 - val_mean_absolute_error: 30.0680 - val_mean_squared_error: 96254.3125 - val_coeff_determination: 0.3805
#
# Epoch 00050: val_loss did not improve from 33.01198
# Epoch 51/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 31.7918 - mean_absolute_error: 25.5420 - mean_squared_error: 84020.3047 - coeff_determination: 0.4308 - val_loss: 43.9577 - val_mean_absolute_error: 37.7440 - val_mean_squared_error: 99156.7500 - val_coeff_determination: 0.3586
#
# Epoch 00051: val_loss did not improve from 33.01198
# Epoch 52/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.7814 - mean_absolute_error: 25.5897 - mean_squared_error: 83945.7656 - coeff_determination: 0.4302 - val_loss: 36.5870 - val_mean_absolute_error: 30.3884 - val_mean_squared_error: 99004.2891 - val_coeff_determination: 0.3627
#
# Epoch 00052: val_loss did not improve from 33.01198
# Epoch 53/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 31.8825 - mean_absolute_error: 25.6434 - mean_squared_error: 84178.8984 - coeff_determination: 0.4255 - val_loss: 40.5759 - val_mean_absolute_error: 34.3070 - val_mean_squared_error: 98624.3906 - val_coeff_determination: 0.3632
#
# Epoch 00053: val_loss did not improve from 33.01198
# Epoch 54/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 32.0406 - mean_absolute_error: 25.7396 - mean_squared_error: 84516.9844 - coeff_determination: 0.4285 - val_loss: 38.5163 - val_mean_absolute_error: 32.1874 - val_mean_squared_error: 98601.9375 - val_coeff_determination: 0.3629
#
# Epoch 00054: val_loss did not improve from 33.01198
# Epoch 55/1000
# 254417/254417 [==============================] - 97s 382us/step - loss: 31.8910 - mean_absolute_error: 25.5408 - mean_squared_error: 83940.5547 - coeff_determination: 0.4309 - val_loss: 35.7004 - val_mean_absolute_error: 29.4004 - val_mean_squared_error: 97375.0859 - val_coeff_determination: 0.3727
#
# Epoch 00055: val_loss did not improve from 33.01198
# Epoch 56/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 31.7186 - mean_absolute_error: 25.4733 - mean_squared_error: 83821.0625 - coeff_determination: 0.4313 - val_loss: 36.5965 - val_mean_absolute_error: 30.2879 - val_mean_squared_error: 98965.3594 - val_coeff_determination: 0.3626
#
# Epoch 00056: val_loss did not improve from 33.01198
# Epoch 57/1000
# 254417/254417 [==============================] - 97s 383us/step - loss: 32.0627 - mean_absolute_error: 25.6525 - mean_squared_error: 84000.3594 - coeff_determination: 0.4289 - val_loss: 40.0600 - val_mean_absolute_error: 33.6547 - val_mean_squared_error: 100134.5078 - val_coeff_determination: 0.3500
#
# Epoch 00057: val_loss did not improve from 33.01198
# Epoch 58/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 31.8125 - mean_absolute_error: 25.4646 - mean_squared_error: 83573.8828 - coeff_determination: 0.4331 - val_loss: 40.0547 - val_mean_absolute_error: 33.6987 - val_mean_squared_error: 98536.7344 - val_coeff_determination: 0.3628
#
# Epoch 00058: val_loss did not improve from 33.01198
# Epoch 59/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.9115 - mean_absolute_error: 25.5487 - mean_squared_error: 83805.6406 - coeff_determination: 0.4325 - val_loss: 40.8225 - val_mean_absolute_error: 34.4682 - val_mean_squared_error: 109264.5156 - val_coeff_determination: 0.2823
#
# Epoch 00059: val_loss did not improve from 33.01198
# Epoch 60/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.7422 - mean_absolute_error: 25.4217 - mean_squared_error: 83591.9766 - coeff_determination: 0.4334 - val_loss: 39.6346 - val_mean_absolute_error: 33.3287 - val_mean_squared_error: 104269.0156 - val_coeff_determination: 0.3223
#
# Epoch 00060: val_loss did not improve from 33.01198
# Epoch 61/1000
# 254417/254417 [==============================] - 98s 385us/step - loss: 31.8629 - mean_absolute_error: 25.5164 - mean_squared_error: 83980.2656 - coeff_determination: 0.4282 - val_loss: 37.8142 - val_mean_absolute_error: 31.4511 - val_mean_squared_error: 98651.2969 - val_coeff_determination: 0.3644
#
# Epoch 00061: val_loss did not improve from 33.01198
# Epoch 62/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 32.0230 - mean_absolute_error: 25.5776 - mean_squared_error: 83828.8281 - coeff_determination: 0.4294 - val_loss: 37.0772 - val_mean_absolute_error: 30.6171 - val_mean_squared_error: 97549.9297 - val_coeff_determination: 0.3711
#
# Epoch 00062: val_loss did not improve from 33.01198
# Epoch 63/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.7423 - mean_absolute_error: 25.3349 - mean_squared_error: 83510.8203 - coeff_determination: 0.4353 - val_loss: 40.1830 - val_mean_absolute_error: 33.8052 - val_mean_squared_error: 101072.5547 - val_coeff_determination: 0.3456
#
# Epoch 00063: val_loss did not improve from 33.01198
# Epoch 64/1000
# 254417/254417 [==============================] - 98s 385us/step - loss: 31.9399 - mean_absolute_error: 25.5099 - mean_squared_error: 83996.1172 - coeff_determination: 0.4284 - val_loss: 38.6343 - val_mean_absolute_error: 32.1702 - val_mean_squared_error: 94756.9688 - val_coeff_determination: 0.3904
#
# Epoch 00064: val_loss did not improve from 33.01198
# Epoch 65/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.8066 - mean_absolute_error: 25.3970 - mean_squared_error: 84074.5234 - coeff_determination: 0.4283 - val_loss: 52.9230 - val_mean_absolute_error: 46.5334 - val_mean_squared_error: 122205.3203 - val_coeff_determination: 0.1682
#
# Epoch 00065: val_loss did not improve from 33.01198
# Epoch 66/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.8836 - mean_absolute_error: 25.4914 - mean_squared_error: 83889.9922 - coeff_determination: 0.4305 - val_loss: 41.4483 - val_mean_absolute_error: 35.0351 - val_mean_squared_error: 106092.1172 - val_coeff_determination: 0.3032
#
# Epoch 00066: val_loss did not improve from 33.01198
# Epoch 67/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 32.0272 - mean_absolute_error: 25.5518 - mean_squared_error: 83484.6641 - coeff_determination: 0.4312 - val_loss: 43.8131 - val_mean_absolute_error: 37.2758 - val_mean_squared_error: 101819.2188 - val_coeff_determination: 0.3362
#
# Epoch 00067: val_loss did not improve from 33.01198
# Epoch 68/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.9668 - mean_absolute_error: 25.4089 - mean_squared_error: 83509.5078 - coeff_determination: 0.4350 - val_loss: 38.0649 - val_mean_absolute_error: 31.5595 - val_mean_squared_error: 96029.2656 - val_coeff_determination: 0.3835
#
# Epoch 00068: val_loss did not improve from 33.01198
# Epoch 69/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 31.8421 - mean_absolute_error: 25.3600 - mean_squared_error: 83739.8750 - coeff_determination: 0.4348 - val_loss: 37.1149 - val_mean_absolute_error: 30.6858 - val_mean_squared_error: 97538.8672 - val_coeff_determination: 0.3723
#
# Epoch 00069: val_loss did not improve from 33.01198
# Epoch 70/1000
# 254417/254417 [==============================] - 98s 383us/step - loss: 31.5957 - mean_absolute_error: 25.2093 - mean_squared_error: 83332.7188 - coeff_determination: 0.4322 - val_loss: 39.1314 - val_mean_absolute_error: 32.7432 - val_mean_squared_error: 98058.2891 - val_coeff_determination: 0.3678
#
# Epoch 00070: val_loss did not improve from 33.01198
# Epoch 71/1000
# 254417/254417 [==============================] - 98s 385us/step - loss: 31.7106 - mean_absolute_error: 25.3414 - mean_squared_error: 83353.2656 - coeff_determination: 0.4358 - val_loss: 56.6395 - val_mean_absolute_error: 50.2197 - val_mean_squared_error: 123011.7109 - val_coeff_determination: 0.1613
#
# Epoch 00071: val_loss did not improve from 33.01198
# Epoch 72/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.7671 - mean_absolute_error: 25.3070 - mean_squared_error: 83422.3672 - coeff_determination: 0.4329 - val_loss: 36.2299 - val_mean_absolute_error: 29.7873 - val_mean_squared_error: 94689.2109 - val_coeff_determination: 0.3938
#
# Epoch 00072: val_loss did not improve from 33.01198
# Epoch 73/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.5314 - mean_absolute_error: 25.1363 - mean_squared_error: 83119.9141 - coeff_determination: 0.4377 - val_loss: 40.7013 - val_mean_absolute_error: 34.3717 - val_mean_squared_error: 100975.1797 - val_coeff_determination: 0.3437
#
# Epoch 00073: val_loss did not improve from 33.01198
# Epoch 74/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.8602 - mean_absolute_error: 25.4584 - mean_squared_error: 83794.1875 - coeff_determination: 0.4295 - val_loss: 45.9296 - val_mean_absolute_error: 39.4366 - val_mean_squared_error: 116111.9609 - val_coeff_determination: 0.2315
#
# Epoch 00074: val_loss did not improve from 33.01198
# Epoch 75/1000
# 254417/254417 [==============================] - 98s 385us/step - loss: 31.9074 - mean_absolute_error: 25.4004 - mean_squared_error: 84126.9609 - coeff_determination: 0.4284 - val_loss: 45.8300 - val_mean_absolute_error: 39.3731 - val_mean_squared_error: 103876.5469 - val_coeff_determination: 0.3191
#
# Epoch 00075: val_loss did not improve from 33.01198
# Epoch 76/1000
# 254417/254417 [==============================] - 98s 384us/step - loss: 31.7562 - mean_absolute_error: 25.3310 - mean_squared_error: 83782.8594 - coeff_determination: 0.4295 - val_loss: 43.1159 - val_mean_absolute_error: 36.5941 - val_mean_squared_error: 102461.5547 - val_coeff_determination: 0.3274
#
# Epoch 00076: val_loss did not improve from 33.01198
# Epoch 00076: early stopping

# %%
predict_y_cnn = model_cnn.predict(test_x_cnn)

# %% [markdown]
# # Red Neuronal Recurrente - LSTM

# %% [markdown]
# ## Funciones

# %%
def layer_lstm(model, neurons = 128, regularizer = l2(0.0001),
              dropout = 0.2, return_sequences = True):
    
    model.add(LSTM(neurons, return_sequences=return_sequences,
                   kernel_regularizer=regularizer,
                   bias_regularizer=regularizer, dropout=dropout,
                   recurrent_dropout=dropout))

    model.add(BatchNormalization())
    
    return model

# %% [markdown]
# ## Modelo

# %%
def model_lstm():
    
    #Creación del modelo secuencial
    model = Sequential()
    
    function_act = 'relu'

    #Primera Capa convolucional
    #Capa inicial
    model = input_layer(model, len(train_x[0]), len(train_x[0][0]) )
    
    model = layer_lstm(model, 128)
    
    model = layer_lstm(model, 256)
    
    model = layer_lstm(model, 128, return_sequences=False)
    
    #Capa de salida
    model = result_layer(model, len(train_y[0]))

    return model

# %% [markdown]
# ## Ejecución

# %% [markdown]
# ### Ejecución entrada 1 mes

# %%
model_lstm, history_lstm = run_desing(model_lstm(), 'modelo_lstm_full', 
                                      batch, epochs,
                                      train_x, train_y, 
                                      validation_x, validation_y,
                                     'adam','huber_loss')

# %%
predict_y_lstm = model_lstm.predict(test_x)

# %% [markdown]
# ### Ejecución entrada 36 meses

# %%
model_lstm, history_lstm = run_desing(model_lstm(), 'modelo_lstm_full', 
                                      batch, epochs,
                                      train_x, train_y, 
                                      validation_x, validation_y,
                                     'adam','huber_loss')
# Out:
# Model: "modelo_lstm_full"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 36, 37)            148
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 36, 128)           84992
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 36, 128)           512
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 36, 256)           394240
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 36, 256)           1024
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 128)               197120
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 13)                1677
# =================================================================
# Total params: 680,225
# Trainable params: 679,127
# Non-trainable params: 1,098
# _________________________________________________________________
# Train on 254417 samples, validate on 63605 samples
# Epoch 1/1000
# 254417/254417 [==============================] - 151s 592us/step - loss: 45.9305 - mean_absolute_error: 45.9961 - mean_squared_error: 136736.2344 - coeff_determination: 0.0025 - val_loss: 46.5132 - val_mean_absolute_error: 46.7479 - val_mean_squared_error: 146313.2500 - val_coeff_determination: -0.0049
#
# Epoch 00001: val_loss improved from inf to 46.51319, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 2/1000
# 254417/254417 [==============================] - 147s 576us/step - loss: 42.4854 - mean_absolute_error: 42.5367 - mean_squared_error: 126017.4609 - coeff_determination: 0.0931 - val_loss: 41.4894 - val_mean_absolute_error: 41.5166 - val_mean_squared_error: 132190.9531 - val_coeff_determination: 0.1066
#
# Epoch 00002: val_loss improved from 46.51319 to 41.48936, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 3/1000
# 254417/254417 [==============================] - 147s 576us/step - loss: 40.4062 - mean_absolute_error: 40.4341 - mean_squared_error: 118518.3750 - coeff_determination: 0.1533 - val_loss: 38.8018 - val_mean_absolute_error: 38.8199 - val_mean_squared_error: 124176.3828 - val_coeff_determination: 0.1699
#
# Epoch 00003: val_loss improved from 41.48936 to 38.80177, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 4/1000
# 254417/254417 [==============================] - 146s 574us/step - loss: 38.9590 - mean_absolute_error: 38.9566 - mean_squared_error: 114175.1328 - coeff_determination: 0.1905 - val_loss: 36.9338 - val_mean_absolute_error: 36.9133 - val_mean_squared_error: 119503.9922 - val_coeff_determination: 0.2049
#
# Epoch 00004: val_loss improved from 38.80177 to 36.93378, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 5/1000
# 254417/254417 [==============================] - 147s 578us/step - loss: 37.8761 - mean_absolute_error: 37.8416 - mean_squared_error: 111348.4219 - coeff_determination: 0.2124 - val_loss: 35.4219 - val_mean_absolute_error: 35.3700 - val_mean_squared_error: 114620.1719 - val_coeff_determination: 0.2425
#
# Epoch 00005: val_loss improved from 36.93378 to 35.42193, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 6/1000
# 254417/254417 [==============================] - 146s 576us/step - loss: 36.8627 - mean_absolute_error: 36.8082 - mean_squared_error: 108783.1250 - coeff_determination: 0.2319 - val_loss: 34.3540 - val_mean_absolute_error: 34.2894 - val_mean_squared_error: 112524.5000 - val_coeff_determination: 0.2583
#
# Epoch 00006: val_loss improved from 35.42193 to 34.35404, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 7/1000
# 254417/254417 [==============================] - 147s 576us/step - loss: 35.9329 - mean_absolute_error: 35.8643 - mean_squared_error: 106866.3828 - coeff_determination: 0.2508 - val_loss: 33.3109 - val_mean_absolute_error: 33.2316 - val_mean_squared_error: 109725.6797 - val_coeff_determination: 0.2796
#
# Epoch 00007: val_loss improved from 34.35404 to 33.31093, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 8/1000
# 254417/254417 [==============================] - 146s 572us/step - loss: 35.0575 - mean_absolute_error: 34.9767 - mean_squared_error: 104776.5078 - coeff_determination: 0.2646 - val_loss: 32.1326 - val_mean_absolute_error: 32.0411 - val_mean_squared_error: 107237.0234 - val_coeff_determination: 0.2993
#
# Epoch 00008: val_loss improved from 33.31093 to 32.13261, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 9/1000
# 254417/254417 [==============================] - 147s 576us/step - loss: 34.0253 - mean_absolute_error: 33.9311 - mean_squared_error: 102165.5156 - coeff_determination: 0.2866 - val_loss: 30.7439 - val_mean_absolute_error: 30.6390 - val_mean_squared_error: 105382.5000 - val_coeff_determination: 0.3141
#
# Epoch 00009: val_loss improved from 32.13261 to 30.74386, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 10/1000
# 254417/254417 [==============================] - 146s 575us/step - loss: 33.1446 - mean_absolute_error: 33.0383 - mean_squared_error: 99982.4844 - coeff_determination: 0.3070 - val_loss: 29.5381 - val_mean_absolute_error: 29.4205 - val_mean_squared_error: 103113.0781 - val_coeff_determination: 0.3323
#
# Epoch 00010: val_loss improved from 30.74386 to 29.53814, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 11/1000
# 254417/254417 [==============================] - 146s 575us/step - loss: 32.3659 - mean_absolute_error: 32.2476 - mean_squared_error: 98331.7812 - coeff_determination: 0.3192 - val_loss: 28.5326 - val_mean_absolute_error: 28.4057 - val_mean_squared_error: 101323.0703 - val_coeff_determination: 0.3463
#
# Epoch 00011: val_loss improved from 29.53814 to 28.53260, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 12/1000
# 254417/254417 [==============================] - 146s 575us/step - loss: 31.6119 - mean_absolute_error: 31.4818 - mean_squared_error: 96718.2109 - coeff_determination: 0.3339 - val_loss: 27.7972 - val_mean_absolute_error: 27.6592 - val_mean_squared_error: 99661.4375 - val_coeff_determination: 0.3598
#
# Epoch 00012: val_loss improved from 28.53260 to 27.79715, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 13/1000
# 254417/254417 [==============================] - 147s 576us/step - loss: 31.0347 - mean_absolute_error: 30.8929 - mean_squared_error: 95477.4219 - coeff_determination: 0.3421 - val_loss: 27.1685 - val_mean_absolute_error: 27.0185 - val_mean_squared_error: 98859.3906 - val_coeff_determination: 0.3658
#
# Epoch 00013: val_loss improved from 27.79715 to 27.16849, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 14/1000
# 254417/254417 [==============================] - 146s 574us/step - loss: 30.6786 - mean_absolute_error: 30.5255 - mean_squared_error: 94745.9688 - coeff_determination: 0.3483 - val_loss: 26.8863 - val_mean_absolute_error: 26.7238 - val_mean_squared_error: 97799.0312 - val_coeff_determination: 0.3743
#
# Epoch 00014: val_loss improved from 27.16849 to 26.88625, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 15/1000
# 254417/254417 [==============================] - 146s 575us/step - loss: 30.2256 - mean_absolute_error: 30.0614 - mean_squared_error: 93836.3906 - coeff_determination: 0.3556 - val_loss: 26.6384 - val_mean_absolute_error: 26.4660 - val_mean_squared_error: 96646.6016 - val_coeff_determination: 0.3832
#
# Epoch 00015: val_loss improved from 26.88625 to 26.63844, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 16/1000
# 254417/254417 [==============================] - 146s 573us/step - loss: 29.7821 - mean_absolute_error: 29.6070 - mean_squared_error: 93005.0000 - coeff_determination: 0.3650 - val_loss: 26.0630 - val_mean_absolute_error: 25.8807 - val_mean_squared_error: 96473.0156 - val_coeff_determination: 0.3847
#
# Epoch 00016: val_loss improved from 26.63844 to 26.06301, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 17/1000
# 254417/254417 [==============================] - 146s 573us/step - loss: 29.4738 - mean_absolute_error: 29.2889 - mean_squared_error: 92079.7031 - coeff_determination: 0.3684 - val_loss: 25.7468 - val_mean_absolute_error: 25.5548 - val_mean_squared_error: 95711.9844 - val_coeff_determination: 0.3907
#
# Epoch 00017: val_loss improved from 26.06301 to 25.74676, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 18/1000
# 254417/254417 [==============================] - 146s 573us/step - loss: 29.1423 - mean_absolute_error: 28.9474 - mean_squared_error: 91849.9922 - coeff_determination: 0.3684 - val_loss: 25.5994 - val_mean_absolute_error: 25.3973 - val_mean_squared_error: 94906.8984 - val_coeff_determination: 0.3967
#
# Epoch 00018: val_loss improved from 25.74676 to 25.59942, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 19/1000
# 254417/254417 [==============================] - 146s 572us/step - loss: 28.8311 - mean_absolute_error: 28.6266 - mean_squared_error: 91137.7422 - coeff_determination: 0.3805 - val_loss: 25.1126 - val_mean_absolute_error: 24.9040 - val_mean_squared_error: 94156.6406 - val_coeff_determination: 0.4031
#
# Epoch 00019: val_loss improved from 25.59942 to 25.11263, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 20/1000
# 254417/254417 [==============================] - 146s 574us/step - loss: 28.6127 - mean_absolute_error: 28.3981 - mean_squared_error: 90444.0000 - coeff_determination: 0.3805 - val_loss: 24.7590 - val_mean_absolute_error: 24.5359 - val_mean_squared_error: 93692.1406 - val_coeff_determination: 0.4067
#
# Epoch 00020: val_loss improved from 25.11263 to 24.75901, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 21/1000
# 254417/254417 [==============================] - 145s 572us/step - loss: 28.4367 - mean_absolute_error: 28.2107 - mean_squared_error: 90051.5859 - coeff_determination: 0.3866 - val_loss: 24.7005 - val_mean_absolute_error: 24.4669 - val_mean_squared_error: 93156.3438 - val_coeff_determination: 0.4108
#
# Epoch 00021: val_loss improved from 24.75901 to 24.70052, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 22/1000
# 254417/254417 [==============================] - 146s 572us/step - loss: 28.4315 - mean_absolute_error: 28.1934 - mean_squared_error: 89538.9922 - coeff_determination: 0.3891 - val_loss: 24.4162 - val_mean_absolute_error: 24.1684 - val_mean_squared_error: 92587.1172 - val_coeff_determination: 0.4153
#
# Epoch 00022: val_loss improved from 24.70052 to 24.41620, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 23/1000
# 254417/254417 [==============================] - 145s 570us/step - loss: 28.0328 - mean_absolute_error: 27.7845 - mean_squared_error: 89021.6094 - coeff_determination: 0.3959 - val_loss: 24.1794 - val_mean_absolute_error: 23.9260 - val_mean_squared_error: 91600.5000 - val_coeff_determination: 0.4234
#
# Epoch 00023: val_loss improved from 24.41620 to 24.17941, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 24/1000
# 254417/254417 [==============================] - 145s 572us/step - loss: 27.6849 - mean_absolute_error: 27.4305 - mean_squared_error: 87998.4922 - coeff_determination: 0.4036 - val_loss: 23.9488 - val_mean_absolute_error: 23.6911 - val_mean_squared_error: 91883.5234 - val_coeff_determination: 0.4212
#
# Epoch 00024: val_loss improved from 24.17941 to 23.94882, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 25/1000
# 254417/254417 [==============================] - 145s 571us/step - loss: 27.5896 - mean_absolute_error: 27.3276 - mean_squared_error: 87581.0469 - coeff_determination: 0.4051 - val_loss: 23.6691 - val_mean_absolute_error: 23.3996 - val_mean_squared_error: 90439.0156 - val_coeff_determination: 0.4317
#
# Epoch 00025: val_loss improved from 23.94882 to 23.66907, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 26/1000
# 254417/254417 [==============================] - 145s 571us/step - loss: 27.3337 - mean_absolute_error: 27.0649 - mean_squared_error: 87139.4141 - coeff_determination: 0.4073 - val_loss: 23.3852 - val_mean_absolute_error: 23.1102 - val_mean_squared_error: 90026.7188 - val_coeff_determination: 0.4346
#
# Epoch 00026: val_loss improved from 23.66907 to 23.38517, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 27/1000
# 254417/254417 [==============================] - 144s 568us/step - loss: 27.1228 - mean_absolute_error: 26.8487 - mean_squared_error: 86613.2344 - coeff_determination: 0.4184 - val_loss: 23.1533 - val_mean_absolute_error: 22.8727 - val_mean_squared_error: 89441.9141 - val_coeff_determination: 0.4397
#
# Epoch 00027: val_loss improved from 23.38517 to 23.15335, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 28/1000
# 254417/254417 [==============================] - 145s 571us/step - loss: 26.9178 - mean_absolute_error: 26.6381 - mean_squared_error: 85809.1484 - coeff_determination: 0.4154 - val_loss: 23.0478 - val_mean_absolute_error: 22.7623 - val_mean_squared_error: 88531.4531 - val_coeff_determination: 0.4466
#
# Epoch 00028: val_loss improved from 23.15335 to 23.04783, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 29/1000
# 254417/254417 [==============================] - 145s 569us/step - loss: 26.7937 - mean_absolute_error: 26.5070 - mean_squared_error: 85225.6016 - coeff_determination: 0.4206 - val_loss: 22.6035 - val_mean_absolute_error: 22.3137 - val_mean_squared_error: 87581.5859 - val_coeff_determination: 0.4536
#
# Epoch 00029: val_loss improved from 23.04783 to 22.60347, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 30/1000
# 254417/254417 [==============================] - 145s 572us/step - loss: 26.5263 - mean_absolute_error: 26.2338 - mean_squared_error: 84475.7031 - coeff_determination: 0.4316 - val_loss: 22.7329 - val_mean_absolute_error: 22.4359 - val_mean_squared_error: 86637.0156 - val_coeff_determination: 0.4604
#
# Epoch 00030: val_loss did not improve from 22.60347
# Epoch 31/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 26.4069 - mean_absolute_error: 26.1094 - mean_squared_error: 83956.6016 - coeff_determination: 0.4357 - val_loss: 22.3187 - val_mean_absolute_error: 22.0155 - val_mean_squared_error: 86088.2656 - val_coeff_determination: 0.4646
#
# Epoch 00031: val_loss improved from 22.60347 to 22.31871, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 32/1000
# 254417/254417 [==============================] - 145s 568us/step - loss: 26.1390 - mean_absolute_error: 25.8355 - mean_squared_error: 83144.0078 - coeff_determination: 0.4414 - val_loss: 22.0037 - val_mean_absolute_error: 21.6995 - val_mean_squared_error: 85920.1719 - val_coeff_determination: 0.4655
#
# Epoch 00032: val_loss improved from 22.31871 to 22.00370, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 33/1000
# 254417/254417 [==============================] - 145s 570us/step - loss: 26.0645 - mean_absolute_error: 25.7555 - mean_squared_error: 82700.1328 - coeff_determination: 0.4440 - val_loss: 21.9456 - val_mean_absolute_error: 21.6310 - val_mean_squared_error: 85649.1016 - val_coeff_determination: 0.4677
#
# Epoch 00033: val_loss improved from 22.00370 to 21.94561, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 34/1000
# 254417/254417 [==============================] - 144s 568us/step - loss: 25.8923 - mean_absolute_error: 25.5780 - mean_squared_error: 82200.6406 - coeff_determination: 0.4456 - val_loss: 21.8008 - val_mean_absolute_error: 21.4812 - val_mean_squared_error: 84975.3594 - val_coeff_determination: 0.4723
#
# Epoch 00034: val_loss improved from 21.94561 to 21.80078, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 35/1000
# 254417/254417 [==============================] - 145s 569us/step - loss: 25.8049 - mean_absolute_error: 25.4843 - mean_squared_error: 82172.1172 - coeff_determination: 0.4511 - val_loss: 21.7320 - val_mean_absolute_error: 21.4094 - val_mean_squared_error: 84755.7969 - val_coeff_determination: 0.4736
#
# Epoch 00035: val_loss improved from 21.80078 to 21.73203, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 36/1000
# 254417/254417 [==============================] - 144s 565us/step - loss: 25.7029 - mean_absolute_error: 25.3770 - mean_squared_error: 81835.5156 - coeff_determination: 0.4498 - val_loss: 21.4533 - val_mean_absolute_error: 21.1208 - val_mean_squared_error: 84707.5547 - val_coeff_determination: 0.4743
#
# Epoch 00036: val_loss improved from 21.73203 to 21.45328, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 37/1000
# 254417/254417 [==============================] - 145s 571us/step - loss: 25.4834 - mean_absolute_error: 25.1512 - mean_squared_error: 81368.4531 - coeff_determination: 0.4543 - val_loss: 21.2890 - val_mean_absolute_error: 20.9521 - val_mean_squared_error: 84414.9453 - val_coeff_determination: 0.4766
#
# Epoch 00037: val_loss improved from 21.45328 to 21.28897, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 38/1000
# 254417/254417 [==============================] - 145s 568us/step - loss: 25.3757 - mean_absolute_error: 25.0383 - mean_squared_error: 81206.8594 - coeff_determination: 0.4557 - val_loss: 21.2767 - val_mean_absolute_error: 20.9352 - val_mean_squared_error: 84065.8125 - val_coeff_determination: 0.4792
#
# Epoch 00038: val_loss improved from 21.28897 to 21.27670, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 39/1000
# 254417/254417 [==============================] - 145s 570us/step - loss: 25.2283 - mean_absolute_error: 24.8852 - mean_squared_error: 80565.3672 - coeff_determination: 0.4611 - val_loss: 20.9637 - val_mean_absolute_error: 20.6167 - val_mean_squared_error: 83935.6875 - val_coeff_determination: 0.4803
#
# Epoch 00039: val_loss improved from 21.27670 to 20.96373, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 40/1000
# 254417/254417 [==============================] - 145s 568us/step - loss: 25.1082 - mean_absolute_error: 24.7602 - mean_squared_error: 80524.6641 - coeff_determination: 0.4599 - val_loss: 20.9768 - val_mean_absolute_error: 20.6230 - val_mean_squared_error: 83703.8359 - val_coeff_determination: 0.4818
#
# Epoch 00040: val_loss did not improve from 20.96373
# Epoch 41/1000
# 254417/254417 [==============================] - 145s 569us/step - loss: 25.0795 - mean_absolute_error: 24.7270 - mean_squared_error: 80194.2969 - coeff_determination: 0.4642 - val_loss: 20.9018 - val_mean_absolute_error: 20.5418 - val_mean_squared_error: 83359.6641 - val_coeff_determination: 0.4841
#
# Epoch 00041: val_loss improved from 20.96373 to 20.90184, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 42/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 24.8973 - mean_absolute_error: 24.5401 - mean_squared_error: 79837.9297 - coeff_determination: 0.4679 - val_loss: 20.9250 - val_mean_absolute_error: 20.5624 - val_mean_squared_error: 83208.5156 - val_coeff_determination: 0.4854
#
# Epoch 00042: val_loss did not improve from 20.90184
# Epoch 43/1000
# 254417/254417 [==============================] - 143s 564us/step - loss: 24.8395 - mean_absolute_error: 24.4774 - mean_squared_error: 79746.3828 - coeff_determination: 0.4684 - val_loss: 20.7748 - val_mean_absolute_error: 20.4081 - val_mean_squared_error: 83005.9375 - val_coeff_determination: 0.4869
#
# Epoch 00043: val_loss improved from 20.90184 to 20.77480, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 44/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 24.7885 - mean_absolute_error: 24.4215 - mean_squared_error: 79597.2891 - coeff_determination: 0.4727 - val_loss: 20.6746 - val_mean_absolute_error: 20.3009 - val_mean_squared_error: 82749.3203 - val_coeff_determination: 0.4887
#
# Epoch 00044: val_loss improved from 20.77480 to 20.67456, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 45/1000
# 254417/254417 [==============================] - 144s 568us/step - loss: 24.7187 - mean_absolute_error: 24.3467 - mean_squared_error: 79392.7734 - coeff_determination: 0.4779 - val_loss: 20.5806 - val_mean_absolute_error: 20.2048 - val_mean_squared_error: 82750.2578 - val_coeff_determination: 0.4887
#
# Epoch 00045: val_loss improved from 20.67456 to 20.58057, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 46/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 24.5398 - mean_absolute_error: 24.1636 - mean_squared_error: 79110.6250 - coeff_determination: 0.4732 - val_loss: 20.5288 - val_mean_absolute_error: 20.1461 - val_mean_squared_error: 82401.0000 - val_coeff_determination: 0.4913
#
# Epoch 00046: val_loss improved from 20.58057 to 20.52880, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 47/1000
# 254417/254417 [==============================] - 144s 564us/step - loss: 24.5741 - mean_absolute_error: 24.1930 - mean_squared_error: 79022.4141 - coeff_determination: 0.4707 - val_loss: 20.5713 - val_mean_absolute_error: 20.1846 - val_mean_squared_error: 82494.4844 - val_coeff_determination: 0.4904
#
# Epoch 00047: val_loss did not improve from 20.52880
# Epoch 48/1000
# 254417/254417 [==============================] - 143s 560us/step - loss: 24.5150 - mean_absolute_error: 24.1288 - mean_squared_error: 78936.5391 - coeff_determination: 0.4749 - val_loss: 20.5442 - val_mean_absolute_error: 20.1524 - val_mean_squared_error: 82040.1094 - val_coeff_determination: 0.4939
#
# Epoch 00048: val_loss did not improve from 20.52880
# Epoch 49/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 24.4985 - mean_absolute_error: 24.1074 - mean_squared_error: 78862.5859 - coeff_determination: 0.4742 - val_loss: 20.2814 - val_mean_absolute_error: 19.8855 - val_mean_squared_error: 81934.3203 - val_coeff_determination: 0.4946
#
# Epoch 00049: val_loss improved from 20.52880 to 20.28144, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 50/1000
# 254417/254417 [==============================] - 143s 564us/step - loss: 24.4443 - mean_absolute_error: 24.0488 - mean_squared_error: 78814.4297 - coeff_determination: 0.4753 - val_loss: 20.3159 - val_mean_absolute_error: 19.9126 - val_mean_squared_error: 81967.7500 - val_coeff_determination: 0.4943
#
# Epoch 00050: val_loss did not improve from 20.28144
# Epoch 51/1000
# 254417/254417 [==============================] - 144s 564us/step - loss: 24.3143 - mean_absolute_error: 23.9144 - mean_squared_error: 78456.3984 - coeff_determination: 0.4754 - val_loss: 20.1580 - val_mean_absolute_error: 19.7522 - val_mean_squared_error: 81810.9766 - val_coeff_determination: 0.4956
#
# Epoch 00051: val_loss improved from 20.28144 to 20.15800, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 52/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 24.3723 - mean_absolute_error: 23.9676 - mean_squared_error: 78680.2344 - coeff_determination: 0.4804 - val_loss: 20.0519 - val_mean_absolute_error: 19.6437 - val_mean_squared_error: 81498.6172 - val_coeff_determination: 0.4974
#
# Epoch 00052: val_loss improved from 20.15800 to 20.05188, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 53/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 24.1875 - mean_absolute_error: 23.7790 - mean_squared_error: 78131.3828 - coeff_determination: 0.4811 - val_loss: 20.1308 - val_mean_absolute_error: 19.7164 - val_mean_squared_error: 81448.5312 - val_coeff_determination: 0.4986
#
# Epoch 00053: val_loss did not improve from 20.05188
# Epoch 54/1000
# 254417/254417 [==============================] - 143s 564us/step - loss: 24.1521 - mean_absolute_error: 23.7388 - mean_squared_error: 78054.2031 - coeff_determination: 0.4825 - val_loss: 20.0051 - val_mean_absolute_error: 19.5886 - val_mean_squared_error: 81639.4297 - val_coeff_determination: 0.4972
#
# Epoch 00054: val_loss improved from 20.05188 to 20.00511, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 55/1000
# 254417/254417 [==============================] - 142s 558us/step - loss: 24.1297 - mean_absolute_error: 23.7124 - mean_squared_error: 78033.2344 - coeff_determination: 0.4820 - val_loss: 20.0569 - val_mean_absolute_error: 19.6350 - val_mean_squared_error: 81248.6641 - val_coeff_determination: 0.4998
#
# Epoch 00055: val_loss did not improve from 20.00511
# Epoch 56/1000
# 254417/254417 [==============================] - 142s 560us/step - loss: 24.0820 - mean_absolute_error: 23.6611 - mean_squared_error: 77843.5469 - coeff_determination: 0.4821 - val_loss: 19.9239 - val_mean_absolute_error: 19.5007 - val_mean_squared_error: 81365.3125 - val_coeff_determination: 0.4991
#
# Epoch 00056: val_loss improved from 20.00511 to 19.92393, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 57/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 23.9928 - mean_absolute_error: 23.5683 - mean_squared_error: 77569.8203 - coeff_determination: 0.4823 - val_loss: 19.9088 - val_mean_absolute_error: 19.4757 - val_mean_squared_error: 81138.8828 - val_coeff_determination: 0.5005
#
# Epoch 00057: val_loss improved from 19.92393 to 19.90882, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 58/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 23.9622 - mean_absolute_error: 23.5343 - mean_squared_error: 77494.1875 - coeff_determination: 0.4870 - val_loss: 19.7872 - val_mean_absolute_error: 19.3535 - val_mean_squared_error: 81188.3672 - val_coeff_determination: 0.5004
#
# Epoch 00058: val_loss improved from 19.90882 to 19.78718, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 59/1000
# 254417/254417 [==============================] - 144s 565us/step - loss: 23.9051 - mean_absolute_error: 23.4740 - mean_squared_error: 77421.8203 - coeff_determination: 0.4856 - val_loss: 19.8288 - val_mean_absolute_error: 19.3932 - val_mean_squared_error: 81318.0781 - val_coeff_determination: 0.4999
#
# Epoch 00059: val_loss did not improve from 19.78718
# Epoch 60/1000
# 254417/254417 [==============================] - 144s 567us/step - loss: 23.7867 - mean_absolute_error: 23.3524 - mean_squared_error: 77211.9609 - coeff_determination: 0.4881 - val_loss: 19.7850 - val_mean_absolute_error: 19.3474 - val_mean_squared_error: 81093.8203 - val_coeff_determination: 0.5011
#
# Epoch 00060: val_loss improved from 19.78718 to 19.78496, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 61/1000
# 254417/254417 [==============================] - 143s 562us/step - loss: 23.8632 - mean_absolute_error: 23.4248 - mean_squared_error: 77066.6250 - coeff_determination: 0.4876 - val_loss: 19.6913 - val_mean_absolute_error: 19.2488 - val_mean_squared_error: 80635.5000 - val_coeff_determination: 0.5042
#
# Epoch 00061: val_loss improved from 19.78496 to 19.69129, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 62/1000
# 254417/254417 [==============================] - 142s 559us/step - loss: 23.7645 - mean_absolute_error: 23.3217 - mean_squared_error: 77094.8516 - coeff_determination: 0.4921 - val_loss: 19.7725 - val_mean_absolute_error: 19.3240 - val_mean_squared_error: 80550.6016 - val_coeff_determination: 0.5050
#
# Epoch 00062: val_loss did not improve from 19.69129
# Epoch 63/1000
# 254417/254417 [==============================] - 143s 562us/step - loss: 23.7898 - mean_absolute_error: 23.3434 - mean_squared_error: 77031.3672 - coeff_determination: 0.4915 - val_loss: 19.5748 - val_mean_absolute_error: 19.1201 - val_mean_squared_error: 80459.7109 - val_coeff_determination: 0.5055
#
# Epoch 00063: val_loss improved from 19.69129 to 19.57477, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 64/1000
# 254417/254417 [==============================] - 142s 559us/step - loss: 23.6546 - mean_absolute_error: 23.2049 - mean_squared_error: 76734.5234 - coeff_determination: 0.4940 - val_loss: 19.5899 - val_mean_absolute_error: 19.1347 - val_mean_squared_error: 80607.5078 - val_coeff_determination: 0.5045
#
# Epoch 00064: val_loss did not improve from 19.57477
# Epoch 65/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 23.6535 - mean_absolute_error: 23.2007 - mean_squared_error: 76748.5234 - coeff_determination: 0.4905 - val_loss: 19.6504 - val_mean_absolute_error: 19.1925 - val_mean_squared_error: 80268.0469 - val_coeff_determination: 0.5069
#
# Epoch 00065: val_loss did not improve from 19.57477
# Epoch 66/1000
# 254417/254417 [==============================] - 142s 559us/step - loss: 23.6399 - mean_absolute_error: 23.1832 - mean_squared_error: 76779.9922 - coeff_determination: 0.4928 - val_loss: 19.5056 - val_mean_absolute_error: 19.0433 - val_mean_squared_error: 80467.0469 - val_coeff_determination: 0.5054
#
# Epoch 00066: val_loss improved from 19.57477 to 19.50558, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 67/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 23.5482 - mean_absolute_error: 23.0891 - mean_squared_error: 76507.6016 - coeff_determination: 0.4947 - val_loss: 19.5851 - val_mean_absolute_error: 19.1212 - val_mean_squared_error: 80406.5547 - val_coeff_determination: 0.5058
#
# Epoch 00067: val_loss did not improve from 19.50558
# Epoch 68/1000
# 254417/254417 [==============================] - 142s 558us/step - loss: 23.5816 - mean_absolute_error: 23.1192 - mean_squared_error: 76555.7266 - coeff_determination: 0.4942 - val_loss: 19.4485 - val_mean_absolute_error: 18.9786 - val_mean_squared_error: 80257.6016 - val_coeff_determination: 0.5070
#
# Epoch 00068: val_loss improved from 19.50558 to 19.44849, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 69/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 23.6167 - mean_absolute_error: 23.1502 - mean_squared_error: 76902.5234 - coeff_determination: 0.4915 - val_loss: 19.3907 - val_mean_absolute_error: 18.9214 - val_mean_squared_error: 80436.7109 - val_coeff_determination: 0.5062
#
# Epoch 00069: val_loss improved from 19.44849 to 19.39066, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 70/1000
# 254417/254417 [==============================] - 142s 560us/step - loss: 23.5045 - mean_absolute_error: 23.0347 - mean_squared_error: 76326.3281 - coeff_determination: 0.4950 - val_loss: 19.4480 - val_mean_absolute_error: 18.9741 - val_mean_squared_error: 80046.0625 - val_coeff_determination: 0.5085
#
# Epoch 00070: val_loss did not improve from 19.39066
# Epoch 71/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 23.4196 - mean_absolute_error: 22.9473 - mean_squared_error: 76247.5156 - coeff_determination: 0.4978 - val_loss: 19.4031 - val_mean_absolute_error: 18.9253 - val_mean_squared_error: 79766.9375 - val_coeff_determination: 0.5104
#
# Epoch 00071: val_loss did not improve from 19.39066
# Epoch 72/1000
# 254417/254417 [==============================] - 142s 559us/step - loss: 23.4136 - mean_absolute_error: 22.9384 - mean_squared_error: 76010.8125 - coeff_determination: 0.4976 - val_loss: 19.3586 - val_mean_absolute_error: 18.8775 - val_mean_squared_error: 80009.2578 - val_coeff_determination: 0.5087
#
# Epoch 00072: val_loss improved from 19.39066 to 19.35862, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 73/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 23.3847 - mean_absolute_error: 22.9074 - mean_squared_error: 76167.1406 - coeff_determination: 0.4964 - val_loss: 19.2617 - val_mean_absolute_error: 18.7772 - val_mean_squared_error: 79710.7344 - val_coeff_determination: 0.5108
#
# Epoch 00073: val_loss improved from 19.35862 to 19.26170, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 74/1000
# 254417/254417 [==============================] - 144s 564us/step - loss: 23.3408 - mean_absolute_error: 22.8603 - mean_squared_error: 76098.3906 - coeff_determination: 0.4997 - val_loss: 19.1451 - val_mean_absolute_error: 18.6629 - val_mean_squared_error: 79680.8438 - val_coeff_determination: 0.5110
#
# Epoch 00074: val_loss improved from 19.26170 to 19.14511, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 75/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 23.3189 - mean_absolute_error: 22.8359 - mean_squared_error: 75849.3672 - coeff_determination: 0.4981 - val_loss: 19.2368 - val_mean_absolute_error: 18.7467 - val_mean_squared_error: 79427.3359 - val_coeff_determination: 0.5127
#
# Epoch 00075: val_loss did not improve from 19.14511
# Epoch 76/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 23.2609 - mean_absolute_error: 22.7743 - mean_squared_error: 75723.4375 - coeff_determination: 0.5023 - val_loss: 19.2226 - val_mean_absolute_error: 18.7307 - val_mean_squared_error: 79766.5234 - val_coeff_determination: 0.5102
#
# Epoch 00076: val_loss did not improve from 19.14511
# Epoch 77/1000
# 254417/254417 [==============================] - 143s 562us/step - loss: 23.2740 - mean_absolute_error: 22.7846 - mean_squared_error: 75786.4766 - coeff_determination: 0.4974 - val_loss: 19.2903 - val_mean_absolute_error: 18.7966 - val_mean_squared_error: 79276.0391 - val_coeff_determination: 0.5139
#
# Epoch 00077: val_loss did not improve from 19.14511
# Epoch 78/1000
# 254417/254417 [==============================] - 144s 564us/step - loss: 23.1255 - mean_absolute_error: 22.6344 - mean_squared_error: 75639.5234 - coeff_determination: 0.5012 - val_loss: 19.1525 - val_mean_absolute_error: 18.6560 - val_mean_squared_error: 78985.6875 - val_coeff_determination: 0.5160
#
# Epoch 00078: val_loss did not improve from 19.14511
# Epoch 79/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 23.1635 - mean_absolute_error: 22.6699 - mean_squared_error: 75570.0312 - coeff_determination: 0.4983 - val_loss: 19.1063 - val_mean_absolute_error: 18.6068 - val_mean_squared_error: 78866.2422 - val_coeff_determination: 0.5164
#
# Epoch 00079: val_loss improved from 19.14511 to 19.10631, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 80/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 23.2319 - mean_absolute_error: 22.7349 - mean_squared_error: 75686.6641 - coeff_determination: 0.5013 - val_loss: 19.1613 - val_mean_absolute_error: 18.6605 - val_mean_squared_error: 79137.8047 - val_coeff_determination: 0.5148
#
# Epoch 00080: val_loss did not improve from 19.10631
# Epoch 81/1000
# 254417/254417 [==============================] - 143s 562us/step - loss: 23.0603 - mean_absolute_error: 22.5603 - mean_squared_error: 75494.6797 - coeff_determination: 0.5022 - val_loss: 19.0863 - val_mean_absolute_error: 18.5796 - val_mean_squared_error: 78953.1875 - val_coeff_determination: 0.5157
#
# Epoch 00081: val_loss improved from 19.10631 to 19.08628, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 82/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 23.0007 - mean_absolute_error: 22.4979 - mean_squared_error: 74999.7344 - coeff_determination: 0.5098 - val_loss: 18.9644 - val_mean_absolute_error: 18.4559 - val_mean_squared_error: 78792.1562 - val_coeff_determination: 0.5167
#
# Epoch 00082: val_loss improved from 19.08628 to 18.96439, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 83/1000
# 254417/254417 [==============================] - 143s 561us/step - loss: 23.0180 - mean_absolute_error: 22.5124 - mean_squared_error: 75261.5547 - coeff_determination: 0.5024 - val_loss: 18.9865 - val_mean_absolute_error: 18.4737 - val_mean_squared_error: 78859.7656 - val_coeff_determination: 0.5164
#
# Epoch 00083: val_loss did not improve from 18.96439
# Epoch 84/1000
# 254417/254417 [==============================] - 143s 564us/step - loss: 22.9935 - mean_absolute_error: 22.4852 - mean_squared_error: 75207.4375 - coeff_determination: 0.5046 - val_loss: 19.0149 - val_mean_absolute_error: 18.5020 - val_mean_squared_error: 79019.0859 - val_coeff_determination: 0.5157
#
# Epoch 00084: val_loss did not improve from 18.96439
# Epoch 85/1000
# 254417/254417 [==============================] - 143s 563us/step - loss: 22.9700 - mean_absolute_error: 22.4591 - mean_squared_error: 74959.7500 - coeff_determination: 0.5108 - val_loss: 18.8889 - val_mean_absolute_error: 18.3731 - val_mean_squared_error: 78718.2578 - val_coeff_determination: 0.5173
#
# Epoch 00085: val_loss improved from 18.96439 to 18.88886, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 86/1000
# 254417/254417 [==============================] - 144s 567us/step - loss: 22.9401 - mean_absolute_error: 22.4259 - mean_squared_error: 74953.5000 - coeff_determination: 0.5057 - val_loss: 18.9407 - val_mean_absolute_error: 18.4226 - val_mean_squared_error: 78617.2031 - val_coeff_determination: 0.5183
#
# Epoch 00086: val_loss did not improve from 18.88886
# Epoch 87/1000
# 254417/254417 [==============================] - 144s 565us/step - loss: 22.8841 - mean_absolute_error: 22.3685 - mean_squared_error: 74852.3828 - coeff_determination: 0.5077 - val_loss: 18.8365 - val_mean_absolute_error: 18.3125 - val_mean_squared_error: 78558.8672 - val_coeff_determination: 0.5187
#
# Epoch 00087: val_loss improved from 18.88886 to 18.83654, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 88/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 22.9338 - mean_absolute_error: 22.4158 - mean_squared_error: 75202.9609 - coeff_determination: 0.5046 - val_loss: 18.7651 - val_mean_absolute_error: 18.2431 - val_mean_squared_error: 78476.9141 - val_coeff_determination: 0.5192
#
# Epoch 00088: val_loss improved from 18.83654 to 18.76513, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_lstm_full.model
# Epoch 89/1000
# 254417/254417 [==============================] - 144s 566us/step - loss: 22.7939 - mean_absolute_error: 22.2741 - mean_squared_error: 74375.6250 - coeff_determination: 0.5107 - val_loss: 18.8017 - val_mean_absolute_error: 18.2780 - val_mean_squared_error: 78542.0000 - val_coeff_determination: 0.5187
#
# Epoch 00089: val_loss did not improve from 18.76513
# Epoch 90/1000
# 254417/254417 [==============================] - 144s 565us/step - loss: 22.9083 - mean_absolute_error: 22.3857 - mean_squared_error: 74735.7031 - coeff_determination: 0.5097 - val_loss: 18.8640 - val_mean_absolute_error: 18.3358 - val_mean_squared_error: 78195.5547 - val_coeff_determination: 0.5209
#
# Epoch 00090: val_loss did not improve from 18.76513
# Epoch 91/1000
# 254417/254417 [==============================] - 144s 565us/step - loss: 22.8996 - mean_absolute_error: 22.3750 - mean_squared_error: 75056.7109 - coeff_determination: 0.5068 - val_loss: 18.7883 - val_mean_absolute_error: 18.2598 - val_mean_squared_error: 78460.6641 - val_coeff_determination: 0.5193
#
# Epoch 00091: val_loss did not improve from 18.76513
# Epoch 92/1000
#  34304/254417 [===>..........................] - ETA: 1:59 - loss: 22.4748 - mean_absolute_error: 21.9485 - mean_squared_error: 66094.5547 - coeff_determination: 0.5449Buffered data was truncated after reaching the output size limit.

# %%
predict_y_lstm = model_lstm.predict(test_x)

# %% [markdown]
# # Modelo red neuronal convolucional bidireccional con LSTM

# %% [markdown]
# ## Función

# %%
def layer_bi_lstm(model, neurons = 128, regularizer = l2(0.0001),
              dropout = 0.2, return_sequences = True):
    
    model.add(Bidirectional(LSTM(neurons, return_sequences=return_sequences,
                                 kernel_regularizer=regularizer,
                                 bias_regularizer=regularizer, dropout=dropout,
                                 recurrent_dropout=dropout)))

    model.add(BatchNormalization())
    
    return model

# %%
#Función convolucional
def convolutional1D(model, filtros = 256, kernel_x = 3, 
                  stride = 1, activacion = 'relu', regularizador = l2(0.001), 
                  dropout = 0.2):

    #Capa convolucional
    model.add(Conv1D(filtros, kernel_size=kernel_x,
                   activation=activacion,padding='same',
                   kernel_regularizer=regularizador,
                   bias_regularizer=regularizador))
    
    model.add(Dropout(dropout))

    return model

# %%
#Función de pooling
def pooling1D(model, pooling_x = 3, dropout = 0.2):

    #Capa de polling
    model.add(MaxPooling1D(pooling_x))

    model.add(Dropout(dropout))
    
    model.add(BatchNormalization())

    return model

# %% [markdown]
# ## Modelo

# %%
def model_bi_lstm():
    
    #Creación del modelo secuencial
    model = Sequential()
    
    function_act = 'relu'

    #Primera Capa convolucional
    #Capa inicial
    model = input_layer(model, len(train_x[0]),len(train_x[0][0]))
    
    model = convolutional1D(model, 128, activacion = function_act)

    model = pooling1D(model, 2, dropout = 0)
    
    model = layer_bi_lstm(model, 128)
    
    model = layer_bi_lstm(model, 128, return_sequences=False)
    
    model = densa(model, 128, activacion = function_act)
    
    #Capa de salida
    model = result_layer(model, len(train_y[0]))

    return model

# %% [markdown]
# ## Ejecución

# %%
model_bi_lstm, history_bi_lstm = run_desing(model_bi_lstm(), 
                                            'modelo_bilstm_full_1c_1d', 
                                            batch, epochs, 
                                            train_x, train_y, 
                                            validation_x, validation_y,
                                            'adam','huber_loss')
# Out:
# Model: "modelo_bilstm_full"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 36, 37)            148
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 36, 64)            7168
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 36, 64)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 36, 64)            12352
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36, 64)            0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 18, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 18, 64)            0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 64)            256
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 18, 256)           197632
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 18, 256)           1024
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 256)               394240
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 13)                3341
# =================================================================
# Total params: 750,817
# Trainable params: 748,567
# Non-trainable params: 2,250
# _________________________________________________________________
# Train on 254417 samples, validate on 63605 samples
# Epoch 1/1000
# 254417/254417 [==============================] - 125s 492us/step - loss: 44.9969 - mean_absolute_error: 44.7964 - mean_squared_error: 133386.4219 - coeff_determination: 0.0287 - val_loss: 47.7916 - val_mean_absolute_error: 47.5888 - val_mean_squared_error: 145429.6094 - val_coeff_determination: 0.0017
#
# Epoch 00001: val_loss improved from inf to 47.79157, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 2/1000
# 254417/254417 [==============================] - 115s 453us/step - loss: 37.7039 - mean_absolute_error: 37.4290 - mean_squared_error: 113593.5859 - coeff_determination: 0.1954 - val_loss: 34.3872 - val_mean_absolute_error: 34.0471 - val_mean_squared_error: 114672.7188 - val_coeff_determination: 0.2436
#
# Epoch 00002: val_loss improved from 47.79157 to 34.38721, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 3/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 34.1500 - mean_absolute_error: 33.7558 - mean_squared_error: 103553.7109 - coeff_determination: 0.2759 - val_loss: 32.0873 - val_mean_absolute_error: 31.6406 - val_mean_squared_error: 107114.8594 - val_coeff_determination: 0.3020
#
# Epoch 00003: val_loss improved from 34.38721 to 32.08734, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 4/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 31.6299 - mean_absolute_error: 31.1430 - mean_squared_error: 97668.7109 - coeff_determination: 0.3214 - val_loss: 29.1329 - val_mean_absolute_error: 28.6035 - val_mean_squared_error: 100625.9141 - val_coeff_determination: 0.3538
#
# Epoch 00004: val_loss improved from 32.08734 to 29.13288, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 5/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 29.3453 - mean_absolute_error: 28.7831 - mean_squared_error: 92895.8828 - coeff_determination: 0.3637 - val_loss: 26.2235 - val_mean_absolute_error: 25.6276 - val_mean_squared_error: 96409.3750 - val_coeff_determination: 0.3872
#
# Epoch 00005: val_loss improved from 29.13288 to 26.22350, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 6/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 27.8469 - mean_absolute_error: 27.2201 - mean_squared_error: 88994.7812 - coeff_determination: 0.3967 - val_loss: 25.5138 - val_mean_absolute_error: 24.8539 - val_mean_squared_error: 92941.5078 - val_coeff_determination: 0.4136
#
# Epoch 00006: val_loss improved from 26.22350 to 25.51375, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 7/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 26.8623 - mean_absolute_error: 26.1837 - mean_squared_error: 85996.0391 - coeff_determination: 0.4167 - val_loss: 24.5412 - val_mean_absolute_error: 23.8388 - val_mean_squared_error: 90531.6641 - val_coeff_determination: 0.4308
#
# Epoch 00007: val_loss improved from 25.51375 to 24.54118, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 8/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 26.1475 - mean_absolute_error: 25.4277 - mean_squared_error: 83990.2344 - coeff_determination: 0.4339 - val_loss: 23.6674 - val_mean_absolute_error: 22.9271 - val_mean_squared_error: 88556.4141 - val_coeff_determination: 0.4455
#
# Epoch 00008: val_loss improved from 24.54118 to 23.66744, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 9/1000
# 254417/254417 [==============================] - 113s 442us/step - loss: 25.6547 - mean_absolute_error: 24.8985 - mean_squared_error: 82944.6094 - coeff_determination: 0.4455 - val_loss: 22.8694 - val_mean_absolute_error: 22.0948 - val_mean_squared_error: 87747.3359 - val_coeff_determination: 0.4514
#
# Epoch 00009: val_loss improved from 23.66744 to 22.86940, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 10/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 25.2191 - mean_absolute_error: 24.4334 - mean_squared_error: 81277.3516 - coeff_determination: 0.4561 - val_loss: 22.5567 - val_mean_absolute_error: 21.7578 - val_mean_squared_error: 85755.1797 - val_coeff_determination: 0.4660
#
# Epoch 00010: val_loss improved from 22.86940 to 22.55671, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 11/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 24.8090 - mean_absolute_error: 23.9969 - mean_squared_error: 80235.5156 - coeff_determination: 0.4664 - val_loss: 22.1349 - val_mean_absolute_error: 21.3063 - val_mean_squared_error: 84731.9922 - val_coeff_determination: 0.4722
#
# Epoch 00011: val_loss improved from 22.55671 to 22.13489, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 12/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 24.4635 - mean_absolute_error: 23.6258 - mean_squared_error: 79008.7891 - coeff_determination: 0.4749 - val_loss: 22.0026 - val_mean_absolute_error: 21.1511 - val_mean_squared_error: 83485.2422 - val_coeff_determination: 0.4810
#
# Epoch 00012: val_loss improved from 22.13489 to 22.00256, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 13/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 24.2750 - mean_absolute_error: 23.4156 - mean_squared_error: 78539.6094 - coeff_determination: 0.4807 - val_loss: 21.7594 - val_mean_absolute_error: 20.8906 - val_mean_squared_error: 83773.3203 - val_coeff_determination: 0.4796
#
# Epoch 00013: val_loss improved from 22.00256 to 21.75939, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 14/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 23.9606 - mean_absolute_error: 23.0812 - mean_squared_error: 77733.1641 - coeff_determination: 0.4874 - val_loss: 21.6917 - val_mean_absolute_error: 20.8031 - val_mean_squared_error: 82835.6172 - val_coeff_determination: 0.4867
#
# Epoch 00014: val_loss improved from 21.75939 to 21.69167, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 15/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 23.8127 - mean_absolute_error: 22.9144 - mean_squared_error: 77123.7188 - coeff_determination: 0.4882 - val_loss: 21.7800 - val_mean_absolute_error: 20.8723 - val_mean_squared_error: 81584.0625 - val_coeff_determination: 0.4952
#
# Epoch 00015: val_loss did not improve from 21.69167
# Epoch 16/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 23.6157 - mean_absolute_error: 22.7027 - mean_squared_error: 76431.4766 - coeff_determination: 0.4976 - val_loss: 21.2723 - val_mean_absolute_error: 20.3456 - val_mean_squared_error: 80921.6641 - val_coeff_determination: 0.5005
#
# Epoch 00016: val_loss improved from 21.69167 to 21.27231, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 17/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 23.4326 - mean_absolute_error: 22.5007 - mean_squared_error: 76027.9297 - coeff_determination: 0.5007 - val_loss: 21.0405 - val_mean_absolute_error: 20.1015 - val_mean_squared_error: 81159.2109 - val_coeff_determination: 0.4990
#
# Epoch 00017: val_loss improved from 21.27231 to 21.04050, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 18/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 23.2860 - mean_absolute_error: 22.3389 - mean_squared_error: 75205.3281 - coeff_determination: 0.5041 - val_loss: 20.7920 - val_mean_absolute_error: 19.8322 - val_mean_squared_error: 80239.8125 - val_coeff_determination: 0.5051
#
# Epoch 00018: val_loss improved from 21.04050 to 20.79198, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 19/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 23.0626 - mean_absolute_error: 22.0965 - mean_squared_error: 74860.2266 - coeff_determination: 0.5097 - val_loss: 20.5575 - val_mean_absolute_error: 19.5835 - val_mean_squared_error: 80184.4844 - val_coeff_determination: 0.5057
#
# Epoch 00019: val_loss improved from 20.79198 to 20.55749, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 20/1000
# 254417/254417 [==============================] - 114s 450us/step - loss: 22.9023 - mean_absolute_error: 21.9214 - mean_squared_error: 74230.5547 - coeff_determination: 0.5105 - val_loss: 20.7143 - val_mean_absolute_error: 19.7257 - val_mean_squared_error: 78632.1641 - val_coeff_determination: 0.5152
#
# Epoch 00020: val_loss did not improve from 20.55749
# Epoch 21/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 22.7496 - mean_absolute_error: 21.7522 - mean_squared_error: 73918.8438 - coeff_determination: 0.5148 - val_loss: 20.2413 - val_mean_absolute_error: 19.2367 - val_mean_squared_error: 78494.0547 - val_coeff_determination: 0.5187
#
# Epoch 00021: val_loss improved from 20.55749 to 20.24133, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 22/1000
# 254417/254417 [==============================] - 116s 454us/step - loss: 22.5821 - mean_absolute_error: 21.5695 - mean_squared_error: 72982.1250 - coeff_determination: 0.5230 - val_loss: 20.3843 - val_mean_absolute_error: 19.3634 - val_mean_squared_error: 78120.1719 - val_coeff_determination: 0.5211
#
# Epoch 00022: val_loss did not improve from 20.24133
# Epoch 23/1000
# 254417/254417 [==============================] - 116s 456us/step - loss: 22.4723 - mean_absolute_error: 21.4450 - mean_squared_error: 72523.4688 - coeff_determination: 0.5274 - val_loss: 19.9718 - val_mean_absolute_error: 18.9369 - val_mean_squared_error: 77234.2266 - val_coeff_determination: 0.5267
#
# Epoch 00023: val_loss improved from 20.24133 to 19.97176, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 24/1000
# 254417/254417 [==============================] - 115s 453us/step - loss: 22.2909 - mean_absolute_error: 21.2494 - mean_squared_error: 72315.9688 - coeff_determination: 0.5284 - val_loss: 20.1023 - val_mean_absolute_error: 19.0524 - val_mean_squared_error: 76551.8984 - val_coeff_determination: 0.5320
#
# Epoch 00024: val_loss did not improve from 19.97176
# Epoch 25/1000
# 254417/254417 [==============================] - 115s 452us/step - loss: 22.2123 - mean_absolute_error: 21.1560 - mean_squared_error: 72043.2266 - coeff_determination: 0.5318 - val_loss: 19.4824 - val_mean_absolute_error: 18.4188 - val_mean_squared_error: 76407.7266 - val_coeff_determination: 0.5340
#
# Epoch 00025: val_loss improved from 19.97176 to 19.48236, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 26/1000
# 254417/254417 [==============================] - 115s 453us/step - loss: 22.0144 - mean_absolute_error: 20.9456 - mean_squared_error: 71611.2031 - coeff_determination: 0.5358 - val_loss: 19.5635 - val_mean_absolute_error: 18.4866 - val_mean_squared_error: 76726.6250 - val_coeff_determination: 0.5311
#
# Epoch 00026: val_loss did not improve from 19.48236
# Epoch 27/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 21.8603 - mean_absolute_error: 20.7783 - mean_squared_error: 71019.8281 - coeff_determination: 0.5392 - val_loss: 19.2609 - val_mean_absolute_error: 18.1725 - val_mean_squared_error: 75560.3125 - val_coeff_determination: 0.5392
#
# Epoch 00027: val_loss improved from 19.48236 to 19.26089, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 28/1000
# 254417/254417 [==============================] - 115s 450us/step - loss: 21.7781 - mean_absolute_error: 20.6833 - mean_squared_error: 70934.3984 - coeff_determination: 0.5372 - val_loss: 19.3460 - val_mean_absolute_error: 18.2486 - val_mean_squared_error: 76218.0156 - val_coeff_determination: 0.5356
#
# Epoch 00028: val_loss did not improve from 19.26089
# Epoch 29/1000
# 254417/254417 [==============================] - 115s 450us/step - loss: 21.6541 - mean_absolute_error: 20.5524 - mean_squared_error: 70768.6094 - coeff_determination: 0.5395 - val_loss: 18.8428 - val_mean_absolute_error: 17.7395 - val_mean_squared_error: 75094.6094 - val_coeff_determination: 0.5424
#
# Epoch 00029: val_loss improved from 19.26089 to 18.84280, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 30/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 21.5343 - mean_absolute_error: 20.4227 - mean_squared_error: 70180.2344 - coeff_determination: 0.5439 - val_loss: 19.3420 - val_mean_absolute_error: 18.2252 - val_mean_squared_error: 74529.7969 - val_coeff_determination: 0.5468
#
# Epoch 00030: val_loss did not improve from 18.84280
# Epoch 31/1000
# 254417/254417 [==============================] - 115s 450us/step - loss: 21.4258 - mean_absolute_error: 20.3046 - mean_squared_error: 69817.9141 - coeff_determination: 0.5500 - val_loss: 18.6062 - val_mean_absolute_error: 17.4778 - val_mean_squared_error: 73772.7188 - val_coeff_determination: 0.5520
#
# Epoch 00031: val_loss improved from 18.84280 to 18.60616, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 32/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 21.4153 - mean_absolute_error: 20.2843 - mean_squared_error: 69491.0625 - coeff_determination: 0.5502 - val_loss: 18.8771 - val_mean_absolute_error: 17.7376 - val_mean_squared_error: 73978.7266 - val_coeff_determination: 0.5493
#
# Epoch 00032: val_loss did not improve from 18.60616
# Epoch 33/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 21.4268 - mean_absolute_error: 20.2860 - mean_squared_error: 69157.5859 - coeff_determination: 0.5502 - val_loss: 18.3670 - val_mean_absolute_error: 17.2171 - val_mean_squared_error: 73450.2344 - val_coeff_determination: 0.5534
#
# Epoch 00033: val_loss improved from 18.60616 to 18.36700, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 34/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 21.2743 - mean_absolute_error: 20.1239 - mean_squared_error: 68675.4453 - coeff_determination: 0.5546 - val_loss: 19.0056 - val_mean_absolute_error: 17.8529 - val_mean_squared_error: 72167.1172 - val_coeff_determination: 0.5617
#
# Epoch 00034: val_loss did not improve from 18.36700
# Epoch 35/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 21.1359 - mean_absolute_error: 19.9761 - mean_squared_error: 68080.6172 - coeff_determination: 0.5602 - val_loss: 18.3934 - val_mean_absolute_error: 17.2284 - val_mean_squared_error: 71769.4062 - val_coeff_determination: 0.5644
#
# Epoch 00035: val_loss did not improve from 18.36700
# Epoch 36/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 21.1779 - mean_absolute_error: 20.0060 - mean_squared_error: 68212.1328 - coeff_determination: 0.5582 - val_loss: 18.4237 - val_mean_absolute_error: 17.2479 - val_mean_squared_error: 71140.9219 - val_coeff_determination: 0.5684
#
# Epoch 00036: val_loss did not improve from 18.36700
# Epoch 37/1000
# 254417/254417 [==============================] - 112s 440us/step - loss: 21.0091 - mean_absolute_error: 19.8297 - mean_squared_error: 67808.1953 - coeff_determination: 0.5648 - val_loss: 18.1485 - val_mean_absolute_error: 16.9646 - val_mean_squared_error: 71428.3594 - val_coeff_determination: 0.5671
#
# Epoch 00037: val_loss improved from 18.36700 to 18.14851, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 38/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 20.9261 - mean_absolute_error: 19.7353 - mean_squared_error: 67274.2891 - coeff_determination: 0.5638 - val_loss: 18.5473 - val_mean_absolute_error: 17.3525 - val_mean_squared_error: 71180.3203 - val_coeff_determination: 0.5683
#
# Epoch 00038: val_loss did not improve from 18.14851
# Epoch 39/1000
# 254417/254417 [==============================] - 112s 440us/step - loss: 20.8643 - mean_absolute_error: 19.6664 - mean_squared_error: 66905.3906 - coeff_determination: 0.5624 - val_loss: 18.0066 - val_mean_absolute_error: 16.8043 - val_mean_squared_error: 70739.7734 - val_coeff_determination: 0.5727
#
# Epoch 00039: val_loss improved from 18.14851 to 18.00658, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 40/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 20.7705 - mean_absolute_error: 19.5638 - mean_squared_error: 66415.9141 - coeff_determination: 0.5703 - val_loss: 18.5604 - val_mean_absolute_error: 17.3449 - val_mean_squared_error: 70792.8203 - val_coeff_determination: 0.5698
#
# Epoch 00040: val_loss did not improve from 18.00658
# Epoch 41/1000
# 254417/254417 [==============================] - 113s 442us/step - loss: 20.6667 - mean_absolute_error: 19.4512 - mean_squared_error: 66063.0547 - coeff_determination: 0.5749 - val_loss: 17.8032 - val_mean_absolute_error: 16.5837 - val_mean_squared_error: 70038.8984 - val_coeff_determination: 0.5754
#
# Epoch 00041: val_loss improved from 18.00658 to 17.80317, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 42/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 20.6588 - mean_absolute_error: 19.4375 - mean_squared_error: 66002.1328 - coeff_determination: 0.5771 - val_loss: 18.3437 - val_mean_absolute_error: 17.1202 - val_mean_squared_error: 70467.3906 - val_coeff_determination: 0.5737
#
# Epoch 00042: val_loss did not improve from 17.80317
# Epoch 43/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 20.4177 - mean_absolute_error: 19.1909 - mean_squared_error: 65435.6562 - coeff_determination: 0.5792 - val_loss: 18.9526 - val_mean_absolute_error: 17.7231 - val_mean_squared_error: 70344.8281 - val_coeff_determination: 0.5734
#
# Epoch 00043: val_loss did not improve from 17.80317
# Epoch 44/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 20.5522 - mean_absolute_error: 19.3184 - mean_squared_error: 65730.9609 - coeff_determination: 0.5758 - val_loss: 18.1401 - val_mean_absolute_error: 16.8989 - val_mean_squared_error: 71527.8750 - val_coeff_determination: 0.5649
#
# Epoch 00044: val_loss did not improve from 17.80317
# Epoch 45/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 20.5130 - mean_absolute_error: 19.2690 - mean_squared_error: 65512.3984 - coeff_determination: 0.5768 - val_loss: 18.0972 - val_mean_absolute_error: 16.8522 - val_mean_squared_error: 70860.0000 - val_coeff_determination: 0.5692
#
# Epoch 00045: val_loss did not improve from 17.80317
# Epoch 46/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 20.4491 - mean_absolute_error: 19.2001 - mean_squared_error: 65574.6172 - coeff_determination: 0.5736 - val_loss: 17.9349 - val_mean_absolute_error: 16.6809 - val_mean_squared_error: 70668.4062 - val_coeff_determination: 0.5724
#
# Epoch 00046: val_loss did not improve from 17.80317
# Epoch 47/1000
# 254417/254417 [==============================] - 112s 439us/step - loss: 20.4146 - mean_absolute_error: 19.1572 - mean_squared_error: 65107.9453 - coeff_determination: 0.5781 - val_loss: 17.8455 - val_mean_absolute_error: 16.5820 - val_mean_squared_error: 69822.0469 - val_coeff_determination: 0.5763
#
# Epoch 00047: val_loss did not improve from 17.80317
# Epoch 48/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 20.2486 - mean_absolute_error: 18.9861 - mean_squared_error: 64942.5039 - coeff_determination: 0.5880 - val_loss: 17.8405 - val_mean_absolute_error: 16.5700 - val_mean_squared_error: 70994.4688 - val_coeff_determination: 0.5682
#
# Epoch 00048: val_loss did not improve from 17.80317
# Epoch 49/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 20.3596 - mean_absolute_error: 19.0885 - mean_squared_error: 65106.8164 - coeff_determination: 0.5822 - val_loss: 17.7434 - val_mean_absolute_error: 16.4669 - val_mean_squared_error: 69587.6328 - val_coeff_determination: 0.5788
#
# Epoch 00049: val_loss improved from 17.80317 to 17.74339, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 50/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 20.3032 - mean_absolute_error: 19.0248 - mean_squared_error: 64715.8672 - coeff_determination: 0.5835 - val_loss: 17.9168 - val_mean_absolute_error: 16.6362 - val_mean_squared_error: 69563.7500 - val_coeff_determination: 0.5791
#
# Epoch 00050: val_loss did not improve from 17.74339
# Epoch 51/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 20.2266 - mean_absolute_error: 18.9432 - mean_squared_error: 64586.6484 - coeff_determination: 0.5856 - val_loss: 18.2407 - val_mean_absolute_error: 16.9542 - val_mean_squared_error: 71519.3984 - val_coeff_determination: 0.5636
#
# Epoch 00051: val_loss did not improve from 17.74339
# Epoch 52/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 20.2088 - mean_absolute_error: 18.9194 - mean_squared_error: 64791.0898 - coeff_determination: 0.5805 - val_loss: 17.9091 - val_mean_absolute_error: 16.6182 - val_mean_squared_error: 70537.3984 - val_coeff_determination: 0.5716
#
# Epoch 00052: val_loss did not improve from 17.74339
# Epoch 53/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 20.1796 - mean_absolute_error: 18.8846 - mean_squared_error: 64718.6914 - coeff_determination: 0.5893 - val_loss: 18.1871 - val_mean_absolute_error: 16.8913 - val_mean_squared_error: 69638.6797 - val_coeff_determination: 0.5789
#
# Epoch 00053: val_loss did not improve from 17.74339
# Epoch 54/1000
# 254417/254417 [==============================] - 112s 440us/step - loss: 20.1359 - mean_absolute_error: 18.8373 - mean_squared_error: 64480.2812 - coeff_determination: 0.5849 - val_loss: 18.4004 - val_mean_absolute_error: 17.1015 - val_mean_squared_error: 70469.7734 - val_coeff_determination: 0.5732
#
# Epoch 00054: val_loss did not improve from 17.74339
# Epoch 55/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 20.0334 - mean_absolute_error: 18.7298 - mean_squared_error: 64000.5469 - coeff_determination: 0.5879 - val_loss: 17.9452 - val_mean_absolute_error: 16.6353 - val_mean_squared_error: 70124.1719 - val_coeff_determination: 0.5740
#
# Epoch 00055: val_loss did not improve from 17.74339
# Epoch 56/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 20.0950 - mean_absolute_error: 18.7847 - mean_squared_error: 64722.1445 - coeff_determination: 0.5829 - val_loss: 17.7627 - val_mean_absolute_error: 16.4539 - val_mean_squared_error: 70930.6875 - val_coeff_determination: 0.5697
#
# Epoch 00056: val_loss did not improve from 17.74339
# Epoch 57/1000
# 254417/254417 [==============================] - 112s 440us/step - loss: 19.9822 - mean_absolute_error: 18.6702 - mean_squared_error: 63918.3438 - coeff_determination: 0.5913 - val_loss: 17.8422 - val_mean_absolute_error: 16.5312 - val_mean_squared_error: 70654.5156 - val_coeff_determination: 0.5704
#
# Epoch 00057: val_loss did not improve from 17.74339
# Epoch 58/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 19.9441 - mean_absolute_error: 18.6299 - mean_squared_error: 64143.1094 - coeff_determination: 0.5887 - val_loss: 17.6860 - val_mean_absolute_error: 16.3690 - val_mean_squared_error: 70611.8203 - val_coeff_determination: 0.5722
#
# Epoch 00058: val_loss improved from 17.74339 to 17.68602, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 59/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 20.0620 - mean_absolute_error: 18.7419 - mean_squared_error: 64245.8633 - coeff_determination: 0.5898 - val_loss: 17.6138 - val_mean_absolute_error: 16.2832 - val_mean_squared_error: 71195.0625 - val_coeff_determination: 0.5656
#
# Epoch 00059: val_loss improved from 17.68602 to 17.61378, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 60/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 19.9066 - mean_absolute_error: 18.5807 - mean_squared_error: 63368.4453 - coeff_determination: 0.5950 - val_loss: 17.7012 - val_mean_absolute_error: 16.3717 - val_mean_squared_error: 70416.4297 - val_coeff_determination: 0.5704
#
# Epoch 00060: val_loss did not improve from 17.61378
# Epoch 61/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 19.8256 - mean_absolute_error: 18.4967 - mean_squared_error: 63172.1094 - coeff_determination: 0.5977 - val_loss: 17.2977 - val_mean_absolute_error: 15.9549 - val_mean_squared_error: 69051.7500 - val_coeff_determination: 0.5827
#
# Epoch 00061: val_loss improved from 17.61378 to 17.29774, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 62/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.8544 - mean_absolute_error: 18.5235 - mean_squared_error: 63380.0234 - coeff_determination: 0.5912 - val_loss: 17.7169 - val_mean_absolute_error: 16.3852 - val_mean_squared_error: 69037.1797 - val_coeff_determination: 0.5813
#
# Epoch 00062: val_loss did not improve from 17.29774
# Epoch 63/1000
# 254417/254417 [==============================] - 112s 438us/step - loss: 19.7948 - mean_absolute_error: 18.4585 - mean_squared_error: 63148.2383 - coeff_determination: 0.5962 - val_loss: 17.1074 - val_mean_absolute_error: 15.7685 - val_mean_squared_error: 69602.3672 - val_coeff_determination: 0.5772
#
# Epoch 00063: val_loss improved from 17.29774 to 17.10742, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 64/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 19.7791 - mean_absolute_error: 18.4398 - mean_squared_error: 62975.7852 - coeff_determination: 0.5932 - val_loss: 18.2539 - val_mean_absolute_error: 16.8997 - val_mean_squared_error: 71483.4609 - val_coeff_determination: 0.5641
#
# Epoch 00064: val_loss did not improve from 17.10742
# Epoch 65/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 19.7050 - mean_absolute_error: 18.3634 - mean_squared_error: 63009.9883 - coeff_determination: 0.5973 - val_loss: 17.6306 - val_mean_absolute_error: 16.2904 - val_mean_squared_error: 68896.2578 - val_coeff_determination: 0.5828
#
# Epoch 00065: val_loss did not improve from 17.10742
# Epoch 66/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.7331 - mean_absolute_error: 18.3839 - mean_squared_error: 62798.6016 - coeff_determination: 0.5936 - val_loss: 17.0877 - val_mean_absolute_error: 15.7400 - val_mean_squared_error: 69243.4688 - val_coeff_determination: 0.5806
#
# Epoch 00066: val_loss improved from 17.10742 to 17.08774, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 67/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 19.7335 - mean_absolute_error: 18.3808 - mean_squared_error: 63064.5586 - coeff_determination: 0.5979 - val_loss: 17.5031 - val_mean_absolute_error: 16.1536 - val_mean_squared_error: 69564.1797 - val_coeff_determination: 0.5772
#
# Epoch 00067: val_loss did not improve from 17.08774
# Epoch 68/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.6452 - mean_absolute_error: 18.2868 - mean_squared_error: 62817.9531 - coeff_determination: 0.6028 - val_loss: 16.9979 - val_mean_absolute_error: 15.6267 - val_mean_squared_error: 68916.7812 - val_coeff_determination: 0.5830
#
# Epoch 00068: val_loss improved from 17.08774 to 16.99787, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 69/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.5956 - mean_absolute_error: 18.2344 - mean_squared_error: 62886.3320 - coeff_determination: 0.5960 - val_loss: 17.8476 - val_mean_absolute_error: 16.4818 - val_mean_squared_error: 71729.8672 - val_coeff_determination: 0.5612
#
# Epoch 00069: val_loss did not improve from 16.99787
# Epoch 70/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 19.5609 - mean_absolute_error: 18.1948 - mean_squared_error: 62423.2773 - coeff_determination: 0.5989 - val_loss: 17.3678 - val_mean_absolute_error: 15.9929 - val_mean_squared_error: 72246.6719 - val_coeff_determination: 0.5588
#
# Epoch 00070: val_loss did not improve from 16.99787
# Epoch 71/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.6279 - mean_absolute_error: 18.2589 - mean_squared_error: 62361.0508 - coeff_determination: 0.6015 - val_loss: 17.4905 - val_mean_absolute_error: 16.1209 - val_mean_squared_error: 71167.5859 - val_coeff_determination: 0.5652
#
# Epoch 00071: val_loss did not improve from 16.99787
# Epoch 72/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.5517 - mean_absolute_error: 18.1793 - mean_squared_error: 62548.5508 - coeff_determination: 0.5991 - val_loss: 17.5686 - val_mean_absolute_error: 16.1862 - val_mean_squared_error: 69499.9609 - val_coeff_determination: 0.5785
#
# Epoch 00072: val_loss did not improve from 16.99787
# Epoch 73/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 19.5095 - mean_absolute_error: 18.1387 - mean_squared_error: 62240.9453 - coeff_determination: 0.6026 - val_loss: 18.3944 - val_mean_absolute_error: 17.0096 - val_mean_squared_error: 70300.8828 - val_coeff_determination: 0.5730
#
# Epoch 00073: val_loss did not improve from 16.99787
# Epoch 74/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 19.5526 - mean_absolute_error: 18.1766 - mean_squared_error: 62136.1016 - coeff_determination: 0.5992 - val_loss: 17.0510 - val_mean_absolute_error: 15.6782 - val_mean_squared_error: 69249.4141 - val_coeff_determination: 0.5798
#
# Epoch 00074: val_loss did not improve from 16.99787
# Epoch 75/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 19.4975 - mean_absolute_error: 18.1211 - mean_squared_error: 62179.2617 - coeff_determination: 0.6012 - val_loss: 17.9162 - val_mean_absolute_error: 16.5339 - val_mean_squared_error: 68264.1797 - val_coeff_determination: 0.5872
#
# Epoch 00075: val_loss did not improve from 16.99787
# Epoch 76/1000
# 254417/254417 [==============================] - 113s 442us/step - loss: 19.4190 - mean_absolute_error: 18.0388 - mean_squared_error: 61890.3984 - coeff_determination: 0.6044 - val_loss: 17.5182 - val_mean_absolute_error: 16.1366 - val_mean_squared_error: 69434.5781 - val_coeff_determination: 0.5770
#
# Epoch 00076: val_loss did not improve from 16.99787
# Epoch 77/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 19.4490 - mean_absolute_error: 18.0642 - mean_squared_error: 61590.8789 - coeff_determination: 0.6054 - val_loss: 17.1008 - val_mean_absolute_error: 15.7109 - val_mean_squared_error: 69601.4141 - val_coeff_determination: 0.5780
#
# Epoch 00077: val_loss did not improve from 16.99787
# Epoch 78/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 19.4970 - mean_absolute_error: 18.1079 - mean_squared_error: 62233.2305 - coeff_determination: 0.6010 - val_loss: 17.2379 - val_mean_absolute_error: 15.8343 - val_mean_squared_error: 70631.2031 - val_coeff_determination: 0.5704
#
# Epoch 00078: val_loss did not improve from 16.99787
# Epoch 79/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 19.4100 - mean_absolute_error: 18.0173 - mean_squared_error: 61627.1211 - coeff_determination: 0.6059 - val_loss: 16.9013 - val_mean_absolute_error: 15.4952 - val_mean_squared_error: 68207.1953 - val_coeff_determination: 0.5877
#
# Epoch 00079: val_loss improved from 16.99787 to 16.90131, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 80/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 19.3955 - mean_absolute_error: 18.0024 - mean_squared_error: 61391.4922 - coeff_determination: 0.6083 - val_loss: 17.7609 - val_mean_absolute_error: 16.3594 - val_mean_squared_error: 71250.0000 - val_coeff_determination: 0.5645
#
# Epoch 00080: val_loss did not improve from 16.90131
# Epoch 81/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 19.3752 - mean_absolute_error: 17.9805 - mean_squared_error: 61630.9766 - coeff_determination: 0.6083 - val_loss: 17.7301 - val_mean_absolute_error: 16.3239 - val_mean_squared_error: 68984.3672 - val_coeff_determination: 0.5811
#
# Epoch 00081: val_loss did not improve from 16.90131
# Epoch 82/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 19.2768 - mean_absolute_error: 17.8819 - mean_squared_error: 61439.2773 - coeff_determination: 0.6089 - val_loss: 17.3959 - val_mean_absolute_error: 15.9904 - val_mean_squared_error: 70855.2422 - val_coeff_determination: 0.5669
#
# Epoch 00082: val_loss did not improve from 16.90131
# Epoch 83/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.2868 - mean_absolute_error: 17.8878 - mean_squared_error: 61437.2500 - coeff_determination: 0.6075 - val_loss: 17.5804 - val_mean_absolute_error: 16.1664 - val_mean_squared_error: 68568.7422 - val_coeff_determination: 0.5846
#
# Epoch 00083: val_loss did not improve from 16.90131
# Epoch 84/1000
# 254417/254417 [==============================] - 115s 450us/step - loss: 19.2492 - mean_absolute_error: 17.8502 - mean_squared_error: 61212.4062 - coeff_determination: 0.6108 - val_loss: 17.1686 - val_mean_absolute_error: 15.7526 - val_mean_squared_error: 69296.1719 - val_coeff_determination: 0.5790
#
# Epoch 00084: val_loss did not improve from 16.90131
# Epoch 85/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 19.3924 - mean_absolute_error: 17.9869 - mean_squared_error: 61313.1172 - coeff_determination: 0.6075 - val_loss: 17.3722 - val_mean_absolute_error: 15.9536 - val_mean_squared_error: 71775.3047 - val_coeff_determination: 0.5606
#
# Epoch 00085: val_loss did not improve from 16.90131
# Epoch 86/1000
# 254417/254417 [==============================] - 115s 451us/step - loss: 19.3366 - mean_absolute_error: 17.9307 - mean_squared_error: 61287.5078 - coeff_determination: 0.6072 - val_loss: 17.1679 - val_mean_absolute_error: 15.7568 - val_mean_squared_error: 67930.5859 - val_coeff_determination: 0.5878
#
# Epoch 00086: val_loss did not improve from 16.90131
# Epoch 87/1000
# 254417/254417 [==============================] - 115s 450us/step - loss: 19.2650 - mean_absolute_error: 17.8549 - mean_squared_error: 61276.8125 - coeff_determination: 0.6053 - val_loss: 16.8893 - val_mean_absolute_error: 15.4693 - val_mean_squared_error: 69804.3906 - val_coeff_determination: 0.5745
#
# Epoch 00087: val_loss improved from 16.90131 to 16.88926, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 88/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 19.2141 - mean_absolute_error: 17.7998 - mean_squared_error: 61098.2773 - coeff_determination: 0.6074 - val_loss: 17.4285 - val_mean_absolute_error: 16.0097 - val_mean_squared_error: 73815.4844 - val_coeff_determination: 0.5440
#
# Epoch 00088: val_loss did not improve from 16.88926
# Epoch 89/1000
# 254417/254417 [==============================] - 115s 451us/step - loss: 19.2370 - mean_absolute_error: 17.8226 - mean_squared_error: 61013.5586 - coeff_determination: 0.6097 - val_loss: 17.1896 - val_mean_absolute_error: 15.7644 - val_mean_squared_error: 70443.6328 - val_coeff_determination: 0.5699
#
# Epoch 00089: val_loss did not improve from 16.88926
# Epoch 90/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 19.1969 - mean_absolute_error: 17.7799 - mean_squared_error: 61016.1641 - coeff_determination: 0.6098 - val_loss: 17.1062 - val_mean_absolute_error: 15.6753 - val_mean_squared_error: 68038.1406 - val_coeff_determination: 0.5876
#
# Epoch 00090: val_loss did not improve from 16.88926
# Epoch 91/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 19.1808 - mean_absolute_error: 17.7603 - mean_squared_error: 60660.6406 - coeff_determination: 0.6087 - val_loss: 17.3816 - val_mean_absolute_error: 15.9453 - val_mean_squared_error: 70614.2734 - val_coeff_determination: 0.5671
#
# Epoch 00091: val_loss did not improve from 16.88926
# Epoch 92/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 19.1931 - mean_absolute_error: 17.7743 - mean_squared_error: 60872.3516 - coeff_determination: 0.6112 - val_loss: 17.2395 - val_mean_absolute_error: 15.8082 - val_mean_squared_error: 71028.7891 - val_coeff_determination: 0.5664
#
# Epoch 00092: val_loss did not improve from 16.88926
# Epoch 93/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 19.1336 - mean_absolute_error: 17.7114 - mean_squared_error: 60616.6406 - coeff_determination: 0.6173 - val_loss: 17.4861 - val_mean_absolute_error: 16.0587 - val_mean_squared_error: 70624.4922 - val_coeff_determination: 0.5654
#
# Epoch 00093: val_loss did not improve from 16.88926
# Epoch 94/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.0793 - mean_absolute_error: 17.6562 - mean_squared_error: 60603.3242 - coeff_determination: 0.6166 - val_loss: 17.5197 - val_mean_absolute_error: 16.0914 - val_mean_squared_error: 68089.4766 - val_coeff_determination: 0.5843
#
# Epoch 00094: val_loss did not improve from 16.88926
# Epoch 95/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 19.0938 - mean_absolute_error: 17.6687 - mean_squared_error: 60543.2930 - coeff_determination: 0.6138 - val_loss: 17.0810 - val_mean_absolute_error: 15.6359 - val_mean_squared_error: 70252.3359 - val_coeff_determination: 0.5687
#
# Epoch 00095: val_loss did not improve from 16.88926
# Epoch 96/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 19.1258 - mean_absolute_error: 17.6993 - mean_squared_error: 60121.3633 - coeff_determination: 0.6162 - val_loss: 17.7432 - val_mean_absolute_error: 16.3060 - val_mean_squared_error: 69602.8125 - val_coeff_determination: 0.5749
#
# Epoch 00096: val_loss did not improve from 16.88926
# Epoch 97/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 19.1222 - mean_absolute_error: 17.6942 - mean_squared_error: 60539.7695 - coeff_determination: 0.6138 - val_loss: 17.2607 - val_mean_absolute_error: 15.8293 - val_mean_squared_error: 70175.6172 - val_coeff_determination: 0.5697
#
# Epoch 00097: val_loss did not improve from 16.88926
# Epoch 98/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 19.0878 - mean_absolute_error: 17.6592 - mean_squared_error: 60667.6367 - coeff_determination: 0.6098 - val_loss: 17.2712 - val_mean_absolute_error: 15.8400 - val_mean_squared_error: 73484.9688 - val_coeff_determination: 0.5461
#
# Epoch 00098: val_loss did not improve from 16.88926
# Epoch 99/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 19.0336 - mean_absolute_error: 17.6034 - mean_squared_error: 60376.9336 - coeff_determination: 0.6150 - val_loss: 17.1355 - val_mean_absolute_error: 15.6997 - val_mean_squared_error: 70665.5938 - val_coeff_determination: 0.5674
#
# Epoch 00099: val_loss did not improve from 16.88926
# Epoch 100/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 19.0651 - mean_absolute_error: 17.6347 - mean_squared_error: 60527.3984 - coeff_determination: 0.6124 - val_loss: 17.2410 - val_mean_absolute_error: 15.8062 - val_mean_squared_error: 71239.3203 - val_coeff_determination: 0.5640
#
# Epoch 00100: val_loss did not improve from 16.88926
# Epoch 101/1000
# 254417/254417 [==============================] - 113s 442us/step - loss: 19.0534 - mean_absolute_error: 17.6217 - mean_squared_error: 60268.3750 - coeff_determination: 0.6127 - val_loss: 16.8680 - val_mean_absolute_error: 15.4210 - val_mean_squared_error: 69097.7266 - val_coeff_determination: 0.5796
#
# Epoch 00101: val_loss improved from 16.88926 to 16.86801, saving model to /content/drive/My Drive/Colab Notebooks/TFM/IA/modelo_bilstm_full.model
# Epoch 102/1000
# 254417/254417 [==============================] - 112s 440us/step - loss: 18.9645 - mean_absolute_error: 17.5316 - mean_squared_error: 59731.9023 - coeff_determination: 0.6218 - val_loss: 17.5387 - val_mean_absolute_error: 16.0895 - val_mean_squared_error: 69744.5469 - val_coeff_determination: 0.5747
#
# Epoch 00102: val_loss did not improve from 16.86801
# Epoch 103/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.9984 - mean_absolute_error: 17.5609 - mean_squared_error: 60440.9258 - coeff_determination: 0.6176 - val_loss: 16.9986 - val_mean_absolute_error: 15.5537 - val_mean_squared_error: 72334.6875 - val_coeff_determination: 0.5534
#
# Epoch 00103: val_loss did not improve from 16.86801
# Epoch 104/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.9396 - mean_absolute_error: 17.5021 - mean_squared_error: 59991.9180 - coeff_determination: 0.6195 - val_loss: 17.2084 - val_mean_absolute_error: 15.7497 - val_mean_squared_error: 72645.2188 - val_coeff_determination: 0.5543
#
# Epoch 00104: val_loss did not improve from 16.86801
# Epoch 105/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.9716 - mean_absolute_error: 17.5298 - mean_squared_error: 60136.7812 - coeff_determination: 0.6174 - val_loss: 17.1468 - val_mean_absolute_error: 15.6931 - val_mean_squared_error: 71153.2500 - val_coeff_determination: 0.5639
#
# Epoch 00105: val_loss did not improve from 16.86801
# Epoch 106/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.8608 - mean_absolute_error: 17.4213 - mean_squared_error: 59615.5742 - coeff_determination: 0.6174 - val_loss: 17.3326 - val_mean_absolute_error: 15.8907 - val_mean_squared_error: 70918.0938 - val_coeff_determination: 0.5646
#
# Epoch 00106: val_loss did not improve from 16.86801
# Epoch 107/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 18.9395 - mean_absolute_error: 17.5022 - mean_squared_error: 59808.3008 - coeff_determination: 0.6198 - val_loss: 17.7559 - val_mean_absolute_error: 16.3023 - val_mean_squared_error: 70863.6719 - val_coeff_determination: 0.5640
#
# Epoch 00107: val_loss did not improve from 16.86801
# Epoch 108/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 18.9686 - mean_absolute_error: 17.5281 - mean_squared_error: 60390.5898 - coeff_determination: 0.6154 - val_loss: 17.3876 - val_mean_absolute_error: 15.9412 - val_mean_squared_error: 74000.4453 - val_coeff_determination: 0.5421
#
# Epoch 00108: val_loss did not improve from 16.86801
# Epoch 109/1000
# 254417/254417 [==============================] - 112s 441us/step - loss: 18.8788 - mean_absolute_error: 17.4344 - mean_squared_error: 59657.8828 - coeff_determination: 0.6201 - val_loss: 17.0833 - val_mean_absolute_error: 15.6339 - val_mean_squared_error: 71447.4531 - val_coeff_determination: 0.5622
#
# Epoch 00109: val_loss did not improve from 16.86801
# Epoch 110/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 18.9372 - mean_absolute_error: 17.4910 - mean_squared_error: 59973.1719 - coeff_determination: 0.6179 - val_loss: 17.6089 - val_mean_absolute_error: 16.1470 - val_mean_squared_error: 71973.8906 - val_coeff_determination: 0.5588
#
# Epoch 00110: val_loss did not improve from 16.86801
# Epoch 111/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.8146 - mean_absolute_error: 17.3669 - mean_squared_error: 59912.9297 - coeff_determination: 0.6226 - val_loss: 17.5415 - val_mean_absolute_error: 16.0931 - val_mean_squared_error: 74209.0547 - val_coeff_determination: 0.5449
#
# Epoch 00111: val_loss did not improve from 16.86801
# Epoch 112/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 18.8344 - mean_absolute_error: 17.3847 - mean_squared_error: 60099.0664 - coeff_determination: 0.6147 - val_loss: 17.4186 - val_mean_absolute_error: 15.9619 - val_mean_squared_error: 76736.0156 - val_coeff_determination: 0.5235
#
# Epoch 00112: val_loss did not improve from 16.86801
# Epoch 113/1000
# ...
#
# Epoch 00126: val_loss did not improve from 16.42893
# Epoch 127/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.6825 - mean_absolute_error: 17.2232 - mean_squared_error: 58957.4688 - coeff_determination: 0.6227 - val_loss: 18.2277 - val_mean_absolute_error: 16.7714 - val_mean_squared_error: 84242.4219 - val_coeff_determination: 0.4747
#
# Epoch 00127: val_loss did not improve from 16.42893
# Epoch 128/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.7587 - mean_absolute_error: 17.2981 - mean_squared_error: 59143.0664 - coeff_determination: 0.6201 - val_loss: 17.0001 - val_mean_absolute_error: 15.5334 - val_mean_squared_error: 74698.9688 - val_coeff_determination: 0.5398
#
# Epoch 00128: val_loss did not improve from 16.42893
# Epoch 129/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.6729 - mean_absolute_error: 17.2116 - mean_squared_error: 58814.4180 - coeff_determination: 0.6263 - val_loss: 17.2809 - val_mean_absolute_error: 15.8052 - val_mean_squared_error: 75953.6172 - val_coeff_determination: 0.5317
#
# Epoch 00129: val_loss did not improve from 16.42893
# Epoch 130/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 18.6303 - mean_absolute_error: 17.1657 - mean_squared_error: 58934.5625 - coeff_determination: 0.6247 - val_loss: 17.9601 - val_mean_absolute_error: 16.4845 - val_mean_squared_error: 88785.1484 - val_coeff_determination: 0.4417
#
# Epoch 00130: val_loss did not improve from 16.42893
# Epoch 131/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 18.7486 - mean_absolute_error: 17.2843 - mean_squared_error: 58952.8477 - coeff_determination: 0.6246 - val_loss: 18.0944 - val_mean_absolute_error: 16.6124 - val_mean_squared_error: 81143.0391 - val_coeff_determination: 0.4974
#
# Epoch 00131: val_loss did not improve from 16.42893
# Epoch 132/1000
# 254417/254417 [==============================] - 112s 442us/step - loss: 18.7226 - mean_absolute_error: 17.2588 - mean_squared_error: 59291.1836 - coeff_determination: 0.6193 - val_loss: 17.0479 - val_mean_absolute_error: 15.5789 - val_mean_squared_error: 81787.6094 - val_coeff_determination: 0.4939
#
# Epoch 00132: val_loss did not improve from 16.42893
# Epoch 133/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.6410 - mean_absolute_error: 17.1778 - mean_squared_error: 59067.2422 - coeff_determination: 0.6250 - val_loss: 17.8021 - val_mean_absolute_error: 16.3373 - val_mean_squared_error: 83622.3203 - val_coeff_determination: 0.4718
#
# Epoch 00133: val_loss did not improve from 16.42893
# Epoch 134/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.7246 - mean_absolute_error: 17.2579 - mean_squared_error: 58954.8047 - coeff_determination: 0.6217 - val_loss: 17.3781 - val_mean_absolute_error: 15.9076 - val_mean_squared_error: 84149.6250 - val_coeff_determination: 0.4758
#
# Epoch 00134: val_loss did not improve from 16.42893
# Epoch 135/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.6605 - mean_absolute_error: 17.1928 - mean_squared_error: 58679.4219 - coeff_determination: 0.6224 - val_loss: 17.3222 - val_mean_absolute_error: 15.8520 - val_mean_squared_error: 82767.8672 - val_coeff_determination: 0.4839
#
# Epoch 00135: val_loss did not improve from 16.42893
# Epoch 136/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 18.6100 - mean_absolute_error: 17.1405 - mean_squared_error: 58448.7773 - coeff_determination: 0.6277 - val_loss: 17.7761 - val_mean_absolute_error: 16.2971 - val_mean_squared_error: 82585.3281 - val_coeff_determination: 0.4853
#
# Epoch 00136: val_loss did not improve from 16.42893
# Epoch 137/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 18.6723 - mean_absolute_error: 17.1998 - mean_squared_error: 59068.2891 - coeff_determination: 0.6208 - val_loss: 17.0572 - val_mean_absolute_error: 15.5838 - val_mean_squared_error: 78763.8047 - val_coeff_determination: 0.5119
#
# Epoch 00137: val_loss did not improve from 16.42893
# Epoch 138/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.6448 - mean_absolute_error: 17.1714 - mean_squared_error: 58704.3125 - coeff_determination: 0.6239 - val_loss: 17.4349 - val_mean_absolute_error: 15.9569 - val_mean_squared_error: 76551.7812 - val_coeff_determination: 0.5267
#
# Epoch 00138: val_loss did not improve from 16.42893
# Epoch 139/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.5993 - mean_absolute_error: 17.1280 - mean_squared_error: 58799.2891 - coeff_determination: 0.6241 - val_loss: 17.4032 - val_mean_absolute_error: 15.9235 - val_mean_squared_error: 81985.4453 - val_coeff_determination: 0.4919
#
# Epoch 00139: val_loss did not improve from 16.42893
# Epoch 140/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.6277 - mean_absolute_error: 17.1522 - mean_squared_error: 58907.9805 - coeff_determination: 0.6222 - val_loss: 17.2590 - val_mean_absolute_error: 15.7866 - val_mean_squared_error: 89566.4141 - val_coeff_determination: 0.4406
#
# Epoch 00140: val_loss did not improve from 16.42893
# Epoch 141/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 18.5578 - mean_absolute_error: 17.0859 - mean_squared_error: 58115.3633 - coeff_determination: 0.6252 - val_loss: 17.1731 - val_mean_absolute_error: 15.6917 - val_mean_squared_error: 92718.2969 - val_coeff_determination: 0.4197
#
# Epoch 00141: val_loss did not improve from 16.42893
# Epoch 142/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.5410 - mean_absolute_error: 17.0675 - mean_squared_error: 58716.8164 - coeff_determination: 0.6269 - val_loss: 17.0124 - val_mean_absolute_error: 15.5270 - val_mean_squared_error: 81585.4844 - val_coeff_determination: 0.4924
#
# Epoch 00142: val_loss did not improve from 16.42893
# Epoch 143/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 18.5099 - mean_absolute_error: 17.0365 - mean_squared_error: 58377.1641 - coeff_determination: 0.6267 - val_loss: 17.2897 - val_mean_absolute_error: 15.8028 - val_mean_squared_error: 94746.3359 - val_coeff_determination: 0.4035
#
# Epoch 00143: val_loss did not improve from 16.42893
# Epoch 144/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 18.5223 - mean_absolute_error: 17.0518 - mean_squared_error: 58574.9844 - coeff_determination: 0.6283 - val_loss: 16.9608 - val_mean_absolute_error: 15.4876 - val_mean_squared_error: 84340.1406 - val_coeff_determination: 0.4783
#
# Epoch 00144: val_loss did not improve from 16.42893
# Epoch 145/1000
# 254417/254417 [==============================] - 113s 446us/step - loss: 18.5579 - mean_absolute_error: 17.0865 - mean_squared_error: 58430.3125 - coeff_determination: 0.6212 - val_loss: 17.2091 - val_mean_absolute_error: 15.7269 - val_mean_squared_error: 84758.3516 - val_coeff_determination: 0.4729
#
# Epoch 00145: val_loss did not improve from 16.42893
# Epoch 146/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.5250 - mean_absolute_error: 17.0505 - mean_squared_error: 58277.1641 - coeff_determination: 0.6265 - val_loss: 16.9074 - val_mean_absolute_error: 15.4220 - val_mean_squared_error: 82354.9062 - val_coeff_determination: 0.4903
#
# Epoch 00146: val_loss did not improve from 16.42893
# Epoch 147/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 18.5205 - mean_absolute_error: 17.0468 - mean_squared_error: 58610.1094 - coeff_determination: 0.6260 - val_loss: 17.1583 - val_mean_absolute_error: 15.6710 - val_mean_squared_error: 80940.6172 - val_coeff_determination: 0.4954
#
# Epoch 00147: val_loss did not improve from 16.42893
# Epoch 148/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.5449 - mean_absolute_error: 17.0700 - mean_squared_error: 58167.8047 - coeff_determination: 0.6259 - val_loss: 17.2201 - val_mean_absolute_error: 15.7311 - val_mean_squared_error: 89500.5938 - val_coeff_determination: 0.4373
#
# Epoch 00148: val_loss did not improve from 16.42893
# Epoch 149/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.5812 - mean_absolute_error: 17.1040 - mean_squared_error: 58171.5430 - coeff_determination: 0.6284 - val_loss: 17.1569 - val_mean_absolute_error: 15.6770 - val_mean_squared_error: 90934.4141 - val_coeff_determination: 0.4260
#
# Epoch 00149: val_loss did not improve from 16.42893
# Epoch 150/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 18.5237 - mean_absolute_error: 17.0492 - mean_squared_error: 58754.1484 - coeff_determination: 0.6225 - val_loss: 16.8952 - val_mean_absolute_error: 15.4047 - val_mean_squared_error: 83513.5156 - val_coeff_determination: 0.4761
#
# Epoch 00150: val_loss did not improve from 16.42893
# Epoch 151/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.4851 - mean_absolute_error: 17.0102 - mean_squared_error: 59143.5312 - coeff_determination: 0.6201 - val_loss: 17.8494 - val_mean_absolute_error: 16.3659 - val_mean_squared_error: 95837.4688 - val_coeff_determination: 0.3952
#
# Epoch 00151: val_loss did not improve from 16.42893
# Epoch 152/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 18.4616 - mean_absolute_error: 16.9856 - mean_squared_error: 58859.5859 - coeff_determination: 0.6257 - val_loss: 17.3132 - val_mean_absolute_error: 15.8189 - val_mean_squared_error: 93230.1172 - val_coeff_determination: 0.4121
#
# Epoch 00152: val_loss did not improve from 16.42893
# Epoch 153/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.4368 - mean_absolute_error: 16.9608 - mean_squared_error: 58416.3477 - coeff_determination: 0.6294 - val_loss: 17.1385 - val_mean_absolute_error: 15.6523 - val_mean_squared_error: 87862.2734 - val_coeff_determination: 0.4523
#
# Epoch 00153: val_loss did not improve from 16.42893
# Epoch 154/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 18.5150 - mean_absolute_error: 17.0378 - mean_squared_error: 58281.8125 - coeff_determination: 0.6275 - val_loss: 17.2936 - val_mean_absolute_error: 15.8000 - val_mean_squared_error: 92393.3828 - val_coeff_determination: 0.4165
#
# Epoch 00154: val_loss did not improve from 16.42893
# Epoch 155/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.4642 - mean_absolute_error: 16.9873 - mean_squared_error: 58716.2734 - coeff_determination: 0.6271 - val_loss: 17.5823 - val_mean_absolute_error: 16.1048 - val_mean_squared_error: 104517.3672 - val_coeff_determination: 0.3331
#
# Epoch 00155: val_loss did not improve from 16.42893
# Epoch 156/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 18.4687 - mean_absolute_error: 16.9921 - mean_squared_error: 58430.8945 - coeff_determination: 0.6269 - val_loss: 17.5338 - val_mean_absolute_error: 16.0406 - val_mean_squared_error: 90116.1641 - val_coeff_determination: 0.4324
#
# Epoch 00156: val_loss did not improve from 16.42893
# Epoch 157/1000
# 254417/254417 [==============================] - 114s 448us/step - loss: 18.4303 - mean_absolute_error: 16.9525 - mean_squared_error: 58636.0625 - coeff_determination: 0.6279 - val_loss: 17.7138 - val_mean_absolute_error: 16.2209 - val_mean_squared_error: 90716.3672 - val_coeff_determination: 0.4329
#
# Epoch 00157: val_loss did not improve from 16.42893
# Epoch 158/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 18.4159 - mean_absolute_error: 16.9402 - mean_squared_error: 58317.7539 - coeff_determination: 0.6280 - val_loss: 17.2868 - val_mean_absolute_error: 15.8107 - val_mean_squared_error: 86781.0625 - val_coeff_determination: 0.4547
#
# Epoch 00158: val_loss did not improve from 16.42893
# Epoch 159/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.4059 - mean_absolute_error: 16.9319 - mean_squared_error: 58484.0352 - coeff_determination: 0.6226 - val_loss: 18.1424 - val_mean_absolute_error: 16.6691 - val_mean_squared_error: 89872.5078 - val_coeff_determination: 0.4425
#
# Epoch 00159: val_loss did not improve from 16.42893
# Epoch 160/1000
# 254417/254417 [==============================] - 114s 447us/step - loss: 18.4390 - mean_absolute_error: 16.9591 - mean_squared_error: 58670.4375 - coeff_determination: 0.6239 - val_loss: 17.4316 - val_mean_absolute_error: 15.9471 - val_mean_squared_error: 84609.6328 - val_coeff_determination: 0.4734
#
# Epoch 00160: val_loss did not improve from 16.42893
# Epoch 161/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.3450 - mean_absolute_error: 16.8653 - mean_squared_error: 58316.3125 - coeff_determination: 0.6296 - val_loss: 17.0607 - val_mean_absolute_error: 15.5767 - val_mean_squared_error: 91284.0234 - val_coeff_determination: 0.4252
#
# Epoch 00161: val_loss did not improve from 16.42893
# Epoch 162/1000
# 254417/254417 [==============================] - 114s 446us/step - loss: 18.4845 - mean_absolute_error: 16.9994 - mean_squared_error: 59295.1328 - coeff_determination: 0.6250 - val_loss: 17.0770 - val_mean_absolute_error: 15.5899 - val_mean_squared_error: 87379.3203 - val_coeff_determination: 0.4574
#
# Epoch 00162: val_loss did not improve from 16.42893
# Epoch 163/1000
# 254417/254417 [==============================] - 113s 444us/step - loss: 18.3967 - mean_absolute_error: 16.9109 - mean_squared_error: 58236.3516 - coeff_determination: 0.6260 - val_loss: 17.1485 - val_mean_absolute_error: 15.6705 - val_mean_squared_error: 90340.8984 - val_coeff_determination: 0.4334
#
# Epoch 00163: val_loss did not improve from 16.42893
# Epoch 164/1000
# 254417/254417 [==============================] - 110s 434us/step - loss: 18.3622 - mean_absolute_error: 16.8778 - mean_squared_error: 58261.4297 - coeff_determination: 0.6274 - val_loss: 17.9344 - val_mean_absolute_error: 16.4488 - val_mean_squared_error: 91347.2500 - val_coeff_determination: 0.4252
#
# Epoch 00164: val_loss did not improve from 16.42893
# Epoch 165/1000
# 254417/254417 [==============================] - 113s 442us/step - loss: 18.3096 - mean_absolute_error: 16.8266 - mean_squared_error: 57537.8047 - coeff_determination: 0.6388 - val_loss: 17.2673 - val_mean_absolute_error: 15.7811 - val_mean_squared_error: 94862.1875 - val_coeff_determination: 0.4072
#
# Epoch 00165: val_loss did not improve from 16.42893
# Epoch 166/1000
# 254417/254417 [==============================] - 114s 449us/step - loss: 18.4077 - mean_absolute_error: 16.9224 - mean_squared_error: 58879.5039 - coeff_determination: 0.6281 - val_loss: 17.5947 - val_mean_absolute_error: 16.0936 - val_mean_squared_error: 107279.3047 - val_coeff_determination: 0.3275
#
# Epoch 00166: val_loss did not improve from 16.42893
# Epoch 167/1000
# 254417/254417 [==============================] - 113s 445us/step - loss: 18.4126 - mean_absolute_error: 16.9285 - mean_squared_error: 57948.7852 - coeff_determination: 0.6260 - val_loss: 16.7840 - val_mean_absolute_error: 15.2956 - val_mean_squared_error: 84864.0391 - val_coeff_determination: 0.4730
#
# Epoch 00167: val_loss did not improve from 16.42893
# Epoch 168/1000
# 254417/254417 [==============================] - 113s 443us/step - loss: 18.3770 - mean_absolute_error: 16.8930 - mean_squared_error: 57673.6250 - coeff_determination: 0.6305 - val_loss: 17.6689 - val_mean_absolute_error: 16.1725 - val_mean_squared_error: 102915.3906 - val_coeff_determination: 0.3504
#
# Epoch 00168: val_loss did not improve from 16.42893
# Epoch 169/1000
# 254417/254417 [==============================] - 115s 452us/step - loss: 18.3525 - mean_absolute_error: 16.8673 - mean_squared_error: 57994.0820 - coeff_determination: 0.6298 - val_loss: 17.0798 - val_mean_absolute_error: 15.5818 - val_mean_squared_error: 90044.4766 - val_coeff_determination: 0.4368
#
# Epoch 00169: val_loss did not improve from 16.42893
# Epoch 00169: early stopping

# %%
predict_y_bi_lstm = model_bi_lstm.predict(test_x)

# %% [markdown]
# # Árbol extremadamente aleatorio

# %% [markdown]
# ## Funciones

# %%
def ajustar_entrada(original):
    return np.reshape(original, (original.shape[0], original.shape[1]*original.shape[2]))

# %% [markdown]
# ## Ejecución

# %%
model_extra = ExtraTreesRegressor(n_estimators=350, random_state=0)

# %%
history_extra = model_extra.fit(ajustar_entrada(train_x), train_y)

# %%
dump(model_extra, '/content/drive/My Drive/Colab Notebooks/TFM/IA/model_extra_full_2.joblib.z')
# Out:
# ['/content/drive/My Drive/Colab Notebooks/TFM/IA/model_extra_full_2.joblib.z']

# %%
predict_y_extra = model_extra.predict(ajustar_entrada(test_x))

# %% [markdown]
# ## Metrica

# %%
mean_squared_error(test_y,predict_y_extra)

# %%
mean_absolute_error(test_y,predict_y_extra)

# %%
r2_score(test_y,predict_y_extra)

# %% [markdown]
# # Comparación

# %% [markdown]
# ## Funciones

# %%
def all_metrics (test_y, predict_y, name):
    
    mse = mean_squared_error(test_y,predict_y)
    
    print('Para la técnica ',name, ' da un error cuadratico medio de ', mse)
    
    mae = mean_absolute_error(test_y,predict_y)
    
    print('Para la técnica ',name, ' da un error absoluto medio de ', mae)
    
    r2 = r2_score(test_y,predict_y)
    
    print('Para la técnica ',name, ' da un r cuadrado de ', r2*100, ' %')

# %%
#Ayuda a plotear una metrica para varias redes
# Entrada
#Tensor de histories
#Tensor de nombres
#Nombre de la metrica
# Salida
#No da salida
# Resultado
#Gráfico Ploteado
def plot_compare(histories, names, metric):

    #realizamos nobres para traer valores
    train_metric = metric
    test_metric = 'val_'+metric

    #Colocamos el tituo
    plt.title(metric)

    #Recorremos todas las historias
    for history in histories:
        color = np.random.rand(3,)
        plt.plot(history.history[train_metric], c=color)
        plt.plot(history.history[test_metric], 'r--', c=color)

    plt.ylabel(metric)
    plt.xlabel('Epoch')

    legend = []

    for name in names:
        legend.append('Entrenamiento ' + name)
        legend.append('Evaluación ' + name)

    plt.legend(legend,
               loc='lower right')

    plt.figure(figsize=(20,11))
    
    plt.show()

# %%
def load_models(path, test_x):

  model = load_model('/content/drive/My Drive/Colab Notebooks/TFM/IA/'+path+'_full.h5',
                     {"coeff_determination":coeff_determination})

  predict_y = model.predict(test_x)

  return model, predict_y

# %% [markdown]
# ## Funciones para guardar los modelos

# %%
def save_model(model,history,coeff_determination,name):
  dump([model,history,coeff_determination], 
       '/content/drive/My Drive/Colab Notebooks/TFM/IA/'+name+'.joblib.z')

# %%
#save_model(model_dnn,history_dnn,coeff_determination,'model_dnn_full2')

# %%
#save_model(model_cnn,history_cnn,coeff_determination,'model_cnn_full2')

# %%
#save_model(model_lstm,history_lstm,coeff_determination,'model_lstm_full2')

# %%
#save_model(model_bi_lstm,history_bi_lstm,coeff_determination,'model_bi_lstm_full2')

# %% [markdown]
# ## Funciones para cargar nuevamente los modelos

# %%
#model_dnn, predict_y_dnn = load_models('modelo_dnn_full',test_x)

# %%
#model_cnn, predict_y_cnn = load_models('modelo_cnn_full',test_x_cnn)

# %%
#model_lstm, predict_y_lstm = load_models('modelo_lstm_full',test_x)

# %%
#model_bi_lstm, predict_bi_lstm = load_models('modelo_bilstm_full',test_x)

# %%
#model_extra = load('/content/drive/My Drive/Colab Notebooks/TFM/IA/model_extra_full.joblib.z')

# %% [markdown]
# ## Metricas establecidas

# %%
all_metrics(test_y, predict_y_dnn, 'Red Neuronal Profunda')

# %%
all_metrics(test_y, predict_y_cnn, 'Red Neuronal Convolucional')

# %%
all_metrics(test_y, predict_y_lstm, 'Red Neuronal LSTM')

# %%
all_metrics(test_y, predict_y_bi_lstm, 'Convolucional Bi-Direccional LSTM Profunda')

# %%
all_metrics(test_y, predict_y_extra, 'Árboles extremadamente aleatorios')

# %% [markdown]
# ## Gráficas comparativas DNN vs CNN vs LSTM

# %%
#Gráficas comparativas de los diferentes resultados
histories = [history_dnn, history_cnn, history_lstm, history_bi_lstm]
names = ['Profunda', 'Convolucional', 'Recurrente LSTM', 'NNCRLSTMD']

# %%
#Loss Function
plot_compare(histories, names, 'loss')

# %%
#Error medio absoluto
plot_compare(histories, names, 'mean_absolute_error')

# %%
#Error cuadratico medio
plot_compare(histories, names, 'mean_squared_error')

# %%
#Coeff
plot_compare(histories, names, 'coeff_determination')
